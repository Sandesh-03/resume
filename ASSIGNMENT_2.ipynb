# %% [markdown]
# #**ASSIGNMENT 2: VECTOR ADDITION**

# %% [markdown]
# **1] Install cuda toolkit of nvidia**

# %%
# !apt-get update
# !apt-get install -y --no-install-recommends nvidia-cuda-toolkit
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:6 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [1,784 kB]
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,735 kB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,065 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,455 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [1,822 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,339 kB]
# Fetched 9,541 kB in 3s (2,923 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libaccinj64-11.5 libcub-dev libcublas11 libcublaslt11 libcudart11.0 libcufft10 libcufftw10
#   libcuinj64-11.5 libcupti-dev libcupti11.5 libcurand10 libcusolver11 libcusolvermg11 libcusparse11
#   libnppc11 libnppial11 libnppicc11 libnppidei11 libnppif11 libnppig11 libnppim11 libnppist11
#   libnppisu11 libnppitc11 libnpps11 libnvblas11 libnvidia-compute-495 libnvidia-compute-510
#   libnvidia-compute-525 libnvidia-ml-dev libnvjpeg11 libnvrtc-builtins11.5 libnvrtc11.2
#   libnvtoolsext1 libnvvm4 libthrust-dev nvidia-cuda-dev nvidia-profiler
# Recommended packages:
#   libcupti-doc libgl1-mesa-dev | libgl-dev libvdpau-dev libnvcuvid1 nvidia-cuda-toolkit-doc
#   nvidia-cuda-gdb nvidia-visual-profiler nsight-compute nsight-systems
# The following NEW packages will be installed:
#   libaccinj64-11.5 libcub-dev libcublas11 libcublaslt11 libcudart11.0 libcufft10 libcufftw10
#   libcuinj64-11.5 libcupti-dev libcupti11.5 libcurand10 libcusolver11 libcusolvermg11 libcusparse11
#   libnppc11 libnppial11 libnppicc11 libnppidei11 libnppif11 libnppig11 libnppim11 libnppist11
#   libnppisu11 libnppitc11 libnpps11 libnvblas11 libnvidia-compute-495 libnvidia-compute-510
#   libnvidia-compute-525 libnvidia-ml-dev libnvjpeg11 libnvrtc-builtins11.5 libnvrtc11.2
#   libnvtoolsext1 libnvvm4 libthrust-dev nvidia-cuda-dev nvidia-cuda-toolkit nvidia-profiler
# 0 upgraded, 39 newly installed, 0 to remove and 35 not upgraded.
# Need to get 1,395 MB of archives.
# After this operation, 3,993 MB of additional disk space will be used.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  libnvidia-compute-525 525.147.05-0ubuntu1 [50.4 MB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcupti11.5 amd64 11.5.114~11.5.1-1ubuntu1 [7,696 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libaccinj64-11.5 amd64 11.5.114~11.5.1-1ubuntu1 [845 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcub-dev all 1.15.0-3 [217 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcublaslt11 amd64 11.7.4.6~11.5.1-1ubuntu1 [148 MB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcublas11 amd64 11.7.4.6~11.5.1-1ubuntu1 [78.2 MB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcudart11.0 amd64 11.5.117~11.5.1-1ubuntu1 [178 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcufft10 amd64 11.1.1+~10.6.0.107~11.5.1-1ubuntu1 [70.4 MB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcufftw10 amd64 11.1.1+~10.6.0.107~11.5.1-1ubuntu1 [211 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 libnvidia-compute-510 amd64 525.147.05-0ubuntu0.22.04.1 [7,194 B]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 libnvidia-compute-495 amd64 510.108.03-0ubuntu0.22.04.1 [7,378 B]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcuinj64-11.5 amd64 11.5.114~11.5.1-1ubuntu1 [1,004 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcurand10 amd64 11.1.1+~10.2.7.107~11.5.1-1ubuntu1 [41.8 MB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcusolver11 amd64 11.3.2.107~11.5.1-1ubuntu1 [31.3 MB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcusolvermg11 amd64 11.3.2.107~11.5.1-1ubuntu1 [17.8 MB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcusparse11 amd64 11.7.0.107~11.5.1-1ubuntu1 [96.2 MB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppc11 amd64 11.5.1.107~11.5.1-1ubuntu1 [430 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppial11 amd64 11.5.1.107~11.5.1-1ubuntu1 [5,234 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppicc11 amd64 11.5.1.107~11.5.1-1ubuntu1 [2,373 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppidei11 amd64 11.5.1.107~11.5.1-1ubuntu1 [2,587 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppif11 amd64 11.5.1.107~11.5.1-1ubuntu1 [33.8 MB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppig11 amd64 11.5.1.107~11.5.1-1ubuntu1 [14.5 MB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppim11 amd64 11.5.1.107~11.5.1-1ubuntu1 [3,037 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppist11 amd64 11.5.1.107~11.5.1-1ubuntu1 [13.7 MB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppisu11 amd64 11.5.1.107~11.5.1-1ubuntu1 [177 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnppitc11 amd64 11.5.1.107~11.5.1-1ubuntu1 [1,292 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnpps11 amd64 11.5.1.107~11.5.1-1ubuntu1 [7,116 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvblas11 amd64 11.7.4.6~11.5.1-1ubuntu1 [191 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvidia-ml-dev amd64 11.5.50~11.5.1-1ubuntu1 [69.1 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvjpeg11 amd64 11.5.4.107~11.5.1-1ubuntu1 [1,858 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvrtc-builtins11.5 amd64 11.5.119~11.5.1-1ubuntu1 [116 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvrtc11.2 amd64 11.5.119~11.5.1-1ubuntu1 [15.7 MB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvvm4 amd64 11.5.119~11.5.1-1ubuntu1 [8,675 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcupti-dev amd64 11.5.114~11.5.1-1ubuntu1 [7,915 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libnvtoolsext1 amd64 11.5.114~11.5.1-1ubuntu1 [28.8 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libthrust-dev all 1.15.0-1 [423 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 nvidia-cuda-dev amd64 11.5.1-1ubuntu1 [667 MB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 nvidia-profiler amd64 11.5.114~11.5.1-1ubuntu1 [1,732 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 nvidia-cuda-toolkit amd64 11.5.1-1ubuntu1 [62.8 MB]
# Fetched 1,395 MB in 1min 34s (14.9 MB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package libcupti11.5:amd64.
# (Reading database ... 121749 files and directories currently installed.)
# Preparing to unpack .../00-libcupti11.5_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcupti11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libaccinj64-11.5:amd64.
# Preparing to unpack .../01-libaccinj64-11.5_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libaccinj64-11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcub-dev.
# Preparing to unpack .../02-libcub-dev_1.15.0-3_all.deb ...
# Unpacking libcub-dev (1.15.0-3) ...
# Selecting previously unselected package libcublaslt11:amd64.
# Preparing to unpack .../03-libcublaslt11_11.7.4.6~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcublaslt11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcublas11:amd64.
# Preparing to unpack .../04-libcublas11_11.7.4.6~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcublas11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcudart11.0:amd64.
# Preparing to unpack .../05-libcudart11.0_11.5.117~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcudart11.0:amd64 (11.5.117~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcufft10:amd64.
# Preparing to unpack .../06-libcufft10_11.1.1+~10.6.0.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcufft10:amd64 (11.1.1+~10.6.0.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcufftw10:amd64.
# Preparing to unpack .../07-libcufftw10_11.1.1+~10.6.0.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcufftw10:amd64 (11.1.1+~10.6.0.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvidia-compute-525:amd64.
# Preparing to unpack .../08-libnvidia-compute-525_525.147.05-0ubuntu1_amd64.deb ...
# Unpacking libnvidia-compute-525:amd64 (525.147.05-0ubuntu1) ...
# Selecting previously unselected package libnvidia-compute-510:amd64.
# Preparing to unpack .../09-libnvidia-compute-510_525.147.05-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libnvidia-compute-510:amd64 (525.147.05-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libnvidia-compute-495:amd64.
# Preparing to unpack .../10-libnvidia-compute-495_510.108.03-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libnvidia-compute-495:amd64 (510.108.03-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libcuinj64-11.5:amd64.
# Preparing to unpack .../11-libcuinj64-11.5_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcuinj64-11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcurand10:amd64.
# Preparing to unpack .../12-libcurand10_11.1.1+~10.2.7.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcurand10:amd64 (11.1.1+~10.2.7.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcusolver11:amd64.
# Preparing to unpack .../13-libcusolver11_11.3.2.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcusolver11:amd64 (11.3.2.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcusolvermg11:amd64.
# Preparing to unpack .../14-libcusolvermg11_11.3.2.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcusolvermg11:amd64 (11.3.2.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcusparse11:amd64.
# Preparing to unpack .../15-libcusparse11_11.7.0.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcusparse11:amd64 (11.7.0.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppc11:amd64.
# Preparing to unpack .../16-libnppc11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppial11:amd64.
# Preparing to unpack .../17-libnppial11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppial11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppicc11:amd64.
# Preparing to unpack .../18-libnppicc11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppicc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppidei11:amd64.
# Preparing to unpack .../19-libnppidei11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppidei11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppif11:amd64.
# Preparing to unpack .../20-libnppif11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppif11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppig11:amd64.
# Preparing to unpack .../21-libnppig11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppig11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppim11:amd64.
# Preparing to unpack .../22-libnppim11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppim11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppist11:amd64.
# Preparing to unpack .../23-libnppist11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppist11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppisu11:amd64.
# Preparing to unpack .../24-libnppisu11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppisu11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnppitc11:amd64.
# Preparing to unpack .../25-libnppitc11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnppitc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnpps11:amd64.
# Preparing to unpack .../26-libnpps11_11.5.1.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnpps11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvblas11:amd64.
# Preparing to unpack .../27-libnvblas11_11.7.4.6~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvblas11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvidia-ml-dev:amd64.
# Preparing to unpack .../28-libnvidia-ml-dev_11.5.50~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvidia-ml-dev:amd64 (11.5.50~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvjpeg11:amd64.
# Preparing to unpack .../29-libnvjpeg11_11.5.4.107~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvjpeg11:amd64 (11.5.4.107~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvrtc-builtins11.5:amd64.
# Preparing to unpack .../30-libnvrtc-builtins11.5_11.5.119~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvrtc-builtins11.5:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvrtc11.2:amd64.
# Preparing to unpack .../31-libnvrtc11.2_11.5.119~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvrtc11.2:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvvm4:amd64.
# Preparing to unpack .../32-libnvvm4_11.5.119~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvvm4:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libcupti-dev:amd64.
# Preparing to unpack .../33-libcupti-dev_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcupti-dev:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libnvtoolsext1:amd64.
# Preparing to unpack .../34-libnvtoolsext1_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libnvtoolsext1:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package libthrust-dev.
# Preparing to unpack .../35-libthrust-dev_1.15.0-1_all.deb ...
# Unpacking libthrust-dev (1.15.0-1) ...
# Selecting previously unselected package nvidia-cuda-dev:amd64.
# Preparing to unpack .../36-nvidia-cuda-dev_11.5.1-1ubuntu1_amd64.deb ...
# Unpacking nvidia-cuda-dev:amd64 (11.5.1-1ubuntu1) ...
# Selecting previously unselected package nvidia-profiler.
# Preparing to unpack .../37-nvidia-profiler_11.5.114~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking nvidia-profiler (11.5.114~11.5.1-1ubuntu1) ...
# Selecting previously unselected package nvidia-cuda-toolkit.
# Preparing to unpack .../38-nvidia-cuda-toolkit_11.5.1-1ubuntu1_amd64.deb ...
# Unpacking nvidia-cuda-toolkit (11.5.1-1ubuntu1) ...
# Setting up libcusparse11:amd64 (11.7.0.107~11.5.1-1ubuntu1) ...
# Setting up libnppc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libcudart11.0:amd64 (11.5.117~11.5.1-1ubuntu1) ...
# Setting up libnppisu11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libnppicc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libnvjpeg11:amd64 (11.5.4.107~11.5.1-1ubuntu1) ...
# Setting up libcublaslt11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Setting up libcupti11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libnpps11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libnppim11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libcufft10:amd64 (11.1.1+~10.6.0.107~11.5.1-1ubuntu1) ...
# Setting up libnppitc11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libnppist11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libnvidia-compute-525:amd64 (525.147.05-0ubuntu1) ...
# Setting up libnvvm4:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Setting up libnvtoolsext1:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libcub-dev (1.15.0-3) ...
# Setting up libaccinj64-11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libnppig11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libcurand10:amd64 (11.1.1+~10.2.7.107~11.5.1-1ubuntu1) ...
# Setting up libnvrtc-builtins11.5:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Setting up libnppidei11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libthrust-dev (1.15.0-1) ...
# Setting up libnppial11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libnppif11:amd64 (11.5.1.107~11.5.1-1ubuntu1) ...
# Setting up libcufftw10:amd64 (11.1.1+~10.6.0.107~11.5.1-1ubuntu1) ...
# Setting up libcublas11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Setting up libnvidia-compute-510:amd64 (525.147.05-0ubuntu0.22.04.1) ...
# Setting up libcupti-dev:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libnvidia-compute-495:amd64 (510.108.03-0ubuntu0.22.04.1) ...
# Setting up libnvblas11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# Setting up libcusolver11:amd64 (11.3.2.107~11.5.1-1ubuntu1) ...
# Setting up libnvrtc11.2:amd64 (11.5.119~11.5.1-1ubuntu1) ...
# Setting up libcusolvermg11:amd64 (11.3.2.107~11.5.1-1ubuntu1) ...
# Setting up libcuinj64-11.5:amd64 (11.5.114~11.5.1-1ubuntu1) ...
# Setting up libnvidia-ml-dev:amd64 (11.5.50~11.5.1-1ubuntu1) ...
# Setting up nvidia-cuda-dev:amd64 (11.5.1-1ubuntu1) ...
# Setting up nvidia-profiler (11.5.114~11.5.1-1ubuntu1) ...
# Setting up nvidia-cuda-toolkit (11.5.1-1ubuntu1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link

# %% [markdown]
# **2] Set environment variables**

# %%
# !export PATH=/usr/local/cuda/bin/:$PATH
# !export LD_LIBRARY_PATH=/usr/local/cuda/lib64/:$LD_LIBRARY_PATH

# %% [markdown]
# **3] Sequential code of vector addition:**

# %%
# %%writefile sequential.cpp
#
# #include <iostream>
# #include <Eigen/Dense>
# #include <vector>
# #include <cmath>
# #include <ctime>
#
# using namespace Eigen;
# using namespace std;
#
# vector<vector<double>> polar_to_cartesian(const vector<double>& magnitudes, const vector<double>& angles) {
#     vector<vector<double>> cartesian_vectors;
#     for (size_t i = 0; i < magnitudes.size(); ++i) {
#         double x = magnitudes[i] * cos(angles[i] * M_PI / 180.0);
#         double y = magnitudes[i] * sin(angles[i] * M_PI / 180.0);
#         cartesian_vectors.push_back({x, y});
#     }
#     return cartesian_vectors;
# }
#
# pair<vector<double>, vector<double>> cartesian_to_polar(const MatrixXd& vectors) {
#     vector<double> magnitudes;
#     vector<double> angles;
#     for (int i = 0; i < vectors.rows(); ++i) {
#         double magnitude = vectors.row(i).norm();
#         double angle = atan2(vectors(i, 1), vectors(i, 0)) * 180.0 / M_PI;
#         magnitudes.push_back(magnitude);
#         angles.push_back(angle);
#     }
#     return {magnitudes, angles};
# }
#
# pair<vector<double>, vector<double>> add_polar_vectors(const vector<double>& magnitudes1, const vector<double>& angles1,
#                                                        const vector<double>& magnitudes2, const vector<double>& angles2) {
#     MatrixXd vectors1 = Map<const MatrixXd>(polar_to_cartesian(magnitudes1, angles1)[0].data(), magnitudes1.size(), 2);
#     MatrixXd vectors2 = Map<const MatrixXd>(polar_to_cartesian(magnitudes2, angles2)[0].data(), magnitudes2.size(), 2);
#     MatrixXd result_vectors = vectors1 + vectors2;
#     return cartesian_to_polar(result_vectors);
# }
#
# int main() {
#     srand(time(0)); // Seed for random number generation
#
#     // Example polar vectors for 1000 pairs
#     vector<double> magnitudes_a(1000);
#     vector<double> angles_a(1000);
#     vector<double> magnitudes_b(1000);
#     vector<double> angles_b(1000);
#
#     // Generate random vectors
#     for (int i = 0; i < 1000; ++i) {
#         magnitudes_a[i] = (rand() % 10) + 1;  // Random magnitudes for vector A
#         angles_a[i] = (rand() % 360);         // Random angles for vector A
#         magnitudes_b[i] = (rand() % 10) + 1;  // Random magnitudes for vector B
#         angles_b[i] = (rand() % 360);         // Random angles for vector B
#     }
#
#     clock_t start_time = clock();
#     auto result = add_polar_vectors(magnitudes_a, angles_a, magnitudes_b, angles_b);
#     clock_t end_time = clock();
#     double time_taken = double(end_time - start_time) / CLOCKS_PER_SEC;
#
#     // Print the time taken
#     cout << "Time taken for adding 1000 pairs of vectors: " << time_taken << " seconds" << endl;
#
#     // Print the results
#     for (int i = 0; i < 1000; ++i) {
#         cout << "Pair " << i+1 << ":" << endl;
#         cout << "Vector A: Magnitude=" << magnitudes_a[i] << ", Angle=" << angles_a[i] << " degrees" << endl;
#         cout << "Vector B: Magnitude=" << magnitudes_b[i] << ", Angle=" << angles_b[i] << " degrees" << endl;
#         cout << "Resultant Vector: Magnitude=" << result.first[i] << ", Angle=" << result.second[i] << " degrees" << endl << endl;
#     }
#
#     return 0;
# }
# Out:
# Writing sequential.cpp

# %% [markdown]
# **4] Install the development files for the Eigen C++ template library**

# %%
# !apt-get install libeigen3-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Suggested packages:
#   libeigen3-doc libmpfrc++-dev
# The following NEW packages will be installed:
#   libeigen3-dev
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 1,056 kB of archives.
# After this operation, 9,081 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libeigen3-dev all 3.4.0-2ubuntu2 [1,056 kB]
# Fetched 1,056 kB in 1s (758 kB/s)
# Selecting previously unselected package libeigen3-dev.
# (Reading database ... 123701 files and directories currently installed.)
# Preparing to unpack .../libeigen3-dev_3.4.0-2ubuntu2_all.deb ...
# Unpacking libeigen3-dev (3.4.0-2ubuntu2) ...
# Setting up libeigen3-dev (3.4.0-2ubuntu2) ...

# %% [markdown]
# **5] Compile and Run**

# %%
# !g++ -o sequential sequential.cpp -I/usr/include/eigen3
# !./sequential
# Out:
# Time taken for adding 1000 pairs of vectors: 0.00209 seconds
# Pair 1:
# Vector A: Magnitude=10, Angle=271 degrees
# Vector B: Magnitude=10, Angle=63 degrees
# Resultant Vector: Magnitude=5.12005, Angle=22.9599 degrees
#
# Pair 2:
# Vector A: Magnitude=7, Angle=33 degrees
# Vector B: Magnitude=8, Angle=42 degrees
# Resultant Vector: Magnitude=1.09343, Angle=-174.507 degrees
#
# Pair 3:
# Vector A: Magnitude=6, Angle=73 degrees
# Vector B: Magnitude=2, Angle=290 degrees
# Resultant Vector: Magnitude=5.73783, Angle=-90 degrees
#
# Pair 4:
# Vector A: Magnitude=1, Angle=67 degrees
# Vector B: Magnitude=2, Angle=85 degrees
# Resultant Vector: Magnitude=1.75423, Angle=90 degrees
#
# Pair 5:
# Vector A: Magnitude=2, Angle=93 degrees
# Vector B: Magnitude=9, Angle=221 degrees
# Resultant Vector: Magnitude=11.3547, Angle=131.458 degrees
#
# Pair 6:
# Vector A: Magnitude=7, Angle=155 degrees
# Vector B: Magnitude=9, Angle=128 degrees
# Resultant Vector: Magnitude=3.54298, Angle=-55.7939 degrees
#
# Pair 7:
# Vector A: Magnitude=8, Angle=182 degrees
# Vector B: Magnitude=4, Angle=145 degrees
# Resultant Vector: Magnitude=1.53209, Angle=90 degrees
#
# Pair 8:
# Vector A: Magnitude=7, Angle=196 degrees
# Vector B: Magnitude=3, Angle=8 degrees
# Resultant Vector: Magnitude=1.28558, Angle=90 degrees
#
# Pair 9:
# Vector A: Magnitude=10, Angle=103 degrees
# Vector B: Magnitude=2, Angle=325 degrees
# Resultant Vector: Magnitude=6.1559, Angle=-19.5521 degrees
#
# Pair 10:
# Vector A: Magnitude=7, Angle=51 degrees
# Vector B: Magnitude=1, Angle=153 degrees
# Resultant Vector: Magnitude=4.43616, Angle=-50.6143 degrees
#
# Pair 11:
# Vector A: Magnitude=5, Angle=161 degrees
# Vector B: Magnitude=4, Angle=34 degrees
# Resultant Vector: Magnitude=4, Angle=90 degrees
#
# Pair 12:
# Vector A: Magnitude=2, Angle=44 degrees
# Vector B: Magnitude=10, Angle=314 degrees
# Resultant Vector: Magnitude=6.9282, Angle=-90 degrees
#
# Pair 13:
# Vector A: Magnitude=9, Angle=300 degrees
# Vector B: Magnitude=8, Angle=24 degrees
# Resultant Vector: Magnitude=7.56415, Angle=90 degrees
#
# Pair 14:
# Vector A: Magnitude=8, Angle=125 degrees
# Vector B: Magnitude=6, Angle=24 degrees
# Resultant Vector: Magnitude=inf, Angle=1.42505e-256 degrees
#
# Pair 15:
# Vector A: Magnitude=1, Angle=108 degrees
# Vector B: Magnitude=2, Angle=226 degrees
# Resultant Vector: Magnitude=5.03538, Angle=90 degrees
#
# Pair 16:
# Vector A: Magnitude=8, Angle=153 degrees
# Vector B: Magnitude=7, Angle=156 degrees
# Resultant Vector: Magnitude=4.86261, Angle=-90 degrees
#
# Pair 17:
# Vector A: Magnitude=7, Angle=178 degrees
# Vector B: Magnitude=3, Angle=264 degrees
# Resultant Vector: Magnitude=0.348623, Angle=90 degrees
#
# Pair 18:
# Vector A: Magnitude=2, Angle=2 degrees
# Vector B: Magnitude=9, Angle=225 degrees
# Resultant Vector: Magnitude=3.98478, Angle=-90 degrees
#
# Pair 19:
# Vector A: Magnitude=6, Angle=13 degrees
# Vector B: Magnitude=3, Angle=8 degrees
# Resultant Vector: Magnitude=6.61863, Angle=90 degrees
#
# Pair 20:
# Vector A: Magnitude=9, Angle=123 degrees
# Vector B: Magnitude=6, Angle=68 degrees
# Resultant Vector: Magnitude=2.27898, Angle=-90 degrees
#
# Pair 21:
# Vector A: Magnitude=6, Angle=242 degrees
# Vector B: Magnitude=5, Angle=262 degrees
# Resultant Vector: Magnitude=3.4202, Angle=-90 degrees
#
# Pair 22:
# Vector A: Magnitude=1, Angle=221 degrees
# Vector B: Magnitude=7, Angle=60 degrees
# Resultant Vector: Magnitude=inf, Angle=1.02829e-255 degrees
#
# Pair 23:
# Vector A: Magnitude=1, Angle=327 degrees
# Vector B: Magnitude=9, Angle=19 degrees
# Resultant Vector: Magnitude=4.41474, Angle=-90 degrees
#
# Pair 24:
# Vector A: Magnitude=3, Angle=265 degrees
# Vector B: Magnitude=6, Angle=120 degrees
# Resultant Vector: Magnitude=2.34736, Angle=90 degrees
#
# Pair 25:
# Vector A: Magnitude=6, Angle=169 degrees
# Vector B: Magnitude=8, Angle=288 degrees
# Resultant Vector: Magnitude=0.62932, Angle=90 degrees
#
# Pair 26:
# Vector A: Magnitude=4, Angle=315 degrees
# Vector B: Magnitude=4, Angle=311 degrees
# Resultant Vector: Magnitude=0.777146, Angle=90 degrees
#
# Pair 27:
# Vector A: Magnitude=1, Angle=157 degrees
# Vector B: Magnitude=10, Angle=258 degrees
# Resultant Vector: Magnitude=0.984808, Angle=-90 degrees
#
# Pair 28:
# Vector A: Magnitude=4, Angle=26 degrees
# Vector B: Magnitude=7, Angle=88 degrees
# Resultant Vector: Magnitude=0.173648, Angle=90 degrees
#
# Pair 29:
# Vector A: Magnitude=10, Angle=291 degrees
# Vector B: Magnitude=2, Angle=21 degrees
# Resultant Vector: Magnitude=8.8892, Angle=-90 degrees
#
# Pair 30:
# Vector A: Magnitude=3, Angle=149 degrees
# Vector B: Magnitude=2, Angle=354 degrees
# Resultant Vector: Magnitude=1.40791, Angle=90 degrees
#
# Pair 31:
# Vector A: Magnitude=10, Angle=111 degrees
# Vector B: Magnitude=6, Angle=213 degrees
# Resultant Vector: Magnitude=5.55727, Angle=-90 degrees
#
# Pair 32:
# Vector A: Magnitude=9, Angle=293 degrees
# Vector B: Magnitude=5, Angle=203 degrees
# Resultant Vector: Magnitude=5.75472, Angle=-90 degrees
#
# Pair 33:
# Vector A: Magnitude=3, Angle=231 degrees
# Vector B: Magnitude=2, Angle=18 degrees
# Resultant Vector: Magnitude=5, Angle=90 degrees
#
# Pair 34:
# Vector A: Magnitude=9, Angle=157 degrees
# Vector B: Magnitude=10, Angle=258 degrees
# Resultant Vector: Magnitude=8.66025, Angle=-90 degrees
#
# Pair 35:
# Vector A: Magnitude=7, Angle=160 degrees
# Vector B: Magnitude=10, Angle=211 degrees
# Resultant Vector: Magnitude=0.390731, Angle=3.48168e-320 degrees
#
# Pair 36:
# Vector A: Magnitude=8, Angle=355 degrees
# Vector B: Magnitude=1, Angle=328 degrees
# Resultant Vector: Magnitude=0.920505, Angle=2.03802e-320 degrees
#
# Pair 37:
# Vector A: Magnitude=9, Angle=163 degrees
# Vector B: Magnitude=2, Angle=183 degrees
# Resultant Vector: Magnitude=2.55435, Angle=-90 degrees
#
# Pair 38:
# Vector A: Magnitude=5, Angle=174 degrees
# Vector B: Magnitude=10, Angle=45 degrees
# Resultant Vector: Magnitude=1.94061, Angle=-90 degrees
#
# Pair 39:
# Vector A: Magnitude=6, Angle=295 degrees
# Vector B: Magnitude=10, Angle=174 degrees
# Resultant Vector: Magnitude=0.104672, Angle=180 degrees
#
# Pair 40:
# Vector A: Magnitude=9, Angle=105 degrees
# Vector B: Magnitude=10, Angle=202 degrees
# Resultant Vector: Magnitude=1.99726, Angle=9.34278e-321 degrees
#
# Pair 41:
# Vector A: Magnitude=9, Angle=253 degrees
# Vector B: Magnitude=1, Angle=266 degrees
# Resultant Vector: Magnitude=2.13915, Angle=-90 degrees
#
# Pair 42:
# Vector A: Magnitude=3, Angle=61 degrees
# Vector B: Magnitude=7, Angle=340 degrees
# Resultant Vector: Magnitude=4.7151, Angle=90 degrees
#
# Pair 43:
# Vector A: Magnitude=3, Angle=297 degrees
# Vector B: Magnitude=3, Angle=281 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 44:
# Vector A: Magnitude=6, Angle=132 degrees
# Vector B: Magnitude=2, Angle=323 degrees
# Resultant Vector: Magnitude=inf, Angle=0 degrees
#
# Pair 45:
# Vector A: Magnitude=8, Angle=342 degrees
# Vector B: Magnitude=9, Angle=351 degrees
# Resultant Vector: Magnitude=6.28472, Angle=90 degrees
#
# Pair 46:
# Vector A: Magnitude=7, Angle=300 degrees
# Vector B: Magnitude=10, Angle=313 degrees
# Resultant Vector: Magnitude=8.27376, Angle=90 degrees
#
# Pair 47:
# Vector A: Magnitude=6, Angle=168 degrees
# Vector B: Magnitude=10, Angle=335 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 48:
# Vector A: Magnitude=4, Angle=249 degrees
# Vector B: Magnitude=10, Angle=121 degrees
# Resultant Vector: Magnitude=0, Angle=90 degrees
#
# Pair 49:
# Vector A: Magnitude=5, Angle=270 degrees
# Vector B: Magnitude=10, Angle=168 degrees
# Resultant Vector: Magnitude=9.98478, Angle=-90 degrees
#
# Pair 50:
# Vector A: Magnitude=2, Angle=167 degrees
# Vector B: Magnitude=9, Angle=65 degrees
# Resultant Vector: Magnitude=0.488348, Angle=-90 degrees
#
# Pair 51:
# Vector A: Magnitude=6, Angle=340 degrees
# Vector B: Magnitude=9, Angle=270 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 52:
# Vector A: Magnitude=5, Angle=339 degrees
# Vector B: Magnitude=6, Angle=23 degrees
# Resultant Vector: Magnitude=0, Angle=90 degrees
#
# Pair 53:
# Vector A: Magnitude=4, Angle=356 degrees
# Vector B: Magnitude=8, Angle=221 degrees
# Resultant Vector: Magnitude=9.94377, Angle=90 degrees
#
# Pair 54:
# Vector A: Magnitude=7, Angle=156 degrees
# Vector B: Magnitude=6, Angle=43 degrees
# Resultant Vector: Magnitude=0.176434, Angle=90 degrees
#
# Pair 55:
# Vector A: Magnitude=7, Angle=174 degrees
# Vector B: Magnitude=9, Angle=109 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 56:
# Vector A: Magnitude=6, Angle=299 degrees
# Vector B: Magnitude=3, Angle=181 degrees
# Resultant Vector: Magnitude=0, Angle=90 degrees
#
# Pair 57:
# Vector A: Magnitude=10, Angle=233 degrees
# Vector B: Magnitude=10, Angle=53 degrees
# Resultant Vector: Magnitude=8.15541, Angle=90 degrees
#
# Pair 58:
# Vector A: Magnitude=3, Angle=10 degrees
# Vector B: Magnitude=1, Angle=17 degrees
# Resultant Vector: Magnitude=9.29752, Angle=90 degrees
#
# Pair 59:
# Vector A: Magnitude=3, Angle=209 degrees
# Vector B: Magnitude=10, Angle=79 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 60:
# Vector A: Magnitude=9, Angle=265 degrees
# Vector B: Magnitude=3, Angle=254 degrees
# Resultant Vector: Magnitude=0, Angle=90 degrees
#
# Pair 61:
# Vector A: Magnitude=2, Angle=221 degrees
# Vector B: Magnitude=6, Angle=69 degrees
# Resultant Vector: Magnitude=6.22827, Angle=90 degrees
#
# Pair 62:
# Vector A: Magnitude=8, Angle=290 degrees
# Vector B: Magnitude=3, Angle=213 degrees
# Resultant Vector: Magnitude=6.30667, Angle=-90 degrees
#
# Pair 63:
# Vector A: Magnitude=8, Angle=2 degrees
# Vector B: Magnitude=5, Angle=144 degrees
# Resultant Vector: Magnitude=6.57785, Angle=0 degrees
#
# Pair 64:
# Vector A: Magnitude=2, Angle=168 degrees
# Vector B: Magnitude=9, Angle=23 degrees
# Resultant Vector: Magnitude=2.39414, Angle=180 degrees
#
# Pair 65:
# Vector A: Magnitude=4, Angle=187 degrees
# Vector B: Magnitude=7, Angle=186 degrees
# Resultant Vector: Magnitude=6.90314, Angle=-90 degrees
#
# Pair 66:
# Vector A: Magnitude=10, Angle=66 degrees
# Vector B: Magnitude=4, Angle=292 degrees
# Resultant Vector: Magnitude=5.36559, Angle=-90 degrees
#
# Pair 67:
# Vector A: Magnitude=6, Angle=3 degrees
# Vector B: Magnitude=4, Angle=336 degrees
# Resultant Vector: Magnitude=0.572427, Angle=0 degrees
#
# Pair 68:
# Vector A: Magnitude=1, Angle=217 degrees
# Vector B: Magnitude=1, Angle=273 degrees
# Resultant Vector: Magnitude=2.94488, Angle=180 degrees
#
# Pair 69:
# Vector A: Magnitude=10, Angle=345 degrees
# Vector B: Magnitude=3, Angle=328 degrees
# Resultant Vector: Magnitude=8.51834, Angle=138.139 degrees
#
# Pair 70:
# Vector A: Magnitude=9, Angle=326 degrees
# Vector B: Magnitude=5, Angle=357 degrees
# Resultant Vector: Magnitude=4.75221, Angle=-51.4998 degrees
#
# Pair 71:
# Vector A: Magnitude=9, Angle=120 degrees
# Vector B: Magnitude=4, Angle=141 degrees
# Resultant Vector: Magnitude=1.59727, Angle=0 degrees
#
# Pair 72:
# Vector A: Magnitude=10, Angle=211 degrees
# Vector B: Magnitude=5, Angle=202 degrees
# Resultant Vector: Magnitude=1.20363, Angle=180 degrees
#
# Pair 73:
# Vector A: Magnitude=2, Angle=112 degrees
# Vector B: Magnitude=9, Angle=340 degrees
# Resultant Vector: Magnitude=11.4815, Angle=134.135 degrees
#
# Pair 74:
# Vector A: Magnitude=10, Angle=104 degrees
# Vector B: Magnitude=5, Angle=326 degrees
# Resultant Vector: Magnitude=2.94312, Angle=95.4435 degrees
#
# Pair 75:
# Vector A: Magnitude=10, Angle=27 degrees
# Vector B: Magnitude=5, Angle=351 degrees
# Resultant Vector: Magnitude=8.8892, Angle=0 degrees
#
# Pair 76:
# Vector A: Magnitude=8, Angle=276 degrees
# Vector B: Magnitude=5, Angle=196 degrees
# Resultant Vector: Magnitude=1.40791, Angle=180 degrees
#
# Pair 77:
# Vector A: Magnitude=5, Angle=118 degrees
# Vector B: Magnitude=7, Angle=282 degrees
# Resultant Vector: Magnitude=7.36867, Angle=155.947 degrees
#
# Pair 78:
# Vector A: Magnitude=5, Angle=90 degrees
# Vector B: Magnitude=2, Angle=284 degrees
# Resultant Vector: Magnitude=2.17859, Angle=-152.331 degrees
#
# Pair 79:
# Vector A: Magnitude=4, Angle=164 degrees
# Vector B: Magnitude=6, Angle=12 degrees
# Resultant Vector: Magnitude=6.81998, Angle=0 degrees
#
# Pair 80:
# Vector A: Magnitude=7, Angle=102 degrees
# Vector B: Magnitude=7, Angle=287 degrees
# Resultant Vector: Magnitude=7.31354, Angle=180 degrees
#
# Pair 81:
# Vector A: Magnitude=5, Angle=347 degrees
# Vector B: Magnitude=10, Angle=265 degrees
# Resultant Vector: Magnitude=3.84676, Angle=-125.788 degrees
#
# Pair 82:
# Vector A: Magnitude=4, Angle=284 degrees
# Vector B: Magnitude=3, Angle=174 degrees
# Resultant Vector: Magnitude=10.3618, Angle=19.8899 degrees
#
# Pair 83:
# Vector A: Magnitude=4, Angle=278 degrees
# Vector B: Magnitude=6, Angle=300 degrees
# Resultant Vector: Magnitude=9.06308, Angle=0 degrees
#
# Pair 84:
# Vector A: Magnitude=6, Angle=69 degrees
# Vector B: Magnitude=9, Angle=329 degrees
# Resultant Vector: Magnitude=4.22618, Angle=180 degrees
#
# Pair 85:
# Vector A: Magnitude=10, Angle=45 degrees
# Vector B: Magnitude=4, Angle=15 degrees
# Resultant Vector: Magnitude=3.08452, Angle=-90 degrees
#
# Pair 86:
# Vector A: Magnitude=8, Angle=146 degrees
# Vector B: Magnitude=10, Angle=90 degrees
# Resultant Vector: Magnitude=inf, Angle=-2.25754e-256 degrees
#
# Pair 87:
# Vector A: Magnitude=1, Angle=236 degrees
# Vector B: Magnitude=5, Angle=198 degrees
# Resultant Vector: Magnitude=5.15038, Angle=180 degrees
#
# Pair 88:
# Vector A: Magnitude=9, Angle=293 degrees
# Vector B: Magnitude=6, Angle=65 degrees
# Resultant Vector: Magnitude=8.57167, Angle=2.26282e-321 degrees
#
# Pair 89:
# Vector A: Magnitude=3, Angle=265 degrees
# Vector B: Magnitude=1, Angle=115 degrees
# Resultant Vector: Magnitude=4.33646, Angle=90 degrees
#
# Pair 90:
# Vector A: Magnitude=2, Angle=74 degrees
# Vector B: Magnitude=10, Angle=116 degrees
# Resultant Vector: Magnitude=5.45856, Angle=90 degrees
#
# Pair 91:
# Vector A: Magnitude=4, Angle=94 degrees
# Vector B: Magnitude=8, Angle=60 degrees
# Resultant Vector: Magnitude=9.78148, Angle=180 degrees
#
# Pair 92:
# Vector A: Magnitude=6, Angle=65 degrees
# Vector B: Magnitude=10, Angle=94 degrees
# Resultant Vector: Magnitude=2.07912, Angle=9.05622e-321 degrees
#
# Pair 93:
# Vector A: Magnitude=3, Angle=24 degrees
# Vector B: Magnitude=2, Angle=350 degrees
# Resultant Vector: Magnitude=3.86049, Angle=-90 degrees
#
# Pair 94:
# Vector A: Magnitude=1, Angle=280 degrees
# Vector B: Magnitude=1, Angle=120 degrees
# Resultant Vector: Magnitude=3.29717, Angle=-90 degrees
#
# Pair 95:
# Vector A: Magnitude=9, Angle=287 degrees
# Vector B: Magnitude=10, Angle=239 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 96:
# Vector A: Magnitude=1, Angle=316 degrees
# Vector B: Magnitude=5, Angle=12 degrees
# Resultant Vector: Magnitude=inf, Angle=0 degrees
#
# Pair 97:
# Vector A: Magnitude=4, Angle=274 degrees
# Vector B: Magnitude=10, Angle=154 degrees
# Resultant Vector: Magnitude=1.18382, Angle=90 degrees
#
# Pair 98:
# Vector A: Magnitude=2, Angle=288 degrees
# Vector B: Magnitude=4, Angle=214 degrees
# Resultant Vector: Magnitude=0.953788, Angle=90 degrees
#
# Pair 99:
# Vector A: Magnitude=5, Angle=200 degrees
# Vector B: Magnitude=5, Angle=161 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 100:
# Vector A: Magnitude=8, Angle=175 degrees
# Vector B: Magnitude=8, Angle=120 degrees
# Resultant Vector: Magnitude=0, Angle=90 degrees
#
# Pair 101:
# Vector A: Magnitude=10, Angle=108 degrees
# Vector B: Magnitude=3, Angle=241 degrees
# Resultant Vector: Magnitude=7.62069, Angle=-90 degrees
#
# Pair 102:
# Vector A: Magnitude=1, Angle=62 degrees
# Vector B: Magnitude=2, Angle=288 degrees
# Resultant Vector: Magnitude=6.81292, Angle=-90 degrees
#
# Pair 103:
# Vector A: Magnitude=2, Angle=192 degrees
# Vector B: Magnitude=8, Angle=81 degrees
# Resultant Vector: Magnitude=0, Angle=90 degrees
#
# Pair 104:
# Vector A: Magnitude=2, Angle=343 degrees
# Vector B: Magnitude=6, Angle=114 degrees
# Resultant Vector: Magnitude=0, Angle=90 degrees
#
# Pair 105:
# Vector A: Magnitude=1, Angle=324 degrees
# Vector B: Magnitude=2, Angle=351 degrees
# Resultant Vector: Magnitude=7.39693, Angle=-90 degrees
#
# Pair 106:
# Vector A: Magnitude=5, Angle=284 degrees
# Vector B: Magnitude=8, Angle=18 degrees
# Resultant Vector: Magnitude=6.8843, Angle=90 degrees
#
# Pair 107:
# Vector A: Magnitude=7, Angle=223 degrees
# Vector B: Magnitude=10, Angle=133 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 108:
# Vector A: Magnitude=9, Angle=178 degrees
# Vector B: Magnitude=4, Angle=109 degrees
# Resultant Vector: Magnitude=0, Angle=90 degrees
#
# Pair 109:
# Vector A: Magnitude=7, Angle=107 degrees
# Vector B: Magnitude=1, Angle=186 degrees
# Resultant Vector: Magnitude=0.937941, Angle=-90 degrees
#
# Pair 110:
# Vector A: Magnitude=1, Angle=223 degrees
# Vector B: Magnitude=6, Angle=263 degrees
# Resultant Vector: Magnitude=0.359729, Angle=-90 degrees
#
# Pair 111:
# Vector A: Magnitude=7, Angle=154 degrees
# Vector B: Magnitude=6, Angle=309 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 112:
# Vector A: Magnitude=1, Angle=182 degrees
# Vector B: Magnitude=4, Angle=140 degrees
# Resultant Vector: Magnitude=0, Angle=90 degrees
#
# Pair 113:
# Vector A: Magnitude=8, Angle=76 degrees
# Vector B: Magnitude=4, Angle=143 degrees
# Resultant Vector: Magnitude=7.13276, Angle=90 degrees
#
# Pair 114:
# Vector A: Magnitude=1, Angle=80 degrees
# Vector B: Magnitude=3, Angle=356 degrees
# Resultant Vector: Magnitude=4.96346, Angle=-90 degrees
#
# Pair 115:
# Vector A: Magnitude=4, Angle=213 degrees
# Vector B: Magnitude=3, Angle=213 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 116:
# Vector A: Magnitude=3, Angle=127 degrees
# Vector B: Magnitude=3, Angle=190 degrees
# Resultant Vector: Magnitude=0, Angle=90 degrees
#
# Pair 117:
# Vector A: Magnitude=6, Angle=184 degrees
# Vector B: Magnitude=8, Angle=277 degrees
# Resultant Vector: Magnitude=1.11042, Angle=-90 degrees
#
# Pair 118:
# Vector A: Magnitude=8, Angle=4 degrees
# Vector B: Magnitude=1, Angle=335 degrees
# Resultant Vector: Magnitude=5.89553, Angle=-90 degrees
#
# Pair 119:
# Vector A: Magnitude=9, Angle=37 degrees
# Vector B: Magnitude=5, Angle=168 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 120:
# Vector A: Magnitude=1, Angle=220 degrees
# Vector B: Magnitude=1, Angle=239 degrees
# Resultant Vector: Magnitude=0, Angle=90 degrees
#
# Pair 121:
# Vector A: Magnitude=7, Angle=183 degrees
# Vector B: Magnitude=3, Angle=169 degrees
# Resultant Vector: Magnitude=6.38362, Angle=-90 degrees
#
# Pair 122:
# Vector A: Magnitude=6, Angle=56 degrees
# Vector B: Magnitude=8, Angle=78 degrees
# Resultant Vector: Magnitude=2.80652, Angle=90 degrees
#
# Pair 123:
# Vector A: Magnitude=3, Angle=39 degrees
# Vector B: Magnitude=4, Angle=46 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 124:
# Vector A: Magnitude=10, Angle=357 degrees
# Vector B: Magnitude=7, Angle=274 degrees
# Resultant Vector: Magnitude=0, Angle=90 degrees
#
# Pair 125:
# Vector A: Magnitude=2, Angle=253 degrees
# Vector B: Magnitude=2, Angle=101 degrees
# Resultant Vector: Magnitude=0.869968, Angle=90 degrees
#
# Pair 126:
# Vector A: Magnitude=10, Angle=243 degrees
# Vector B: Magnitude=9, Angle=288 degrees
# Resultant Vector: Magnitude=0.575219, Angle=-90 degrees
#
# Pair 127:
# Vector A: Magnitude=2, Angle=105 degrees
# Vector B: Magnitude=9, Angle=13 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 128:
# Vector A: Magnitude=8, Angle=149 degrees
# Vector B: Magnitude=3, Angle=5 degrees
# Resultant Vector: Magnitude=0, Angle=90 degrees
#
# Pair 129:
# Vector A: Magnitude=5, Angle=274 degrees
# Vector B: Magnitude=5, Angle=340 degrees
# Resultant Vector: Magnitude=5.28574, Angle=-90 degrees
#
# Pair 130:
# Vector A: Magnitude=4, Angle=84 degrees
# Vector B: Magnitude=1, Angle=345 degrees
# Resultant Vector: Magnitude=1.18744, Angle=90 degrees
#
# Pair 131:
# Vector A: Magnitude=6, Angle=94 degrees
# Vector B: Magnitude=2, Angle=34 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 132:
# Vector A: Magnitude=2, Angle=139 degrees
# Vector B: Magnitude=9, Angle=145 degrees
# Resultant Vector: Magnitude=0, Angle=90 degrees
#
# Pair 133:
# Vector A: Magnitude=4, Angle=11 degrees
# Vector B: Magnitude=9, Angle=162 degrees
# Resultant Vector: Magnitude=5.24902, Angle=-90 degrees
#
# Pair 134:
# Vector A: Magnitude=6, Angle=298 degrees
# Vector B: Magnitude=3, Angle=48 degrees
# Resultant Vector: Magnitude=7.16885, Angle=90 degrees
#
# Pair 135:
# Vector A: Magnitude=4, Angle=163 degrees
# Vector B: Magnitude=2, Angle=240 degrees
# Resultant Vector: Magnitude=4.40524, Angle=0 degrees
#
# Pair 136:
# Vector A: Magnitude=5, Angle=313 degrees
# Vector B: Magnitude=7, Angle=28 degrees
# Resultant Vector: Magnitude=5.44002, Angle=3.39917e-321 degrees
#
# Pair 137:
# Vector A: Magnitude=10, Angle=292 degrees
# Vector B: Magnitude=9, Angle=302 degrees
# Resultant Vector: Magnitude=11.5004, Angle=-90 degrees
#
# Pair 138:
# Vector A: Magnitude=7, Angle=299 degrees
# Vector B: Magnitude=10, Angle=244 degrees
# Resultant Vector: Magnitude=3.42479, Angle=-90 degrees
#
# Pair 139:
# Vector A: Magnitude=6, Angle=190 degrees
# Vector B: Magnitude=9, Angle=228 degrees
# Resultant Vector: Magnitude=4.72759, Angle=180 degrees
#
# Pair 140:
# Vector A: Magnitude=1, Angle=99 degrees
# Vector B: Magnitude=6, Angle=235 degrees
# Resultant Vector: Magnitude=1.62784, Angle=1.16056e-320 degrees
#
# Pair 141:
# Vector A: Magnitude=3, Angle=3 degrees
# Vector B: Magnitude=10, Angle=109 degrees
# Resultant Vector: Magnitude=1.72039, Angle=90 degrees
#
# Pair 142:
# Vector A: Magnitude=3, Angle=104 degrees
# Vector B: Magnitude=8, Angle=217 degrees
# Resultant Vector: Magnitude=0.196013, Angle=90 degrees
#
# Pair 143:
# Vector A: Magnitude=8, Angle=90 degrees
# Vector B: Magnitude=1, Angle=323 degrees
# Resultant Vector: Magnitude=1.43868, Angle=0 degrees
#
# Pair 144:
# Vector A: Magnitude=4, Angle=88 degrees
# Vector B: Magnitude=2, Angle=15 degrees
# Resultant Vector: Magnitude=1.38932, Angle=1.35868e-320 degrees
#
# Pair 145:
# Vector A: Magnitude=1, Angle=232 degrees
# Vector B: Magnitude=10, Angle=269 degrees
# Resultant Vector: Magnitude=0.771021, Angle=90 degrees
#
# Pair 146:
# Vector A: Magnitude=4, Angle=349 degrees
# Vector B: Magnitude=6, Angle=308 degrees
# Resultant Vector: Magnitude=4.67139, Angle=90 degrees
#
# Pair 147:
# Vector A: Magnitude=10, Angle=175 degrees
# Vector B: Magnitude=7, Angle=21 degrees
# Resultant Vector: Magnitude=4.5, Angle=0 degrees
#
# Pair 148:
# Vector A: Magnitude=5, Angle=62 degrees
# Vector B: Magnitude=9, Angle=129 degrees
# Resultant Vector: Magnitude=7.79423, Angle=180 degrees
#
# Pair 149:
# Vector A: Magnitude=8, Angle=38 degrees
# Vector B: Magnitude=9, Angle=111 degrees
# Resultant Vector: Magnitude=0.052336, Angle=-90 degrees
#
# Pair 150:
# Vector A: Magnitude=5, Angle=268 degrees
# Vector B: Magnitude=10, Angle=153 degrees
# Resultant Vector: Magnitude=0.99863, Angle=-90 degrees
#
# Pair 151:
# Vector A: Magnitude=9, Angle=171 degrees
# Vector B: Magnitude=7, Angle=274 degrees
# Resultant Vector: Magnitude=4.58861, Angle=180 degrees
#
# Pair 152:
# Vector A: Magnitude=10, Angle=107 degrees
# Vector B: Magnitude=2, Angle=151 degrees
# Resultant Vector: Magnitude=6.55322, Angle=2.831e-321 degrees
#
# Pair 153:
# Vector A: Magnitude=2, Angle=350 degrees
# Vector B: Magnitude=3, Angle=254 degrees
# Resultant Vector: Magnitude=6.01448, Angle=90 degrees
#
# Pair 154:
# Vector A: Magnitude=10, Angle=317 degrees
# Vector B: Magnitude=5, Angle=31 degrees
# Resultant Vector: Magnitude=5.7417, Angle=90 degrees
#
# Pair 155:
# Vector A: Magnitude=4, Angle=251 degrees
# Vector B: Magnitude=5, Angle=279 degrees
# Resultant Vector: Magnitude=0.309017, Angle=180 degrees
#
# Pair 156:
# Vector A: Magnitude=6, Angle=53 degrees
# Vector B: Magnitude=1, Angle=354 degrees
# Resultant Vector: Magnitude=0.951057, Angle=1.95304e-320 degrees
#
# Pair 157:
# Vector A: Magnitude=4, Angle=159 degrees
# Vector B: Magnitude=7, Angle=337 degrees
# Resultant Vector: Magnitude=9.52783, Angle=-90 degrees
#
# Pair 158:
# Vector A: Magnitude=10, Angle=307 degrees
# Vector B: Magnitude=1, Angle=297 degrees
# Resultant Vector: Magnitude=5.33466, Angle=90 degrees
#
# Pair 159:
# Vector A: Magnitude=9, Angle=246 degrees
# Vector B: Magnitude=4, Angle=249 degrees
# Resultant Vector: Magnitude=7.12805, Angle=180 degrees
#
# Pair 160:
# Vector A: Magnitude=6, Angle=244 degrees
# Vector B: Magnitude=3, Angle=77 degrees
# Resultant Vector: Magnitude=3.63192, Angle=5.09382e-321 degrees
#
# Pair 161:
# Vector A: Magnitude=8, Angle=205 degrees
# Vector B: Magnitude=4, Angle=86 degrees
# Resultant Vector: Magnitude=5.5785, Angle=90 degrees
#
# Pair 162:
# Vector A: Magnitude=5, Angle=278 degrees
# Vector B: Magnitude=10, Angle=39 degrees
# Resultant Vector: Magnitude=10.9522, Angle=90 degrees
#
# Pair 163:
# Vector A: Magnitude=2, Angle=274 degrees
# Vector B: Magnitude=2, Angle=226 degrees
# Resultant Vector: Magnitude=6.99574, Angle=180 degrees
#
# Pair 164:
# Vector A: Magnitude=10, Angle=111 degrees
# Vector B: Magnitude=3, Angle=162 degrees
# Resultant Vector: Magnitude=0.244296, Angle=7.6432e-320 degrees
#
# Pair 165:
# Vector A: Magnitude=3, Angle=70 degrees
# Vector B: Magnitude=10, Angle=81 degrees
# Resultant Vector: Magnitude=5.1481, Angle=-90 degrees
#
# Pair 166:
# Vector A: Magnitude=8, Angle=141 degrees
# Vector B: Magnitude=2, Angle=7 degrees
# Resultant Vector: Magnitude=3.33963, Angle=-90 degrees
#
# Pair 167:
# Vector A: Magnitude=10, Angle=334 degrees
# Vector B: Magnitude=9, Angle=124 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 168:
# Vector A: Magnitude=2, Angle=41 degrees
# Vector B: Magnitude=4, Angle=198 degrees
# Resultant Vector: Magnitude=inf, Angle=0 degrees
#
# Pair 169:
# Vector A: Magnitude=9, Angle=277 degrees
# Vector B: Magnitude=7, Angle=24 degrees
# Resultant Vector: Magnitude=14.5141, Angle=-90 degrees
#
# Pair 170:
# Vector A: Magnitude=6, Angle=146 degrees
# Vector B: Magnitude=5, Angle=236 degrees
# Resultant Vector: Magnitude=5.33452, Angle=90 degrees
#
# Pair 171:
# Vector A: Magnitude=3, Angle=127 degrees
# Vector B: Magnitude=5, Angle=131 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 172:
# Vector A: Magnitude=9, Angle=66 degrees
# Vector B: Magnitude=4, Angle=21 degrees
# Resultant Vector: Magnitude=0, Angle=90 degrees
#
# Pair 173:
# Vector A: Magnitude=8, Angle=304 degrees
# Vector B: Magnitude=5, Angle=26 degrees
# Resultant Vector: Magnitude=2.09802, Angle=-90 degrees
#
# Pair 174:
# Vector A: Magnitude=6, Angle=225 degrees
# Vector B: Magnitude=7, Angle=344 degrees
# Resultant Vector: Magnitude=4.0182, Angle=90 degrees
#
# Pair 175:
# Vector A: Magnitude=3, Angle=34 degrees
# Vector B: Magnitude=1, Angle=163 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 176:
# Vector A: Magnitude=8, Angle=54 degrees
# Vector B: Magnitude=2, Angle=65 degrees
# Resultant Vector: Magnitude=0, Angle=90 degrees
#
# Pair 177:
# Vector A: Magnitude=2, Angle=29 degrees
# Vector B: Magnitude=1, Angle=38 degrees
# Resultant Vector: Magnitude=0.64204, Angle=-90 degrees
#
# Pair 178:
# Vector A: Magnitude=6, Angle=26 degrees
# Vector B: Magnitude=5, Angle=339 degrees
# Resultant Vector: Magnitude=5.18372, Angle=90 degrees
#
# Pair 179:
# Vector A: Magnitude=4, Angle=248 degrees
# Vector B: Magnitude=1, Angle=31 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 180:
# Vector A: Magnitude=7, Angle=275 degrees
# Vector B: Magnitude=5, Angle=323 degrees
# Resultant Vector: Magnitude=0, Angle=90 degrees
#
# Pair 181:
# Vector A: Magnitude=10, Angle=259 degrees
# Vector B: Magnitude=3, Angle=176 degrees
# Resultant Vector: Magnitude=1.16216, Angle=-90 degrees
#
# Pair 182:
# Vector A: Magnitude=5, Angle=128 degrees
# Vector B: Magnitude=1, Angle=196 degrees
# Resultant Vector: Magnitude=4.04205, Angle=-90 degrees
#
# Pair 183:
# Vector A: Magnitude=3, Angle=13 degrees
# Vector B: Magnitude=2, Angle=342 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 184:
# Vector A: Magnitude=8, Angle=104 degrees
# Vector B: Magnitude=8, Angle=270 degrees
# Resultant Vector: Magnitude=0, Angle=90 degrees
#
# Pair 185:
# Vector A: Magnitude=5, Angle=9 degrees
# Vector B: Magnitude=9, Angle=181 degrees
# Resultant Vector: Magnitude=3.60869, Angle=90 degrees
#
# Pair 186:
# Vector A: Magnitude=6, Angle=222 degrees
# Vector B: Magnitude=2, Angle=188 degrees
# Resultant Vector: Magnitude=0.126018, Angle=-90 degrees
#
# Pair 187:
# Vector A: Magnitude=3, Angle=271 degrees
# Vector B: Magnitude=3, Angle=168 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 188:
# Vector A: Magnitude=8, Angle=248 degrees
# Vector B: Magnitude=5, Angle=278 degrees
# Resultant Vector: Magnitude=0, Angle=90 degrees
#
# Pair 189:
# Vector A: Magnitude=8, Angle=226 degrees
# Vector B: Magnitude=6, Angle=144 degrees
# Resultant Vector: Magnitude=10.3864, Angle=90 degrees
#
# Pair 190:
# Vector A: Magnitude=5, Angle=127 degrees
# Vector B: Magnitude=3, Angle=28 degrees
# Resultant Vector: Magnitude=5.41149, Angle=90 degrees
#
# Pair 191:
# Vector A: Magnitude=1, Angle=84 degrees
# Vector B: Magnitude=1, Angle=207 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 192:
# Vector A: Magnitude=9, Angle=290 degrees
# Vector B: Magnitude=8, Angle=194 degrees
# Resultant Vector: Magnitude=0, Angle=63.4349 degrees
#
# Pair 193:
# Vector A: Magnitude=10, Angle=297 degrees
# Vector B: Magnitude=7, Angle=335 degrees
# Resultant Vector: Magnitude=1.65621, Angle=-107.571 degrees
#
# Pair 194:
# Vector A: Magnitude=10, Angle=177 degrees
# Vector B: Magnitude=6, Angle=13 degrees
# Resultant Vector: Magnitude=3.77572, Angle=76.7402 degrees
#
# Pair 195:
# Vector A: Magnitude=1, Angle=127 degrees
# Vector B: Magnitude=3, Angle=147 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 196:
# Vector A: Magnitude=9, Angle=186 degrees
# Vector B: Magnitude=9, Angle=35 degrees
# Resultant Vector: Magnitude=0, Angle=63.4349 degrees
#
# Pair 197:
# Vector A: Magnitude=5, Angle=33 degrees
# Vector B: Magnitude=2, Angle=278 degrees
# Resultant Vector: Magnitude=6.34781, Angle=144.229 degrees
#
# Pair 198:
# Vector A: Magnitude=1, Angle=136 degrees
# Vector B: Magnitude=9, Angle=301 degrees
# Resultant Vector: Magnitude=8.74511, Angle=-168.57 degrees
#
# Pair 199:
# Vector A: Magnitude=1, Angle=61 degrees
# Vector B: Magnitude=1, Angle=280 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 200:
# Vector A: Magnitude=2, Angle=10 degrees
# Vector B: Magnitude=8, Angle=290 degrees
# Resultant Vector: Magnitude=0, Angle=63.4349 degrees
#
# Pair 201:
# Vector A: Magnitude=8, Angle=3 degrees
# Vector B: Magnitude=8, Angle=339 degrees
# Resultant Vector: Magnitude=8.39979, Angle=54.3914 degrees
#
# Pair 202:
# Vector A: Magnitude=1, Angle=173 degrees
# Vector B: Magnitude=3, Angle=12 degrees
# Resultant Vector: Magnitude=6.18871, Angle=80.3298 degrees
#
# Pair 203:
# Vector A: Magnitude=3, Angle=174 degrees
# Vector B: Magnitude=3, Angle=60 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 204:
# Vector A: Magnitude=3, Angle=330 degrees
# Vector B: Magnitude=9, Angle=156 degrees
# Resultant Vector: Magnitude=0, Angle=63.4349 degrees
#
# Pair 205:
# Vector A: Magnitude=4, Angle=19 degrees
# Vector B: Magnitude=7, Angle=35 degrees
# Resultant Vector: Magnitude=11.5203, Angle=141.278 degrees
#
# Pair 206:
# Vector A: Magnitude=6, Angle=125 degrees
# Vector B: Magnitude=9, Angle=247 degrees
# Resultant Vector: Magnitude=4.47193, Angle=11.3995 degrees
#
# Pair 207:
# Vector A: Magnitude=7, Angle=229 degrees
# Vector B: Magnitude=1, Angle=49 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 208:
# Vector A: Magnitude=10, Angle=27 degrees
# Vector B: Magnitude=10, Angle=58 degrees
# Resultant Vector: Magnitude=0, Angle=63.4349 degrees
#
# Pair 209:
# Vector A: Magnitude=1, Angle=117 degrees
# Vector B: Magnitude=8, Angle=82 degrees
# Resultant Vector: Magnitude=3.79451, Angle=-150.919 degrees
#
# Pair 210:
# Vector A: Magnitude=3, Angle=30 degrees
# Vector B: Magnitude=5, Angle=334 degrees
# Resultant Vector: Magnitude=2.36987, Angle=-160.706 degrees
#
# Pair 211:
# Vector A: Magnitude=7, Angle=358 degrees
# Vector B: Magnitude=8, Angle=309 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 212:
# Vector A: Magnitude=9, Angle=235 degrees
# Vector B: Magnitude=8, Angle=203 degrees
# Resultant Vector: Magnitude=0, Angle=63.4349 degrees
#
# Pair 213:
# Vector A: Magnitude=7, Angle=284 degrees
# Vector B: Magnitude=10, Angle=154 degrees
# Resultant Vector: Magnitude=8.90984, Angle=122.046 degrees
#
# Pair 214:
# Vector A: Magnitude=10, Angle=87 degrees
# Vector B: Magnitude=2, Angle=107 degrees
# Resultant Vector: Magnitude=6.09569, Angle=-74.5113 degrees
#
# Pair 215:
# Vector A: Magnitude=9, Angle=313 degrees
# Vector B: Magnitude=7, Angle=67 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 216:
# Vector A: Magnitude=1, Angle=7 degrees
# Vector B: Magnitude=7, Angle=242 degrees
# Resultant Vector: Magnitude=0, Angle=63.4349 degrees
#
# Pair 217:
# Vector A: Magnitude=5, Angle=35 degrees
# Vector B: Magnitude=7, Angle=158 degrees
# Resultant Vector: Magnitude=7.37402, Angle=122.85 degrees
#
# Pair 218:
# Vector A: Magnitude=6, Angle=163 degrees
# Vector B: Magnitude=4, Angle=14 degrees
# Resultant Vector: Magnitude=7.32433, Angle=18.9299 degrees
#
# Pair 219:
# Vector A: Magnitude=2, Angle=40 degrees
# Vector B: Magnitude=4, Angle=2 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 220:
# Vector A: Magnitude=8, Angle=300 degrees
# Vector B: Magnitude=6, Angle=273 degrees
# Resultant Vector: Magnitude=0, Angle=63.4349 degrees
#
# Pair 221:
# Vector A: Magnitude=7, Angle=316 degrees
# Vector B: Magnitude=8, Angle=17 degrees
# Resultant Vector: Magnitude=3.34827, Angle=115.746 degrees
#
# Pair 222:
# Vector A: Magnitude=7, Angle=341 degrees
# Vector B: Magnitude=5, Angle=104 degrees
# Resultant Vector: Magnitude=2.67182, Angle=169.127 degrees
#
# Pair 223:
# Vector A: Magnitude=5, Angle=152 degrees
# Vector B: Magnitude=5, Angle=147 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 224:
# Vector A: Magnitude=1, Angle=170 degrees
# Vector B: Magnitude=10, Angle=156 degrees
# Resultant Vector: Magnitude=0, Angle=63.4349 degrees
#
# Pair 225:
# Vector A: Magnitude=8, Angle=226 degrees
# Vector B: Magnitude=6, Angle=143 degrees
# Resultant Vector: Magnitude=2.48928, Angle=75.6244 degrees
#
# Pair 226:
# Vector A: Magnitude=2, Angle=320 degrees
# Vector B: Magnitude=10, Angle=62 degrees
# Resultant Vector: Magnitude=10.6579, Angle=100.281 degrees
#
# Pair 227:
# Vector A: Magnitude=3, Angle=352 degrees
# Vector B: Magnitude=5, Angle=19 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 228:
# Vector A: Magnitude=5, Angle=142 degrees
# Vector B: Magnitude=3, Angle=261 degrees
# Resultant Vector: Magnitude=0, Angle=63.4349 degrees
#
# Pair 229:
# Vector A: Magnitude=9, Angle=232 degrees
# Vector B: Magnitude=1, Angle=14 degrees
# Resultant Vector: Magnitude=14.3163, Angle=84.985 degrees
#
# Pair 230:
# Vector A: Magnitude=4, Angle=275 degrees
# Vector B: Magnitude=10, Angle=19 degrees
# Resultant Vector: Magnitude=9.16003, Angle=30.3894 degrees
#
# Pair 231:
# Vector A: Magnitude=10, Angle=163 degrees
# Vector B: Magnitude=7, Angle=99 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 232:
# Vector A: Magnitude=6, Angle=68 degrees
# Vector B: Magnitude=9, Angle=282 degrees
# Resultant Vector: Magnitude=0, Angle=63.4349 degrees
#
# Pair 233:
# Vector A: Magnitude=7, Angle=315 degrees
# Vector B: Magnitude=8, Angle=67 degrees
# Resultant Vector: Magnitude=2.64457, Angle=157.339 degrees
#
# Pair 234:
# Vector A: Magnitude=6, Angle=326 degrees
# Vector B: Magnitude=10, Angle=147 degrees
# Resultant Vector: Magnitude=6.70969, Angle=-35.2225 degrees
#
# Pair 235:
# Vector A: Magnitude=1, Angle=66 degrees
# Vector B: Magnitude=9, Angle=227 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 236:
# Vector A: Magnitude=9, Angle=202 degrees
# Vector B: Magnitude=1, Angle=306 degrees
# Resultant Vector: Magnitude=0, Angle=63.4349 degrees
#
# Pair 237:
# Vector A: Magnitude=5, Angle=150 degrees
# Vector B: Magnitude=4, Angle=159 degrees
# Resultant Vector: Magnitude=3.53769, Angle=-56.0561 degrees
#
# Pair 238:
# Vector A: Magnitude=6, Angle=312 degrees
# Vector B: Magnitude=2, Angle=237 degrees
# Resultant Vector: Magnitude=3.76321, Angle=94.769 degrees
#
# Pair 239:
# Vector A: Magnitude=8, Angle=89 degrees
# Vector B: Magnitude=7, Angle=192 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 240:
# Vector A: Magnitude=8, Angle=104 degrees
# Vector B: Magnitude=7, Angle=323 degrees
# Resultant Vector: Magnitude=0, Angle=63.4349 degrees
#
# Pair 241:
# Vector A: Magnitude=10, Angle=156 degrees
# Vector B: Magnitude=3, Angle=206 degrees
# Resultant Vector: Magnitude=7.7111, Angle=-9.35902 degrees
#
# Pair 242:
# Vector A: Magnitude=3, Angle=32 degrees
# Vector B: Magnitude=6, Angle=185 degrees
# Resultant Vector: Magnitude=4.65992, Angle=57.96 degrees
#
# Pair 243:
# Vector A: Magnitude=1, Angle=263 degrees
# Vector B: Magnitude=3, Angle=178 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 244:
# Vector A: Magnitude=9, Angle=284 degrees
# Vector B: Magnitude=7, Angle=52 degrees
# Resultant Vector: Magnitude=0, Angle=63.4349 degrees
#
# Pair 245:
# Vector A: Magnitude=5, Angle=189 degrees
# Vector B: Magnitude=5, Angle=12 degrees
# Resultant Vector: Magnitude=6.85532, Angle=174.18 degrees
#
# Pair 246:
# Vector A: Magnitude=4, Angle=135 degrees
# Vector B: Magnitude=10, Angle=0 degrees
# Resultant Vector: Magnitude=7.79362, Angle=-20.2153 degrees
#
# Pair 247:
# Vector A: Magnitude=5, Angle=97 degrees
# Vector B: Magnitude=5, Angle=254 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 248:
# Vector A: Magnitude=3, Angle=51 degrees
# Vector B: Magnitude=10, Angle=133 degrees
# Resultant Vector: Magnitude=0, Angle=63.4349 degrees
#
# Pair 249:
# Vector A: Magnitude=10, Angle=352 degrees
# Vector B: Magnitude=3, Angle=73 degrees
# Resultant Vector: Magnitude=2.58915, Angle=-120.197 degrees
#
# Pair 250:
# Vector A: Magnitude=7, Angle=77 degrees
# Vector B: Magnitude=9, Angle=226 degrees
# Resultant Vector: Magnitude=11.9707, Angle=-71.5822 degrees
#
# Pair 251:
# Vector A: Magnitude=4, Angle=182 degrees
# Vector B: Magnitude=7, Angle=191 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 252:
# Vector A: Magnitude=7, Angle=272 degrees
# Vector B: Magnitude=6, Angle=181 degrees
# Resultant Vector: Magnitude=0, Angle=63.4349 degrees
#
# Pair 253:
# Vector A: Magnitude=5, Angle=71 degrees
# Vector B: Magnitude=4, Angle=347 degrees
# Resultant Vector: Magnitude=2.29652, Angle=-115.662 degrees
#
# Pair 254:
# Vector A: Magnitude=7, Angle=314 degrees
# Vector B: Magnitude=9, Angle=303 degrees
# Resultant Vector: Magnitude=7.02492, Angle=-90.8526 degrees
#
# Pair 255:
# Vector A: Magnitude=2, Angle=284 degrees
# Vector B: Magnitude=10, Angle=125 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 256:
# Vector A: Magnitude=8, Angle=158 degrees
# Vector B: Magnitude=2, Angle=286 degrees
# Resultant Vector: Magnitude=0, Angle=63.4349 degrees
#
# Pair 257:
# Vector A: Magnitude=1, Angle=343 degrees
# Vector B: Magnitude=1, Angle=46 degrees
# Resultant Vector: Magnitude=11.6555, Angle=-93.5968 degrees
#
# Pair 258:
# Vector A: Magnitude=3, Angle=258 degrees
# Vector B: Magnitude=5, Angle=17 degrees
# Resultant Vector: Magnitude=10.5848, Angle=124.237 degrees
#
# Pair 259:
# Vector A: Magnitude=4, Angle=60 degrees
# Vector B: Magnitude=9, Angle=59 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 260:
# Vector A: Magnitude=6, Angle=196 degrees
# Vector B: Magnitude=1, Angle=179 degrees
# Resultant Vector: Magnitude=0, Angle=63.4349 degrees
#
# Pair 261:
# Vector A: Magnitude=8, Angle=305 degrees
# Vector B: Magnitude=9, Angle=346 degrees
# Resultant Vector: Magnitude=5.21891, Angle=-43.6552 degrees
#
# Pair 262:
# Vector A: Magnitude=2, Angle=258 degrees
# Vector B: Magnitude=2, Angle=183 degrees
# Resultant Vector: Magnitude=5.10593, Angle=155.955 degrees
#
# Pair 263:
# Vector A: Magnitude=4, Angle=230 degrees
# Vector B: Magnitude=9, Angle=30 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 264:
# Vector A: Magnitude=9, Angle=311 degrees
# Vector B: Magnitude=8, Angle=51 degrees
# Resultant Vector: Magnitude=0, Angle=45 degrees
#
# Pair 265:
# Vector A: Magnitude=5, Angle=189 degrees
# Vector B: Magnitude=10, Angle=99 degrees
# Resultant Vector: Magnitude=4.46591, Angle=-103.802 degrees
#
# Pair 266:
# Vector A: Magnitude=8, Angle=114 degrees
# Vector B: Magnitude=7, Angle=40 degrees
# Resultant Vector: Magnitude=2.81053, Angle=20.0049 degrees
#
# Pair 267:
# Vector A: Magnitude=7, Angle=197 degrees
# Vector B: Magnitude=3, Angle=251 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 268:
# Vector A: Magnitude=4, Angle=84 degrees
# Vector B: Magnitude=3, Angle=300 degrees
# Resultant Vector: Magnitude=0, Angle=45 degrees
#
# Pair 269:
# Vector A: Magnitude=1, Angle=341 degrees
# Vector B: Magnitude=7, Angle=33 degrees
# Resultant Vector: Magnitude=6.77771, Angle=66.9686 degrees
#
# Pair 270:
# Vector A: Magnitude=2, Angle=87 degrees
# Vector B: Magnitude=7, Angle=294 degrees
# Resultant Vector: Magnitude=8.66978, Angle=-64.3203 degrees
#
# Pair 271:
# Vector A: Magnitude=8, Angle=37 degrees
# Vector B: Magnitude=6, Angle=218 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 272:
# Vector A: Magnitude=9, Angle=154 degrees
# Vector B: Magnitude=10, Angle=155 degrees
# Resultant Vector: Magnitude=0, Angle=45 degrees
#
# Pair 273:
# Vector A: Magnitude=4, Angle=110 degrees
# Vector B: Magnitude=5, Angle=302 degrees
# Resultant Vector: Magnitude=6.94011, Angle=-105.967 degrees
#
# Pair 274:
# Vector A: Magnitude=5, Angle=242 degrees
# Vector B: Magnitude=6, Angle=143 degrees
# Resultant Vector: Magnitude=9.00897, Angle=-35.4515 degrees
#
# Pair 275:
# Vector A: Magnitude=10, Angle=187 degrees
# Vector B: Magnitude=7, Angle=112 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 276:
# Vector A: Magnitude=2, Angle=209 degrees
# Vector B: Magnitude=6, Angle=173 degrees
# Resultant Vector: Magnitude=0, Angle=45 degrees
#
# Pair 277:
# Vector A: Magnitude=3, Angle=211 degrees
# Vector B: Magnitude=8, Angle=173 degrees
# Resultant Vector: Magnitude=5.66891, Angle=-160.172 degrees
#
# Pair 278:
# Vector A: Magnitude=2, Angle=295 degrees
# Vector B: Magnitude=1, Angle=0 degrees
# Resultant Vector: Magnitude=7.14105, Angle=-166.089 degrees
#
# Pair 279:
# Vector A: Magnitude=3, Angle=305 degrees
# Vector B: Magnitude=9, Angle=193 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 280:
# Vector A: Magnitude=2, Angle=359 degrees
# Vector B: Magnitude=9, Angle=314 degrees
# Resultant Vector: Magnitude=0, Angle=45 degrees
#
# Pair 281:
# Vector A: Magnitude=1, Angle=114 degrees
# Vector B: Magnitude=9, Angle=206 degrees
# Resultant Vector: Magnitude=3.83299, Angle=165.395 degrees
#
# Pair 282:
# Vector A: Magnitude=7, Angle=343 degrees
# Vector B: Magnitude=10, Angle=76 degrees
# Resultant Vector: Magnitude=1.62044, Angle=-136.581 degrees
#
# Pair 283:
# Vector A: Magnitude=1, Angle=256 degrees
# Vector B: Magnitude=1, Angle=314 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 284:
# Vector A: Magnitude=8, Angle=345 degrees
# Vector B: Magnitude=8, Angle=271 degrees
# Resultant Vector: Magnitude=0, Angle=45 degrees
#
# Pair 285:
# Vector A: Magnitude=8, Angle=206 degrees
# Vector B: Magnitude=7, Angle=240 degrees
# Resultant Vector: Magnitude=1.84273, Angle=10.1972 degrees
#
# Pair 286:
# Vector A: Magnitude=3, Angle=296 degrees
# Vector B: Magnitude=1, Angle=346 degrees
# Resultant Vector: Magnitude=10.9414, Angle=-140.85 degrees
#
# Pair 287:
# Vector A: Magnitude=4, Angle=99 degrees
# Vector B: Magnitude=10, Angle=84 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 288:
# Vector A: Magnitude=1, Angle=167 degrees
# Vector B: Magnitude=1, Angle=312 degrees
# Resultant Vector: Magnitude=0, Angle=45 degrees
#
# Pair 289:
# Vector A: Magnitude=4, Angle=39 degrees
# Vector B: Magnitude=10, Angle=150 degrees
# Resultant Vector: Magnitude=5.38649, Angle=83.1244 degrees
#
# Pair 290:
# Vector A: Magnitude=5, Angle=20 degrees
# Vector B: Magnitude=7, Angle=65 degrees
# Resultant Vector: Magnitude=3.80518, Angle=153.697 degrees
#
# Pair 291:
# Vector A: Magnitude=9, Angle=286 degrees
# Vector B: Magnitude=2, Angle=357 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 292:
# Vector A: Magnitude=5, Angle=18 degrees
# Vector B: Magnitude=9, Angle=341 degrees
# Resultant Vector: Magnitude=0, Angle=45 degrees
#
# Pair 293:
# Vector A: Magnitude=8, Angle=97 degrees
# Vector B: Magnitude=4, Angle=239 degrees
# Resultant Vector: Magnitude=10.7861, Angle=-178.154 degrees
#
# Pair 294:
# Vector A: Magnitude=4, Angle=333 degrees
# Vector B: Magnitude=8, Angle=19 degrees
# Resultant Vector: Magnitude=6.32075, Angle=-69.7819 degrees
#
# Pair 295:
# Vector A: Magnitude=5, Angle=277 degrees
# Vector B: Magnitude=4, Angle=275 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 296:
# Vector A: Magnitude=7, Angle=246 degrees
# Vector B: Magnitude=10, Angle=110 degrees
# Resultant Vector: Magnitude=0, Angle=45 degrees
#
# Pair 297:
# Vector A: Magnitude=8, Angle=130 degrees
# Vector B: Magnitude=1, Angle=51 degrees
# Resultant Vector: Magnitude=2.46951, Angle=-20.4824 degrees
#
# Pair 298:
# Vector A: Magnitude=2, Angle=358 degrees
# Vector B: Magnitude=9, Angle=171 degrees
# Resultant Vector: Magnitude=5.43597, Angle=-132.688 degrees
#
# Pair 299:
# Vector A: Magnitude=7, Angle=239 degrees
# Vector B: Magnitude=10, Angle=300 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 300:
# Vector A: Magnitude=9, Angle=309 degrees
# Vector B: Magnitude=4, Angle=227 degrees
# Resultant Vector: Magnitude=0, Angle=45 degrees
#
# Pair 301:
# Vector A: Magnitude=7, Angle=246 degrees
# Vector B: Magnitude=7, Angle=80 degrees
# Resultant Vector: Magnitude=10.2554, Angle=-112.143 degrees
#
# Pair 302:
# Vector A: Magnitude=3, Angle=203 degrees
# Vector B: Magnitude=10, Angle=36 degrees
# Resultant Vector: Magnitude=5.7883, Angle=-80.4216 degrees
#
# Pair 303:
# Vector A: Magnitude=3, Angle=74 degrees
# Vector B: Magnitude=4, Angle=181 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 304:
# Vector A: Magnitude=3, Angle=283 degrees
# Vector B: Magnitude=2, Angle=349 degrees
# Resultant Vector: Magnitude=0, Angle=45 degrees
#
# Pair 305:
# Vector A: Magnitude=4, Angle=63 degrees
# Vector B: Magnitude=4, Angle=76 degrees
# Resultant Vector: Magnitude=6.01775, Angle=29.0935 degrees
#
# Pair 306:
# Vector A: Magnitude=4, Angle=261 degrees
# Vector B: Magnitude=9, Angle=321 degrees
# Resultant Vector: Magnitude=11.7201, Angle=-35.1859 degrees
#
# Pair 307:
# Vector A: Magnitude=2, Angle=57 degrees
# Vector B: Magnitude=5, Angle=271 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 308:
# Vector A: Magnitude=9, Angle=159 degrees
# Vector B: Magnitude=9, Angle=285 degrees
# Resultant Vector: Magnitude=0, Angle=45 degrees
#
# Pair 309:
# Vector A: Magnitude=9, Angle=244 degrees
# Vector B: Magnitude=6, Angle=10 degrees
# Resultant Vector: Magnitude=10.3481, Angle=52.0603 degrees
#
# Pair 310:
# Vector A: Magnitude=10, Angle=336 degrees
# Vector B: Magnitude=7, Angle=184 degrees
# Resultant Vector: Magnitude=7.51503, Angle=-149.25 degrees
#
# Pair 311:
# Vector A: Magnitude=3, Angle=230 degrees
# Vector B: Magnitude=6, Angle=115 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 312:
# Vector A: Magnitude=4, Angle=168 degrees
# Vector B: Magnitude=7, Angle=78 degrees
# Resultant Vector: Magnitude=0, Angle=45 degrees
#
# Pair 313:
# Vector A: Magnitude=2, Angle=249 degrees
# Vector B: Magnitude=6, Angle=36 degrees
# Resultant Vector: Magnitude=3.03272, Angle=-133.386 degrees
#
# Pair 314:
# Vector A: Magnitude=2, Angle=275 degrees
# Vector B: Magnitude=8, Angle=292 degrees
# Resultant Vector: Magnitude=5.59976, Angle=-166.188 degrees
#
# Pair 315:
# Vector A: Magnitude=5, Angle=131 degrees
# Vector B: Magnitude=6, Angle=82 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 316:
# Vector A: Magnitude=2, Angle=213 degrees
# Vector B: Magnitude=8, Angle=209 degrees
# Resultant Vector: Magnitude=0, Angle=45 degrees
#
# Pair 317:
# Vector A: Magnitude=10, Angle=244 degrees
# Vector B: Magnitude=10, Angle=160 degrees
# Resultant Vector: Magnitude=6.53793, Angle=-127.337 degrees
#
# Pair 318:
# Vector A: Magnitude=3, Angle=137 degrees
# Vector B: Magnitude=5, Angle=15 degrees
# Resultant Vector: Magnitude=11.3207, Angle=-3.54729 degrees
#
# Pair 319:
# Vector A: Magnitude=10, Angle=349 degrees
# Vector B: Magnitude=3, Angle=32 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 320:
# Vector A: Magnitude=8, Angle=338 degrees
# Vector B: Magnitude=4, Angle=260 degrees
# Resultant Vector: Magnitude=0, Angle=45 degrees
#
# Pair 321:
# Vector A: Magnitude=1, Angle=138 degrees
# Vector B: Magnitude=7, Angle=123 degrees
# Resultant Vector: Magnitude=8.28261, Angle=-40.5044 degrees
#
# Pair 322:
# Vector A: Magnitude=4, Angle=166 degrees
# Vector B: Magnitude=8, Angle=129 degrees
# Resultant Vector: Magnitude=17.7642, Angle=-161.478 degrees
#
# Pair 323:
# Vector A: Magnitude=8, Angle=2 degrees
# Vector B: Magnitude=2, Angle=100 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 324:
# Vector A: Magnitude=6, Angle=219 degrees
# Vector B: Magnitude=2, Angle=184 degrees
# Resultant Vector: Magnitude=0, Angle=45 degrees
#
# Pair 325:
# Vector A: Magnitude=4, Angle=272 degrees
# Vector B: Magnitude=5, Angle=196 degrees
# Resultant Vector: Magnitude=6.97096, Angle=9.19566 degrees
#
# Pair 326:
# Vector A: Magnitude=1, Angle=201 degrees
# Vector B: Magnitude=4, Angle=289 degrees
# Resultant Vector: Magnitude=1.67866, Angle=-100.534 degrees
#
# Pair 327:
# Vector A: Magnitude=3, Angle=85 degrees
# Vector B: Magnitude=5, Angle=92 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 328:
# Vector A: Magnitude=6, Angle=177 degrees
# Vector B: Magnitude=3, Angle=267 degrees
# ...
# Resultant Vector: Magnitude=1.94059, Angle=180 degrees
#
# Pair 895:
# Vector A: Magnitude=2, Angle=28 degrees
# Vector B: Magnitude=1, Angle=305 degrees
# Resultant Vector: Magnitude=7.28295, Angle=89.1776 degrees
#
# Pair 896:
# Vector A: Magnitude=10, Angle=110 degrees
# Vector B: Magnitude=1, Angle=94 degrees
# Resultant Vector: Magnitude=11.8222, Angle=85.1744 degrees
#
# Pair 897:
# Vector A: Magnitude=9, Angle=57 degrees
# Vector B: Magnitude=9, Angle=82 degrees
# Resultant Vector: Magnitude=5.86889, Angle=0 degrees
#
# Pair 898:
# Vector A: Magnitude=2, Angle=301 degrees
# Vector B: Magnitude=1, Angle=169 degrees
# Resultant Vector: Magnitude=1.24747, Angle=1.50048e-320 degrees
#
# Pair 899:
# Vector A: Magnitude=7, Angle=88 degrees
# Vector B: Magnitude=1, Angle=30 degrees
# Resultant Vector: Magnitude=13.497, Angle=76.8168 degrees
#
# Pair 900:
# Vector A: Magnitude=3, Angle=256 degrees
# Vector B: Magnitude=4, Angle=197 degrees
# Resultant Vector: Magnitude=13.6274, Angle=-128.36 degrees
#
# Pair 901:
# Vector A: Magnitude=4, Angle=95 degrees
# Vector B: Magnitude=10, Angle=326 degrees
# Resultant Vector: Magnitude=2.0466, Angle=0 degrees
#
# Pair 902:
# Vector A: Magnitude=3, Angle=232 degrees
# Vector B: Magnitude=1, Angle=195 degrees
# Resultant Vector: Magnitude=6.69413, Angle=180 degrees
#
# Pair 903:
# Vector A: Magnitude=2, Angle=41 degrees
# Vector B: Magnitude=1, Angle=180 degrees
# Resultant Vector: Magnitude=4.65703, Angle=12.8771 degrees
#
# Pair 904:
# Vector A: Magnitude=4, Angle=152 degrees
# Vector B: Magnitude=5, Angle=21 degrees
# Resultant Vector: Magnitude=11.897, Angle=-138.498 degrees
#
# Pair 905:
# Vector A: Magnitude=10, Angle=145 degrees
# Vector B: Magnitude=6, Angle=330 degrees
# Resultant Vector: Magnitude=0.871557, Angle=180 degrees
#
# Pair 906:
# Vector A: Magnitude=7, Angle=267 degrees
# Vector B: Magnitude=2, Angle=62 degrees
# Resultant Vector: Magnitude=9.96195, Angle=180 degrees
#
# Pair 907:
# Vector A: Magnitude=7, Angle=121 degrees
# Vector B: Magnitude=4, Angle=188 degrees
# Resultant Vector: Magnitude=10.3071, Angle=-165.667 degrees
#
# Pair 908:
# Vector A: Magnitude=1, Angle=238 degrees
# Vector B: Magnitude=8, Angle=315 degrees
# Resultant Vector: Magnitude=7.27655, Angle=85.8755 degrees
#
# Pair 909:
# Vector A: Magnitude=4, Angle=207 degrees
# Vector B: Magnitude=2, Angle=47 degrees
# Resultant Vector: Magnitude=2.98357, Angle=180 degrees
#
# Pair 910:
# Vector A: Magnitude=2, Angle=174 degrees
# Vector B: Magnitude=3, Angle=212 degrees
# Resultant Vector: Magnitude=0.313585, Angle=5.9446e-320 degrees
#
# Pair 911:
# Vector A: Magnitude=8, Angle=254 degrees
# Vector B: Magnitude=5, Angle=342 degrees
# Resultant Vector: Magnitude=3.05154, Angle=-101.374 degrees
#
# Pair 912:
# Vector A: Magnitude=9, Angle=51 degrees
# Vector B: Magnitude=6, Angle=127 degrees
# Resultant Vector: Magnitude=9.35079, Angle=-85.1005 degrees
#
# Pair 913:
# Vector A: Magnitude=7, Angle=210 degrees
# Vector B: Magnitude=10, Angle=282 degrees
# Resultant Vector: Magnitude=3, Angle=0 degrees
#
# Pair 914:
# Vector A: Magnitude=9, Angle=340 degrees
# Vector B: Magnitude=6, Angle=346 degrees
# Resultant Vector: Magnitude=5.19615, Angle=180 degrees
#
# Pair 915:
# Vector A: Magnitude=5, Angle=310 degrees
# Vector B: Magnitude=5, Angle=96 degrees
# Resultant Vector: Magnitude=8.98082, Angle=-175.306 degrees
#
# Pair 916:
# Vector A: Magnitude=1, Angle=303 degrees
# Vector B: Magnitude=2, Angle=34 degrees
# Resultant Vector: Magnitude=4.35628, Angle=102.472 degrees
#
# Pair 917:
# Vector A: Magnitude=1, Angle=204 degrees
# Vector B: Magnitude=4, Angle=334 degrees
# Resultant Vector: Magnitude=7.71451, Angle=0 degrees
#
# Pair 918:
# Vector A: Magnitude=9, Angle=68 degrees
# Vector B: Magnitude=7, Angle=337 degrees
# Resultant Vector: Magnitude=4.63534, Angle=180 degrees
#
# Pair 919:
# Vector A: Magnitude=3, Angle=91 degrees
# Vector B: Magnitude=10, Angle=113 degrees
# Resultant Vector: Magnitude=4.70048, Angle=26.8602 degrees
#
# Pair 920:
# Vector A: Magnitude=3, Angle=194 degrees
# Vector B: Magnitude=3, Angle=210 degrees
# Resultant Vector: Magnitude=5.79033, Angle=-61.9462 degrees
#
# Pair 921:
# Vector A: Magnitude=8, Angle=82 degrees
# Vector B: Magnitude=3, Angle=267 degrees
# Resultant Vector: Magnitude=3.8637, Angle=0 degrees
#
# Pair 922:
# Vector A: Magnitude=5, Angle=349 degrees
# Vector B: Magnitude=4, Angle=140 degrees
# Resultant Vector: Magnitude=1.03528, Angle=1.81174e-320 degrees
#
# Pair 923:
# Vector A: Magnitude=2, Angle=299 degrees
# Vector B: Magnitude=7, Angle=232 degrees
# Resultant Vector: Magnitude=7.17767, Angle=-95.7518 degrees
#
# Pair 924:
# Vector A: Magnitude=3, Angle=159 degrees
# Vector B: Magnitude=9, Angle=265 degrees
# Resultant Vector: Magnitude=13.307, Angle=87.0077 degrees
#
# Pair 925:
# Vector A: Magnitude=5, Angle=91 degrees
# Vector B: Magnitude=10, Angle=254 degrees
# Resultant Vector: Magnitude=6.12323e-16, Angle=0 degrees
#
# Pair 926:
# Vector A: Magnitude=2, Angle=65 degrees
# Vector B: Magnitude=3, Angle=226 degrees
# Resultant Vector: Magnitude=10, Angle=1.9812e-321 degrees
#
# Pair 927:
# Vector A: Magnitude=9, Angle=63 degrees
# Vector B: Magnitude=10, Angle=42 degrees
# Resultant Vector: Magnitude=0.841578, Angle=-54.8253 degrees
#
# Pair 928:
# Vector A: Magnitude=1, Angle=91 degrees
# Vector B: Magnitude=3, Angle=47 degrees
# Resultant Vector: Magnitude=2.08572, Angle=65.2073 degrees
#
# Pair 929:
# Vector A: Magnitude=6, Angle=257 degrees
# Vector B: Magnitude=5, Angle=212 degrees
# Resultant Vector: Magnitude=4.75528, Angle=180 degrees
#
# Pair 930:
# Vector A: Magnitude=7, Angle=79 degrees
# Vector B: Magnitude=5, Angle=58 degrees
# Resultant Vector: Magnitude=1.54508, Angle=180 degrees
#
# Pair 931:
# Vector A: Magnitude=9, Angle=333 degrees
# Vector B: Magnitude=3, Angle=260 degrees
# Resultant Vector: Magnitude=2.40099, Angle=-34.8817 degrees
#
# Pair 932:
# Vector A: Magnitude=3, Angle=300 degrees
# Vector B: Magnitude=8, Angle=136 degrees
# Resultant Vector: Magnitude=2.16009, Angle=80.7479 degrees
#
# Pair 933:
# Vector A: Magnitude=4, Angle=276 degrees
# Vector B: Magnitude=2, Angle=295 degrees
# Resultant Vector: Magnitude=2.53571, Angle=0 degrees
#
# Pair 934:
# Vector A: Magnitude=5, Angle=135 degrees
# Vector B: Magnitude=2, Angle=114 degrees
# Resultant Vector: Magnitude=5.43785, Angle=3.39917e-321 degrees
#
# Pair 935:
# Vector A: Magnitude=9, Angle=12 degrees
# Vector B: Magnitude=8, Angle=328 degrees
# Resultant Vector: Magnitude=8.55755, Angle=21.0023 degrees
#
# Pair 936:
# Vector A: Magnitude=4, Angle=281 degrees
# Vector B: Magnitude=8, Angle=21 degrees
# Resultant Vector: Magnitude=7.5785, Angle=86.833 degrees
#
# Pair 937:
# Vector A: Magnitude=1, Angle=73 degrees
# Vector B: Magnitude=4, Angle=297 degrees
# Resultant Vector: Magnitude=0.422618, Angle=180 degrees
#
# Pair 938:
# Vector A: Magnitude=3, Angle=329 degrees
# Vector B: Magnitude=8, Angle=170 degrees
# Resultant Vector: Magnitude=0.906308, Angle=2.06668e-320 degrees
#
# Pair 939:
# Vector A: Magnitude=3, Angle=261 degrees
# Vector B: Magnitude=4, Angle=75 degrees
# Resultant Vector: Magnitude=3.90389, Angle=104.729 degrees
#
# Pair 940:
# Vector A: Magnitude=2, Angle=340 degrees
# Vector B: Magnitude=4, Angle=336 degrees
# Resultant Vector: Magnitude=1.89627, Angle=-86.3152 degrees
#
# Pair 941:
# Vector A: Magnitude=10, Angle=346 degrees
# Vector B: Magnitude=2, Angle=343 degrees
# Resultant Vector: Magnitude=4.38371, Angle=180 degrees
#
# Pair 942:
# Vector A: Magnitude=2, Angle=304 degrees
# Vector B: Magnitude=8, Angle=192 degrees
# Resultant Vector: Magnitude=8.98794, Angle=1.9812e-321 degrees
#
# Pair 943:
# Vector A: Magnitude=7, Angle=126 degrees
# Vector B: Magnitude=1, Angle=292 degrees
# Resultant Vector: Magnitude=3.95408, Angle=138.986 degrees
#
# Pair 944:
# Vector A: Magnitude=1, Angle=280 degrees
# Vector B: Magnitude=4, Angle=330 degrees
# Resultant Vector: Magnitude=5.77038, Angle=-86.8848 degrees
#
# Pair 945:
# Vector A: Magnitude=4, Angle=58 degrees
# Vector B: Magnitude=10, Angle=146 degrees
# Resultant Vector: Magnitude=4, Angle=0 degrees
#
# Pair 946:
# Vector A: Magnitude=8, Angle=238 degrees
# Vector B: Magnitude=9, Angle=202 degrees
# Resultant Vector: Magnitude=6.9282, Angle=2.831e-321 degrees
#
# Pair 947:
# Vector A: Magnitude=10, Angle=3 degrees
# Vector B: Magnitude=8, Angle=340 degrees
# Resultant Vector: Magnitude=3.43646, Angle=40.8843 degrees
#
# Pair 948:
# Vector A: Magnitude=7, Angle=232 degrees
# Vector B: Magnitude=10, Angle=345 degrees
# Resultant Vector: Magnitude=4.87088, Angle=107.936 degrees
#
# Pair 949:
# Vector A: Magnitude=10, Angle=332 degrees
# Vector B: Magnitude=1, Angle=340 degrees
# Resultant Vector: Magnitude=0.697565, Angle=180 degrees
#
# Pair 950:
# Vector A: Magnitude=8, Angle=297 degrees
# Vector B: Magnitude=5, Angle=105 degrees
# Resultant Vector: Magnitude=9.97564, Angle=1.9812e-321 degrees
#
# Pair 951:
# Vector A: Magnitude=7, Angle=205 degrees
# Vector B: Magnitude=10, Angle=88 degrees
# Resultant Vector: Magnitude=10.4506, Angle=-68.7831 degrees
#
# Pair 952:
# Vector A: Magnitude=8, Angle=222 degrees
# Vector B: Magnitude=1, Angle=350 degrees
# Resultant Vector: Magnitude=4.13395, Angle=71.638 degrees
#
# Pair 953:
# Vector A: Magnitude=3, Angle=70 degrees
# Vector B: Magnitude=7, Angle=52 degrees
# Resultant Vector: Magnitude=1.96962, Angle=0 degrees
#
# Pair 954:
# Vector A: Magnitude=9, Angle=197 degrees
# Vector B: Magnitude=5, Angle=88 degrees
# Resultant Vector: Magnitude=0.347296, Angle=180 degrees
#
# Pair 955:
# Vector A: Magnitude=1, Angle=43 degrees
# Vector B: Magnitude=1, Angle=56 degrees
# Resultant Vector: Magnitude=6.15004, Angle=124.027 degrees
#
# Pair 956:
# Vector A: Magnitude=6, Angle=1 degrees
# Vector B: Magnitude=4, Angle=6 degrees
# Resultant Vector: Magnitude=8.4039, Angle=54.2085 degrees
#
# Pair 957:
# Vector A: Magnitude=5, Angle=113 degrees
# Vector B: Magnitude=10, Angle=251 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 958:
# Vector A: Magnitude=4, Angle=263 degrees
# Vector B: Magnitude=9, Angle=91 degrees
# Resultant Vector: Magnitude=0, Angle=38.8298 degrees
#
# Pair 959:
# Vector A: Magnitude=1, Angle=138 degrees
# Vector B: Magnitude=10, Angle=337 degrees
# Resultant Vector: Magnitude=4.6709, Angle=-169.482 degrees
#
# Pair 960:
# Vector A: Magnitude=3, Angle=109 degrees
# Vector B: Magnitude=9, Angle=257 degrees
# Resultant Vector: Magnitude=inf, Angle=1.216e-256 degrees
#
# Pair 961:
# Vector A: Magnitude=2, Angle=336 degrees
# Vector B: Magnitude=10, Angle=232 degrees
# Resultant Vector: Magnitude=0, Angle=0 degrees
#
# Pair 962:
# Vector A: Magnitude=4, Angle=203 degrees
# Vector B: Magnitude=3, Angle=246 degrees
# Resultant Vector: Magnitude=0, Angle=63.4349 degrees
#
# Pair 963:
# Vector A: Magnitude=9, Angle=4 degrees
# Vector B: Magnitude=5, Angle=33 degrees
# Resultant Vector: Magnitude=12.6619, Angle=45.2762 degrees
#
# Pair 964:
# Vector A: Magnitude=7, Angle=88 degrees
# Vector B: Magnitude=1, Angle=340 degrees
# Resultant Vector: Magnitude=4.88903, Angle=-21.7839 degrees
#
# Pair 965:
# Vector A: Magnitude=4, Angle=131 degrees
# Vector B: Magnitude=4, Angle=356 degrees
# Resultant Vector: Magnitude=2.41922, Angle=0 degrees
#
# Pair 966:
# Vector A: Magnitude=5, Angle=331 degrees
# Vector B: Magnitude=10, Angle=15 degrees
# Resultant Vector: Magnitude=9.70296, Angle=1.9812e-321 degrees
#
# Pair 967:
# Vector A: Magnitude=2, Angle=138 degrees
# Vector B: Magnitude=3, Angle=214 degrees
# Resultant Vector: Magnitude=4.57488, Angle=95.6952 degrees
#
# Pair 968:
# Vector A: Magnitude=1, Angle=320 degrees
# Vector B: Magnitude=2, Angle=43 degrees
# Resultant Vector: Magnitude=7.24123, Angle=82.932 degrees
#
# Pair 969:
# Vector A: Magnitude=10, Angle=292 degrees
# Vector B: Magnitude=6, Angle=342 degrees
# Resultant Vector: Magnitude=0.694658, Angle=0 degrees
#
# Pair 970:
# Vector A: Magnitude=8, Angle=107 degrees
# Vector B: Magnitude=1, Angle=125 degrees
# Resultant Vector: Magnitude=0.71934, Angle=180 degrees
#
# Pair 971:
# Vector A: Magnitude=3, Angle=275 degrees
# Vector B: Magnitude=1, Angle=118 degrees
# Resultant Vector: Magnitude=3.76959, Angle=46.4317 degrees
#
# Pair 972:
# Vector A: Magnitude=6, Angle=302 degrees
# Vector B: Magnitude=1, Angle=180 degrees
# Resultant Vector: Magnitude=2.3353, Angle=50.0352 degrees
#
# Pair 973:
# Vector A: Magnitude=4, Angle=73 degrees
# Vector B: Magnitude=10, Angle=108 degrees
# Resultant Vector: Magnitude=0.139619, Angle=0 degrees
#
# Pair 974:
# Vector A: Magnitude=5, Angle=8 degrees
# Vector B: Magnitude=4, Angle=258 degrees
# Resultant Vector: Magnitude=7.99878, Angle=180 degrees
#
# Pair 975:
# Vector A: Magnitude=8, Angle=347 degrees
# Vector B: Magnitude=3, Angle=139 degrees
# Resultant Vector: Magnitude=8.18849, Angle=-31.3133 degrees
#
# Pair 976:
# Vector A: Magnitude=9, Angle=95 degrees
# Vector B: Magnitude=3, Angle=117 degrees
# Resultant Vector: Magnitude=0.835028, Angle=107.011 degrees
#
# Pair 977:
# Vector A: Magnitude=10, Angle=98 degrees
# Vector B: Magnitude=2, Angle=266 degrees
# Resultant Vector: Magnitude=3.5, Angle=180 degrees
#
# Pair 978:
# Vector A: Magnitude=8, Angle=72 degrees
# Vector B: Magnitude=4, Angle=61 degrees
# Resultant Vector: Magnitude=6.06218, Angle=180 degrees
#
# Pair 979:
# Vector A: Magnitude=10, Angle=293 degrees
# Vector B: Magnitude=2, Angle=326 degrees
# Resultant Vector: Magnitude=8.16676, Angle=-129.205 degrees
#
# Pair 980:
# Vector A: Magnitude=9, Angle=21 degrees
# Vector B: Magnitude=7, Angle=53 degrees
# Resultant Vector: Magnitude=8.33634, Angle=152.174 degrees
#
# Pair 981:
# Vector A: Magnitude=5, Angle=195 degrees
# Vector B: Magnitude=2, Angle=11 degrees
# Resultant Vector: Magnitude=0.970296, Angle=0 degrees
#
# Pair 982:
# Vector A: Magnitude=5, Angle=156 degrees
# Vector B: Magnitude=10, Angle=223 degrees
# Resultant Vector: Magnitude=0.241922, Angle=180 degrees
#
# Pair 983:
# Vector A: Magnitude=5, Angle=253 degrees
# Vector B: Magnitude=5, Angle=324 degrees
# Resultant Vector: Magnitude=4.99619, Angle=-70.1871 degrees
#
# Pair 984:
# Vector A: Magnitude=1, Angle=56 degrees
# Vector B: Magnitude=4, Angle=119 degrees
# Resultant Vector: Magnitude=10.4632, Angle=-130.477 degrees
#
# Pair 985:
# Vector A: Magnitude=7, Angle=284 degrees
# Vector B: Magnitude=8, Angle=336 degrees
# Resultant Vector: Magnitude=1.04528, Angle=0 degrees
#
# Pair 986:
# Vector A: Magnitude=9, Angle=160 degrees
# Vector B: Magnitude=8, Angle=319 degrees
# Resultant Vector: Magnitude=9.94522, Angle=1.9812e-321 degrees
#
# Pair 987:
# Vector A: Magnitude=6, Angle=89 degrees
# Vector B: Magnitude=6, Angle=305 degrees
# Resultant Vector: Magnitude=1.04573, Angle=-59.9687 degrees
#
# Pair 988:
# Vector A: Magnitude=1, Angle=304 degrees
# Vector B: Magnitude=10, Angle=77 degrees
# Resultant Vector: Magnitude=14.005, Angle=-44.5162 degrees
#
# Pair 989:
# Vector A: Magnitude=10, Angle=32 degrees
# Vector B: Magnitude=9, Angle=215 degrees
# Resultant Vector: Magnitude=0.669131, Angle=0 degrees
#
# Pair 990:
# Vector A: Magnitude=10, Angle=357 degrees
# Vector B: Magnitude=1, Angle=205 degrees
# Resultant Vector: Magnitude=0.743145, Angle=180 degrees
#
# Pair 991:
# Vector A: Magnitude=3, Angle=184 degrees
# Vector B: Magnitude=10, Angle=342 degrees
# Resultant Vector: Magnitude=6.79627, Angle=-25.4261 degrees
#
# Pair 992:
# Vector A: Magnitude=4, Angle=122 degrees
# Vector B: Magnitude=4, Angle=11 degrees
# Resultant Vector: Magnitude=6.99432, Angle=-160.233 degrees
#
# Pair 993:
# Vector A: Magnitude=9, Angle=230 degrees
# Vector B: Magnitude=8, Angle=19 degrees
# Resultant Vector: Magnitude=8.66025, Angle=180 degrees
#
# Pair 994:
# Vector A: Magnitude=3, Angle=257 degrees
# Vector B: Magnitude=9, Angle=227 degrees
# Resultant Vector: Magnitude=5, Angle=3.68079e-321 degrees
#
# Pair 995:
# Vector A: Magnitude=7, Angle=136 degrees
# Vector B: Magnitude=6, Angle=328 degrees
# Resultant Vector: Magnitude=5.83805, Angle=-80.2114 degrees
#
# Pair 996:
# Vector A: Magnitude=1, Angle=44 degrees
# Vector B: Magnitude=6, Angle=219 degrees
# Resultant Vector: Magnitude=4.06657, Angle=88.2827 degrees
#
# Pair 997:
# Vector A: Magnitude=7, Angle=133 degrees
# Vector B: Magnitude=8, Angle=137 degrees
# Resultant Vector: Magnitude=2.95833, Angle=0 degrees
#
# Pair 998:
# Vector A: Magnitude=3, Angle=257 degrees
# Vector B: Magnitude=5, Angle=124 degrees
# Resultant Vector: Magnitude=6.34415, Angle=2.831e-321 degrees
#
# Pair 999:
# Vector A: Magnitude=3, Angle=255 degrees
# Vector B: Magnitude=9, Angle=195 degrees
# Resultant Vector: Magnitude=4.84319, Angle=32.2558 degrees
#
# Pair 1000:
# Vector A: Magnitude=10, Angle=311 degrees
# Vector B: Magnitude=7, Angle=168 degrees
# Resultant Vector: Magnitude=8.54988, Angle=70.4014 degrees

# %% [markdown]
# **7] Parallel code of vector addition(using cuda)**

# %%
# %%writefile parallel_cuda.cu
# #include <iostream>
# #include <vector>
# #include <cmath>
# #include <chrono>
#
# // CUDA kernel to add polar vectors
# __global__ void add_polar_vectors_kernel(const double* magnitudes_a, const double* angles_a,
#                                          const double* magnitudes_b, const double* angles_b,
#                                          double* result_magnitudes, double* result_angles, int n) {
#     int idx = blockIdx.x * blockDim.x + threadIdx.x;
#     if (idx < n) {
#         // Convert polar vectors to Cartesian vectors
#         double x1 = magnitudes_a[idx] * cos(angles_a[idx] * M_PI / 180.0);
#         double y1 = magnitudes_a[idx] * sin(angles_a[idx] * M_PI / 180.0);
#         double x2 = magnitudes_b[idx] * cos(angles_b[idx] * M_PI / 180.0);
#         double y2 = magnitudes_b[idx] * sin(angles_b[idx] * M_PI / 180.0);
#
#         // Perform vector addition
#         double x_sum = x1 + x2;
#         double y_sum = y1 + y2;
#
#         // Convert the resultant vectors back to polar coordinates
#         result_magnitudes[idx] = sqrt(x_sum * x_sum + y_sum * y_sum);
#         result_angles[idx] = atan2(y_sum, x_sum) * 180.0 / M_PI;
#     }
# }
#
# int main() {
#     // Example polar vectors for 1000 pairs
#     const int n = 1000;
#     std::vector<double> magnitudes_a(n);
#     std::vector<double> angles_a(n);
#     std::vector<double> magnitudes_b(n);
#     std::vector<double> angles_b(n);
#
#     // Generate random vectors
#     for (int i = 0; i < n; ++i) {
#         magnitudes_a[i] = (rand() % 10) + 1;  // Random magnitudes for vector A
#         angles_a[i] = (rand() % 360);         // Random angles for vector A
#         magnitudes_b[i] = (rand() % 10) + 1;  // Random magnitudes for vector B
#         angles_b[i] = (rand() % 360);         // Random angles for vector B
#     }
#
#     // Device arrays
#     double *d_magnitudes_a, *d_angles_a, *d_magnitudes_b, *d_angles_b, *d_result_magnitudes, *d_result_angles;
#     cudaMalloc(&d_magnitudes_a, n * sizeof(double));
#     cudaMalloc(&d_angles_a, n * sizeof(double));
#     cudaMalloc(&d_magnitudes_b, n * sizeof(double));
#     cudaMalloc(&d_angles_b, n * sizeof(double));
#     cudaMalloc(&d_result_magnitudes, n * sizeof(double));
#     cudaMalloc(&d_result_angles, n * sizeof(double));
#
#     // Copy data from host to device
#     cudaMemcpy(d_magnitudes_a, magnitudes_a.data(), n * sizeof(double), cudaMemcpyHostToDevice);
#     cudaMemcpy(d_angles_a, angles_a.data(), n * sizeof(double), cudaMemcpyHostToDevice);
#     cudaMemcpy(d_magnitudes_b, magnitudes_b.data(), n * sizeof(double), cudaMemcpyHostToDevice);
#     cudaMemcpy(d_angles_b, angles_b.data(), n * sizeof(double), cudaMemcpyHostToDevice);
#
#     // Calculate block and grid dimensions
#     int blockSize = 256;
#     int numBlocks = (n + blockSize - 1) / blockSize;
#
#     // Measure time for vector addition
#     auto start_time = std::chrono::steady_clock::now();
#
#     // Call CUDA kernel
#     add_polar_vectors_kernel<<<numBlocks, blockSize>>>(d_magnitudes_a, d_angles_a, d_magnitudes_b, d_angles_b, d_result_magnitudes, d_result_angles, n);
#
#     // Measure time taken
#     auto end_time = std::chrono::steady_clock::now();
#     double time_taken = std::chrono::duration_cast<std::chrono::microseconds>(end_time - start_time).count() / 1e6;
#
#     // Copy result from device to host
#     std::vector<double> result_magnitudes(n);
#     std::vector<double> result_angles(n);
#     cudaMemcpy(result_magnitudes.data(), d_result_magnitudes, n * sizeof(double), cudaMemcpyDeviceToHost);
#     cudaMemcpy(result_angles.data(), d_result_angles, n * sizeof(double), cudaMemcpyDeviceToHost);
#
#     // Print the time taken
#     std::cout << "Time taken for adding 1000 pairs of vectors in parallel: " << time_taken << " seconds" << std::endl;
#
#     // Print the results
#     for (int i = 0; i < n; ++i) {
#         std::cout << "Pair " << i+1 << ":" << std::endl;
#         std::cout << "Vector A: Magnitude=" << magnitudes_a[i] << ", Angle=" << angles_a[i] << " degrees" << std::endl;
#         std::cout << "Vector B: Magnitude=" << magnitudes_b[i] << ", Angle=" << angles_b[i] << " degrees" << std::endl;
#         std::cout << "Resultant Vector: Magnitude=" << result_magnitudes[i] << ", Angle=" << result_angles[i] << " degrees" << std::endl << std::endl;
#     }
#
#     // Free device memory
#     cudaFree(d_magnitudes_a);
#     cudaFree(d_angles_a);
#     cudaFree(d_magnitudes_b);
#     cudaFree(d_angles_b);
#     cudaFree(d_result_magnitudes);
#     cudaFree(d_result_angles);
#
#     return 0;
# }
# Out:
# Overwriting parallel_cuda.cu

# %% [markdown]
# **8] Compile and Run**

# %%
# !nvcc -o parallel_cuda parallel_cuda.cu
# !./parallel_cuda
# Out:
# Time taken for adding 1000 pairs of vectors in parallel: 0.16612 seconds
# Pair 1:
# Vector A: Magnitude=4, Angle=286 degrees
# Vector B: Magnitude=8, Angle=115 degrees
# Resultant Vector: Magnitude=4.09731, Angle=123.785 degrees
#
# Pair 2:
# Vector A: Magnitude=4, Angle=295 degrees
# Vector B: Magnitude=7, Angle=12 degrees
# Resultant Vector: Magnitude=8.80893, Angle=-14.2601 degrees
#
# Pair 3:
# Vector A: Magnitude=10, Angle=181 degrees
# Vector B: Magnitude=3, Angle=67 degrees
# Resultant Vector: Magnitude=9.1976, Angle=163.664 degrees
#
# Pair 4:
# Vector A: Magnitude=1, Angle=259 degrees
# Vector B: Magnitude=4, Angle=166 degrees
# Resultant Vector: Magnitude=4.07202, Angle=-179.804 degrees
#
# Pair 5:
# Vector A: Magnitude=1, Angle=306 degrees
# Vector B: Magnitude=3, Angle=136 degrees
# Resultant Vector: Magnitude=2.02266, Angle=140.925 degrees
#
# Pair 6:
# Vector A: Magnitude=2, Angle=8 degrees
# Vector B: Magnitude=8, Angle=69 degrees
# Resultant Vector: Magnitude=9.13859, Angle=57.9648 degrees
#
# Pair 7:
# Vector A: Magnitude=3, Angle=170 degrees
# Vector B: Magnitude=3, Angle=283 degrees
# Resultant Vector: Magnitude=3.31162, Angle=-133.5 degrees
#
# Pair 8:
# Vector A: Magnitude=8, Angle=55 degrees
# Vector B: Magnitude=10, Angle=162 degrees
# Resultant Vector: Magnitude=10.8268, Angle=117.04 degrees
#
# Pair 9:
# Vector A: Magnitude=3, Angle=138 degrees
# Vector B: Magnitude=10, Angle=327 degrees
# Resultant Vector: Magnitude=7.05257, Angle=-29.1845 degrees
#
# Pair 10:
# Vector A: Magnitude=4, Angle=16 degrees
# Vector B: Magnitude=2, Angle=322 degrees
# Resultant Vector: Magnitude=5.4226, Angle=-1.36076 degrees
#
# Pair 11:
# Vector A: Magnitude=10, Angle=333 degrees
# Vector B: Magnitude=2, Angle=119 degrees
# Resultant Vector: Magnitude=8.41656, Angle=-19.364 degrees
#
# Pair 12:
# Vector A: Magnitude=5, Angle=337 degrees
# Vector B: Magnitude=9, Angle=164 degrees
# Resultant Vector: Magnitude=4.08299, Angle=172.583 degrees
#
# Pair 13:
# Vector A: Magnitude=6, Angle=210 degrees
# Vector B: Magnitude=4, Angle=46 degrees
# Resultant Vector: Magnitude=2.42063, Angle=-177.096 degrees
#
# Pair 14:
# Vector A: Magnitude=2, Angle=260 degrees
# Vector B: Magnitude=7, Angle=153 degrees
# Resultant Vector: Magnitude=6.6943, Angle=169.601 degrees
#
# Pair 15:
# Vector A: Magnitude=3, Angle=50 degrees
# Vector B: Magnitude=7, Angle=121 degrees
# Resultant Vector: Magnitude=8.46604, Angle=101.424 degrees
#
# Pair 16:
# Vector A: Magnitude=6, Angle=45 degrees
# Vector B: Magnitude=5, Angle=87 degrees
# Resultant Vector: Magnitude=10.2756, Angle=64.0014 degrees
#
# Pair 17:
# Vector A: Magnitude=7, Angle=305 degrees
# Vector B: Magnitude=7, Angle=129 degrees
# Resultant Vector: Magnitude=0.488593, Angle=-143 degrees
#
# Pair 18:
# Vector A: Magnitude=4, Angle=137 degrees
# Vector B: Magnitude=5, Angle=135 degrees
# Resultant Vector: Magnitude=8.99865, Angle=135.889 degrees
#
# Pair 19:
# Vector A: Magnitude=3, Angle=225 degrees
# Vector B: Magnitude=5, Angle=87 degrees
# Resultant Vector: Magnitude=3.42135, Angle=122.925 degrees
#
# Pair 20:
# Vector A: Magnitude=5, Angle=284 degrees
# Vector B: Magnitude=4, Angle=230 degrees
# Resultant Vector: Magnitude=8.0319, Angle=-99.7597 degrees
#
# Pair 21:
# Vector A: Magnitude=8, Angle=168 degrees
# Vector B: Magnitude=7, Angle=98 degrees
# Resultant Vector: Magnitude=12.3007, Angle=135.673 degrees
#
# Pair 22:
# Vector A: Magnitude=9, Angle=264 degrees
# Vector B: Magnitude=4, Angle=11 degrees
# Resultant Vector: Magnitude=8.71489, Angle=-69.9644 degrees
#
# Pair 23:
# Vector A: Magnitude=5, Angle=199 degrees
# Vector B: Magnitude=3, Angle=60 degrees
# Resultant Vector: Magnitude=3.37027, Angle=163.269 degrees
#
# Pair 24:
# Vector A: Magnitude=7, Angle=288 degrees
# Vector B: Magnitude=10, Angle=172 degrees
# Resultant Vector: Magnitude=9.36098, Angle=-145.77 degrees
#
# Pair 25:
# Vector A: Magnitude=7, Angle=306 degrees
# Vector B: Magnitude=5, Angle=299 degrees
# Resultant Vector: Magnitude=11.9782, Angle=-56.916 degrees
#
# Pair 26:
# Vector A: Magnitude=6, Angle=10 degrees
# Vector B: Magnitude=5, Angle=298 degrees
# Resultant Vector: Magnitude=8.91858, Angle=-22.2211 degrees
#
# Pair 27:
# Vector A: Magnitude=8, Angle=201 degrees
# Vector B: Magnitude=8, Angle=182 degrees
# Resultant Vector: Magnitude=15.7806, Angle=-168.5 degrees
#
# Pair 28:
# Vector A: Magnitude=8, Angle=252 degrees
# Vector B: Magnitude=3, Angle=236 degrees
# Resultant Vector: Magnitude=10.9152, Angle=-112.345 degrees
#
# Pair 29:
# Vector A: Magnitude=2, Angle=200 degrees
# Vector B: Magnitude=7, Angle=1 degrees
# Resultant Vector: Magnitude=5.15029, Angle=-6.26318 degrees
#
# Pair 30:
# Vector A: Magnitude=6, Angle=329 degrees
# Vector B: Magnitude=5, Angle=59 degrees
# Resultant Vector: Magnitude=7.81025, Angle=8.80557 degrees
#
# Pair 31:
# Vector A: Magnitude=1, Angle=249 degrees
# Vector B: Magnitude=2, Angle=157 degrees
# Resultant Vector: Magnitude=2.20463, Angle=-176.043 degrees
#
# Pair 32:
# Vector A: Magnitude=8, Angle=11 degrees
# Vector B: Magnitude=2, Angle=155 degrees
# Resultant Vector: Magnitude=6.48933, Angle=21.437 degrees
#
# Pair 33:
# Vector A: Magnitude=10, Angle=247 degrees
# Vector B: Magnitude=8, Angle=16 degrees
# Resultant Vector: Magnitude=7.95668, Angle=-61.6132 degrees
#
# Pair 34:
# Vector A: Magnitude=8, Angle=273 degrees
# Vector B: Magnitude=7, Angle=5 degrees
# Resultant Vector: Magnitude=10.4447, Angle=-44.9492 degrees
#
# Pair 35:
# Vector A: Magnitude=7, Angle=83 degrees
# Vector B: Magnitude=10, Angle=344 degrees
# Resultant Vector: Magnitude=11.2738, Angle=21.8258 degrees
#
# Pair 36:
# Vector A: Magnitude=9, Angle=111 degrees
# Vector B: Magnitude=3, Angle=269 degrees
# Resultant Vector: Magnitude=6.31918, Angle=121.244 degrees
#
# Pair 37:
# Vector A: Magnitude=4, Angle=299 degrees
# Vector B: Magnitude=1, Angle=288 degrees
# Resultant Vector: Magnitude=4.98528, Angle=-63.1935 degrees
#
# Pair 38:
# Vector A: Magnitude=9, Angle=155 degrees
# Vector B: Magnitude=1, Angle=309 degrees
# Resultant Vector: Magnitude=8.11306, Angle=158.097 degrees
#
# Pair 39:
# Vector A: Magnitude=7, Angle=83 degrees
# Vector B: Magnitude=9, Angle=325 degrees
# Resultant Vector: Magnitude=8.41704, Angle=12.2481 degrees
#
# Pair 40:
# Vector A: Magnitude=7, Angle=51 degrees
# Vector B: Magnitude=2, Angle=155 degrees
# Resultant Vector: Magnitude=6.79898, Angle=67.5842 degrees
#
# Pair 41:
# Vector A: Magnitude=10, Angle=88 degrees
# Vector B: Magnitude=5, Angle=68 degrees
# Resultant Vector: Magnitude=14.7976, Angle=81.3637 degrees
#
# Pair 42:
# Vector A: Magnitude=2, Angle=230 degrees
# Vector B: Magnitude=4, Angle=220 degrees
# Resultant Vector: Magnitude=5.97971, Angle=-136.67 degrees
#
# Pair 43:
# Vector A: Magnitude=5, Angle=4 degrees
# Vector B: Magnitude=5, Angle=34 degrees
# Resultant Vector: Magnitude=9.65926, Angle=19 degrees
#
# Pair 44:
# Vector A: Magnitude=8, Angle=296 degrees
# Vector B: Magnitude=4, Angle=171 degrees
# Resultant Vector: Magnitude=6.5796, Angle=-93.8675 degrees
#
# Pair 45:
# Vector A: Magnitude=8, Angle=85 degrees
# Vector B: Magnitude=10, Angle=16 degrees
# Resultant Vector: Magnitude=14.8775, Angle=46.1331 degrees
#
# Pair 46:
# Vector A: Magnitude=3, Angle=191 degrees
# Vector B: Magnitude=8, Angle=28 degrees
# Resultant Vector: Magnitude=5.20551, Angle=37.7005 degrees
#
# Pair 47:
# Vector A: Magnitude=6, Angle=47 degrees
# Vector B: Magnitude=5, Angle=241 degrees
# Resultant Vector: Magnitude=1.66801, Angle=0.516067 degrees
#
# Pair 48:
# Vector A: Magnitude=9, Angle=115 degrees
# Vector B: Magnitude=10, Angle=37 degrees
# Resultant Vector: Magnitude=14.7792, Angle=73.5595 degrees
#
# Pair 49:
# Vector A: Magnitude=6, Angle=313 degrees
# Vector B: Magnitude=9, Angle=308 degrees
# Resultant Vector: Magnitude=14.9863, Angle=-50.0003 degrees
#
# Pair 50:
# Vector A: Magnitude=4, Angle=51 degrees
# Vector B: Magnitude=9, Angle=9 degrees
# Resultant Vector: Magnitude=12.2681, Angle=21.6015 degrees
#
# Pair 51:
# Vector A: Magnitude=7, Angle=244 degrees
# Vector B: Magnitude=4, Angle=43 degrees
# Resultant Vector: Magnitude=3.56644, Angle=-92.3009 degrees
#
# Pair 52:
# Vector A: Magnitude=4, Angle=218 degrees
# Vector B: Magnitude=7, Angle=160 degrees
# Resultant Vector: Magnitude=9.73013, Angle=-179.597 degrees
#
# Pair 53:
# Vector A: Magnitude=5, Angle=58 degrees
# Vector B: Magnitude=9, Angle=288 degrees
# Resultant Vector: Magnitude=6.93896, Angle=-38.4965 degrees
#
# Pair 54:
# Vector A: Magnitude=10, Angle=117 degrees
# Vector B: Magnitude=8, Angle=36 degrees
# Resultant Vector: Magnitude=13.7488, Angle=81.921 degrees
#
# Pair 55:
# Vector A: Magnitude=5, Angle=183 degrees
# Vector B: Magnitude=1, Angle=263 degrees
# Resultant Vector: Magnitude=5.26654, Angle=-166.223 degrees
#
# Pair 56:
# Vector A: Magnitude=1, Angle=59 degrees
# Vector B: Magnitude=3, Angle=245 degrees
# Resultant Vector: Magnitude=2.0082, Angle=-112.016 degrees
#
# Pair 57:
# Vector A: Magnitude=5, Angle=150 degrees
# Vector B: Magnitude=6, Angle=299 degrees
# Resultant Vector: Magnitude=3.09354, Angle=-117.35 degrees
#
# Pair 58:
# Vector A: Magnitude=5, Angle=106 degrees
# Vector B: Magnitude=10, Angle=2 degrees
# Resultant Vector: Magnitude=10.0403, Angle=30.8946 degrees
#
# Pair 59:
# Vector A: Magnitude=3, Angle=224 degrees
# Vector B: Magnitude=8, Angle=147 degrees
# Resultant Vector: Magnitude=9.15411, Angle=165.622 degrees
#
# Pair 60:
# Vector A: Magnitude=6, Angle=4 degrees
# Vector B: Magnitude=9, Angle=131 degrees
# Resultant Vector: Magnitude=7.21138, Angle=89.3576 degrees
#
# Pair 61:
# Vector A: Magnitude=3, Angle=228 degrees
# Vector B: Magnitude=10, Angle=183 degrees
# Resultant Vector: Magnitude=12.3055, Angle=-167.073 degrees
#
# Pair 62:
# Vector A: Magnitude=7, Angle=248 degrees
# Vector B: Magnitude=1, Angle=22 degrees
# Resultant Vector: Magnitude=6.34624, Angle=-105.492 degrees
#
# Pair 63:
# Vector A: Magnitude=2, Angle=10 degrees
# Vector B: Magnitude=6, Angle=241 degrees
# Resultant Vector: Magnitude=4.98962, Angle=-100.85 degrees
#
# Pair 64:
# Vector A: Magnitude=2, Angle=330 degrees
# Vector B: Magnitude=9, Angle=185 degrees
# Resultant Vector: Magnitude=7.45054, Angle=-166.143 degrees
#
# Pair 65:
# Vector A: Magnitude=1, Angle=296 degrees
# Vector B: Magnitude=5, Angle=66 degrees
# Resultant Vector: Magnitude=4.42404, Angle=56.0287 degrees
#
# Pair 66:
# Vector A: Magnitude=3, Angle=305 degrees
# Vector B: Magnitude=9, Angle=136 degrees
# Resultant Vector: Magnitude=6.08212, Angle=141.4 degrees
#
# Pair 67:
# Vector A: Magnitude=3, Angle=218 degrees
# Vector B: Magnitude=5, Angle=357 degrees
# Resultant Vector: Magnitude=3.37027, Angle=-38.7311 degrees
#
# Pair 68:
# Vector A: Magnitude=3, Angle=104 degrees
# Vector B: Magnitude=1, Angle=156 degrees
# Resultant Vector: Magnitude=3.70054, Angle=116.295 degrees
#
# Pair 69:
# Vector A: Magnitude=3, Angle=59 degrees
# Vector B: Magnitude=10, Angle=190 degrees
# Resultant Vector: Magnitude=8.34485, Angle=174.257 degrees
#
# Pair 70:
# Vector A: Magnitude=9, Angle=71 degrees
# Vector B: Magnitude=4, Angle=251 degrees
# Resultant Vector: Magnitude=5, Angle=71 degrees
#
# Pair 71:
# Vector A: Magnitude=2, Angle=10 degrees
# Vector B: Magnitude=4, Angle=254 degrees
# Resultant Vector: Magnitude=3.60362, Angle=-76.0775 degrees
#
# Pair 72:
# Vector A: Magnitude=1, Angle=3 degrees
# Vector B: Magnitude=10, Angle=101 degrees
# Resultant Vector: Magnitude=9.91043, Angle=95.2653 degrees
#
# Pair 73:
# Vector A: Magnitude=10, Angle=76 degrees
# Vector B: Magnitude=10, Angle=213 degrees
# Resultant Vector: Magnitude=7.33002, Angle=144.5 degrees
#
# Pair 74:
# Vector A: Magnitude=4, Angle=108 degrees
# Vector B: Magnitude=1, Angle=295 degrees
# Resultant Vector: Magnitude=3.00992, Angle=105.68 degrees
#
# Pair 75:
# Vector A: Magnitude=7, Angle=146 degrees
# Vector B: Magnitude=5, Angle=60 degrees
# Resultant Vector: Magnitude=8.88161, Angle=111.834 degrees
#
# Pair 76:
# Vector A: Magnitude=1, Angle=164 degrees
# Vector B: Magnitude=7, Angle=222 degrees
# Resultant Vector: Magnitude=7.57752, Angle=-144.426 degrees
#
# Pair 77:
# Vector A: Magnitude=7, Angle=67 degrees
# Vector B: Magnitude=6, Angle=276 degrees
# Resultant Vector: Magnitude=3.39587, Angle=8.06456 degrees
#
# Pair 78:
# Vector A: Magnitude=10, Angle=138 degrees
# Vector B: Magnitude=8, Angle=92 degrees
# Resultant Vector: Magnitude=16.5875, Angle=117.7 degrees
#
# Pair 79:
# Vector A: Magnitude=9, Angle=172 degrees
# Vector B: Magnitude=10, Angle=129 degrees
# Resultant Vector: Magnitude=17.6817, Angle=149.312 degrees
#
# Pair 80:
# Vector A: Magnitude=7, Angle=170 degrees
# Vector B: Magnitude=3, Angle=347 degrees
# Resultant Vector: Magnitude=4.00719, Angle=172.246 degrees
#
# Pair 81:
# Vector A: Magnitude=7, Angle=141 degrees
# Vector B: Magnitude=4, Angle=12 degrees
# Resultant Vector: Magnitude=5.45509, Angle=106.26 degrees
#
# Pair 82:
# Vector A: Magnitude=2, Angle=295 degrees
# Vector B: Magnitude=10, Angle=319 degrees
# Resultant Vector: Magnitude=11.855, Angle=-44.9346 degrees
#
# Pair 83:
# Vector A: Magnitude=2, Angle=344 degrees
# Vector B: Magnitude=10, Angle=331 degrees
# Resultant Vector: Magnitude=11.9572, Angle=-26.8437 degrees
#
# Pair 84:
# Vector A: Magnitude=1, Angle=107 degrees
# Vector B: Magnitude=6, Angle=348 degrees
# Resultant Vector: Magnitude=5.58411, Angle=-2.98886 degrees
#
# Pair 85:
# Vector A: Magnitude=8, Angle=350 degrees
# Vector B: Magnitude=5, Angle=58 degrees
# Resultant Vector: Magnitude=10.9073, Angle=15.1526 degrees
#
# Pair 86:
# Vector A: Magnitude=1, Angle=304 degrees
# Vector B: Magnitude=3, Angle=149 degrees
# Resultant Vector: Magnitude=2.13592, Angle=160.412 degrees
#
# Pair 87:
# Vector A: Magnitude=7, Angle=241 degrees
# Vector B: Magnitude=1, Angle=164 degrees
# Resultant Vector: Magnitude=7.29036, Angle=-126.681 degrees
#
# Pair 88:
# Vector A: Magnitude=3, Angle=252 degrees
# Vector B: Magnitude=3, Angle=170 degrees
# Resultant Vector: Magnitude=4.52826, Angle=-149 degrees
#
# Pair 89:
# Vector A: Magnitude=6, Angle=225 degrees
# Vector B: Magnitude=3, Angle=259 degrees
# Resultant Vector: Magnitude=8.65132, Angle=-123.819 degrees
#
# Pair 90:
# Vector A: Magnitude=1, Angle=2 degrees
# Vector B: Magnitude=9, Angle=113 degrees
# Resultant Vector: Magnitude=8.69191, Angle=106.834 degrees
#
# Pair 91:
# Vector A: Magnitude=9, Angle=110 degrees
# Vector B: Magnitude=5, Angle=110 degrees
# Resultant Vector: Magnitude=14, Angle=110 degrees
#
# Pair 92:
# Vector A: Magnitude=10, Angle=21 degrees
# Vector B: Magnitude=10, Angle=136 degrees
# Resultant Vector: Magnitude=10.746, Angle=78.5 degrees
#
# Pair 93:
# Vector A: Magnitude=3, Angle=235 degrees
# Vector B: Magnitude=5, Angle=244 degrees
# Resultant Vector: Magnitude=7.97688, Angle=-119.373 degrees
#
# Pair 94:
# Vector A: Magnitude=10, Angle=89 degrees
# Vector B: Magnitude=4, Angle=296 degrees
# Resultant Vector: Magnitude=6.68726, Angle=73.2432 degrees
#
# Pair 95:
# Vector A: Magnitude=1, Angle=55 degrees
# Vector B: Magnitude=1, Angle=22 degrees
# Resultant Vector: Magnitude=1.91764, Angle=38.5 degrees
#
# Pair 96:
# Vector A: Magnitude=10, Angle=124 degrees
# Vector B: Magnitude=4, Angle=85 degrees
# Resultant Vector: Magnitude=13.3481, Angle=113.13 degrees
#
# Pair 97:
# Vector A: Magnitude=2, Angle=247 degrees
# Vector B: Magnitude=5, Angle=253 degrees
# Resultant Vector: Magnitude=6.99217, Angle=-108.713 degrees
#
# Pair 98:
# Vector A: Magnitude=2, Angle=74 degrees
# Vector B: Magnitude=7, Angle=339 degrees
# Resultant Vector: Magnitude=7.11053, Angle=-4.7277 degrees
#
# Pair 99:
# Vector A: Magnitude=5, Angle=322 degrees
# Vector B: Magnitude=3, Angle=146 degrees
# Resultant Vector: Magnitude=2.01819, Angle=-43.9518 degrees
#
# Pair 100:
# Vector A: Magnitude=5, Angle=61 degrees
# Vector B: Magnitude=3, Angle=228 degrees
# Resultant Vector: Magnitude=2.18378, Angle=79.0008 degrees
#
# Pair 101:
# Vector A: Magnitude=9, Angle=349 degrees
# Vector B: Magnitude=3, Angle=348 degrees
# Resultant Vector: Magnitude=11.9997, Angle=-11.25 degrees
#
# Pair 102:
# Vector A: Magnitude=9, Angle=18 degrees
# Vector B: Magnitude=7, Angle=48 degrees
# Resultant Vector: Magnitude=15.4635, Angle=31.0817 degrees
#
# Pair 103:
# Vector A: Magnitude=4, Angle=128 degrees
# Vector B: Magnitude=4, Angle=253 degrees
# Resultant Vector: Magnitude=3.69399, Angle=-169.5 degrees
#
# Pair 104:
# Vector A: Magnitude=4, Angle=8 degrees
# Vector B: Magnitude=1, Angle=114 degrees
# Resultant Vector: Magnitude=3.84641, Angle=22.4723 degrees
#
# Pair 105:
# Vector A: Magnitude=8, Angle=66 degrees
# Vector B: Magnitude=9, Angle=249 degrees
# Resultant Vector: Magnitude=1.09423, Angle=-88.5033 degrees
#
# Pair 106:
# Vector A: Magnitude=1, Angle=246 degrees
# Vector B: Magnitude=9, Angle=197 degrees
# Resultant Vector: Magnitude=9.68551, Angle=-158.531 degrees
#
# Pair 107:
# Vector A: Magnitude=10, Angle=190 degrees
# Vector B: Magnitude=4, Angle=193 degrees
# Resultant Vector: Magnitude=13.9961, Angle=-169.143 degrees
#
# Pair 108:
# Vector A: Magnitude=4, Angle=137 degrees
# Vector B: Magnitude=4, Angle=292 degrees
# Resultant Vector: Magnitude=1.73152, Angle=-145.5 degrees
#
# Pair 109:
# Vector A: Magnitude=7, Angle=45 degrees
# Vector B: Magnitude=3, Angle=76 degrees
# Resultant Vector: Magnitude=9.69541, Angle=54.1701 degrees
#
# Pair 110:
# Vector A: Magnitude=6, Angle=308 degrees
# Vector B: Magnitude=8, Angle=9 degrees
# Resultant Vector: Magnitude=12.1054, Angle=-16.6899 degrees
#
# Pair 111:
# Vector A: Magnitude=7, Angle=300 degrees
# Vector B: Magnitude=5, Angle=201 degrees
# Resultant Vector: Magnitude=7.94038, Angle=-98.458 degrees
#
# Pair 112:
# Vector A: Magnitude=1, Angle=344 degrees
# Vector B: Magnitude=9, Angle=307 degrees
# Resultant Vector: Magnitude=9.8171, Angle=-49.4854 degrees
#
# Pair 113:
# Vector A: Magnitude=1, Angle=68 degrees
# Vector B: Magnitude=7, Angle=62 degrees
# Resultant Vector: Magnitude=7.99521, Angle=62.7491 degrees
#
# Pair 114:
# Vector A: Magnitude=5, Angle=297 degrees
# Vector B: Magnitude=10, Angle=163 degrees
# Resultant Vector: Magnitude=7.45212, Angle=-168.142 degrees
#
# Pair 115:
# Vector A: Magnitude=10, Angle=242 degrees
# Vector B: Magnitude=9, Angle=123 degrees
# Resultant Vector: Magnitude=9.68165, Angle=-172.394 degrees
#
# Pair 116:
# Vector A: Magnitude=1, Angle=161 degrees
# Vector B: Magnitude=8, Angle=18 degrees
# Resultant Vector: Magnitude=7.22647, Angle=22.7771 degrees
#
# Pair 117:
# Vector A: Magnitude=10, Angle=311 degrees
# Vector B: Magnitude=6, Angle=14 degrees
# Resultant Vector: Magnitude=13.8014, Angle=-26.21 degrees
#
# Pair 118:
# Vector A: Magnitude=10, Angle=92 degrees
# Vector B: Magnitude=6, Angle=207 degrees
# Resultant Vector: Magnitude=9.23503, Angle=128.074 degrees
#
# Pair 119:
# Vector A: Magnitude=5, Angle=29 degrees
# Vector B: Magnitude=10, Angle=84 degrees
# Resultant Vector: Magnitude=13.504, Angle=66.3441 degrees
#
# Pair 120:
# Vector A: Magnitude=6, Angle=109 degrees
# Vector B: Magnitude=4, Angle=295 degrees
# Resultant Vector: Magnitude=2.06469, Angle=97.3164 degrees
#
# Pair 121:
# Vector A: Magnitude=8, Angle=100 degrees
# Vector B: Magnitude=9, Angle=131 degrees
# Resultant Vector: Magnitude=16.3839, Angle=116.435 degrees
#
# Pair 122:
# Vector A: Magnitude=10, Angle=129 degrees
# Vector B: Magnitude=8, Angle=268 degrees
# Resultant Vector: Magnitude=6.5762, Angle=-178.051 degrees
#
# Pair 123:
# Vector A: Magnitude=3, Angle=35 degrees
# Vector B: Magnitude=4, Angle=264 degrees
# Resultant Vector: Magnitude=3.04213, Angle=-47.9047 degrees
#
# Pair 124:
# Vector A: Magnitude=10, Angle=190 degrees
# Vector B: Magnitude=3, Angle=20 degrees
# Resultant Vector: Magnitude=7.06481, Angle=-174.229 degrees
#
# Pair 125:
# Vector A: Magnitude=2, Angle=249 degrees
# Vector B: Magnitude=7, Angle=272 degrees
# Resultant Vector: Magnitude=8.87548, Angle=-93.0513 degrees
#
# Pair 126:
# Vector A: Magnitude=2, Angle=162 degrees
# Vector B: Magnitude=1, Angle=117 degrees
# Resultant Vector: Magnitude=2.79793, Angle=147.361 degrees
#
# Pair 127:
# Vector A: Magnitude=4, Angle=41 degrees
# Vector B: Magnitude=2, Angle=309 degrees
# Resultant Vector: Magnitude=4.40926, Angle=14.0435 degrees
#
# Pair 128:
# Vector A: Magnitude=1, Angle=105 degrees
# Vector B: Magnitude=7, Angle=327 degrees
# Resultant Vector: Magnitude=6.29253, Angle=-26.8958 degrees
#
# Pair 129:
# Vector A: Magnitude=8, Angle=114 degrees
# Vector B: Magnitude=1, Angle=346 degrees
# Resultant Vector: Magnitude=7.42627, Angle=107.909 degrees
#
# Pair 130:
# Vector A: Magnitude=5, Angle=137 degrees
# Vector B: Magnitude=5, Angle=128 degrees
# Resultant Vector: Magnitude=9.96917, Angle=132.5 degrees
#
# Pair 131:
# Vector A: Magnitude=6, Angle=158 degrees
# Vector B: Magnitude=3, Angle=346 degrees
# Resultant Vector: Magnitude=3.05783, Angle=150.152 degrees
#
# Pair 132:
# Vector A: Magnitude=1, Angle=186 degrees
# Vector B: Magnitude=7, Angle=234 degrees
# Resultant Vector: Magnitude=7.70505, Angle=-131.535 degrees
#
# Pair 133:
# Vector A: Magnitude=7, Angle=272 degrees
# Vector B: Magnitude=9, Angle=289 degrees
# Resultant Vector: Magnitude=15.827, Angle=-78.4298 degrees
#
# Pair 134:
# Vector A: Magnitude=7, Angle=10 degrees
# Vector B: Magnitude=8, Angle=10 degrees
# Resultant Vector: Magnitude=15, Angle=10 degrees
#
# Pair 135:
# Vector A: Magnitude=2, Angle=120 degrees
# Vector B: Magnitude=2, Angle=73 degrees
# Resultant Vector: Magnitude=3.66824, Angle=96.5 degrees
#
# Pair 136:
# Vector A: Magnitude=8, Angle=307 degrees
# Vector B: Magnitude=3, Angle=46 degrees
# Resultant Vector: Magnitude=8.09266, Angle=-31.5221 degrees
#
# Pair 137:
# Vector A: Magnitude=5, Angle=115 degrees
# Vector B: Magnitude=3, Angle=50 degrees
# Resultant Vector: Magnitude=6.83217, Angle=91.5494 degrees
#
# Pair 138:
# Vector A: Magnitude=3, Angle=159 degrees
# Vector B: Magnitude=1, Angle=169 degrees
# Resultant Vector: Magnitude=3.98859, Angle=161.495 degrees
#
# Pair 139:
# Vector A: Magnitude=10, Angle=314 degrees
# Vector B: Magnitude=6, Angle=281 degrees
# Resultant Vector: Magnitude=15.3831, Angle=-58.2648 degrees
#
# Pair 140:
# Vector A: Magnitude=1, Angle=33 degrees
# Vector B: Magnitude=8, Angle=88 degrees
# Resultant Vector: Magnitude=8.61262, Angle=82.5423 degrees
#
# Pair 141:
# Vector A: Magnitude=9, Angle=46 degrees
# Vector B: Magnitude=1, Angle=124 degrees
# Resultant Vector: Magnitude=9.25972, Angle=52.0637 degrees
#
# Pair 142:
# Vector A: Magnitude=7, Angle=297 degrees
# Vector B: Magnitude=7, Angle=340 degrees
# Resultant Vector: Magnitude=13.0258, Angle=-41.5 degrees
#
# Pair 143:
# Vector A: Magnitude=10, Angle=197 degrees
# Vector B: Magnitude=6, Angle=259 degrees
# Resultant Vector: Magnitude=13.8685, Angle=-140.543 degrees
#
# Pair 144:
# Vector A: Magnitude=8, Angle=198 degrees
# Vector B: Magnitude=6, Angle=183 degrees
# Resultant Vector: Magnitude=13.8827, Angle=-168.423 degrees
#
# Pair 145:
# Vector A: Magnitude=4, Angle=338 degrees
# Vector B: Magnitude=4, Angle=77 degrees
# Resultant Vector: Magnitude=5.19558, Angle=27.5 degrees
#
# Pair 146:
# Vector A: Magnitude=10, Angle=283 degrees
# Vector B: Magnitude=8, Angle=198 degrees
# Resultant Vector: Magnitude=13.3396, Angle=-113.686 degrees
#
# Pair 147:
# Vector A: Magnitude=8, Angle=274 degrees
# Vector B: Magnitude=2, Angle=249 degrees
# Resultant Vector: Magnitude=9.84895, Angle=-90.9232 degrees
#
# Pair 148:
# Vector A: Magnitude=1, Angle=19 degrees
# Vector B: Magnitude=9, Angle=358 degrees
# Resultant Vector: Magnitude=9.94004, Angle=0.0661302 degrees
#
# Pair 149:
# Vector A: Magnitude=6, Angle=228 degrees
# Vector B: Magnitude=5, Angle=353 degrees
# Resultant Vector: Magnitude=5.1561, Angle=-79.4059 degrees
#
# Pair 150:
# Vector A: Magnitude=8, Angle=1 degrees
# Vector B: Magnitude=4, Angle=198 degrees
# Resultant Vector: Magnitude=4.33549, Angle=-14.6492 degrees
#
# Pair 151:
# Vector A: Magnitude=1, Angle=259 degrees
# Vector B: Magnitude=8, Angle=319 degrees
# Resultant Vector: Magnitude=8.544, Angle=-46.8175 degrees
#
# Pair 152:
# Vector A: Magnitude=10, Angle=43 degrees
# Vector B: Magnitude=3, Angle=154 degrees
# Resultant Vector: Magnitude=9.35403, Angle=60.4225 degrees
#
# Pair 153:
# Vector A: Magnitude=4, Angle=247 degrees
# Vector B: Magnitude=2, Angle=262 degrees
# Resultant Vector: Magnitude=5.95439, Angle=-108.013 degrees
#
# Pair 154:
# Vector A: Magnitude=3, Angle=350 degrees
# Vector B: Magnitude=3, Angle=151 degrees
# Resultant Vector: Magnitude=0.990286, Angle=70.5 degrees
#
# Pair 155:
# Vector A: Magnitude=8, Angle=195 degrees
# Vector B: Magnitude=2, Angle=317 degrees
# Resultant Vector: Magnitude=7.14441, Angle=-151.267 degrees
#
# Pair 156:
# Vector A: Magnitude=5, Angle=251 degrees
# Vector B: Magnitude=8, Angle=151 degrees
# Resultant Vector: Magnitude=8.6665, Angle=-174.377 degrees
#
# Pair 157:
# Vector A: Magnitude=2, Angle=181 degrees
# Vector B: Magnitude=8, Angle=260 degrees
# Resultant Vector: Magnitude=8.60848, Angle=-113.183 degrees
#
# Pair 158:
# Vector A: Magnitude=5, Angle=350 degrees
# Vector B: Magnitude=9, Angle=125 degrees
# Resultant Vector: Magnitude=6.50849, Angle=92.097 degrees
#
# Pair 159:
# Vector A: Magnitude=2, Angle=196 degrees
# Vector B: Magnitude=7, Angle=322 degrees
# Resultant Vector: Magnitude=6.045, Angle=-53.5254 degrees
#
# Pair 160:
# Vector A: Magnitude=2, Angle=99 degrees
# Vector B: Magnitude=7, Angle=4 degrees
# Resultant Vector: Magnitude=7.11053, Angle=20.2723 degrees
#
# Pair 161:
# Vector A: Magnitude=9, Angle=220 degrees
# Vector B: Magnitude=9, Angle=261 degrees
# Resultant Vector: Magnitude=16.8601, Angle=-119.5 degrees
#
# Pair 162:
# Vector A: Magnitude=1, Angle=342 degrees
# Vector B: Magnitude=3, Angle=219 degrees
# Resultant Vector: Magnitude=2.59464, Angle=-122.142 degrees
#
# Pair 163:
# Vector A: Magnitude=8, Angle=325 degrees
# Vector B: Magnitude=7, Angle=264 degrees
# Resultant Vector: Magnitude=12.9344, Angle=-63.2512 degrees
#
# Pair 164:
# Vector A: Magnitude=7, Angle=3 degrees
# Vector B: Magnitude=8, Angle=79 degrees
# Resultant Vector: Magnitude=11.8362, Angle=43.9816 degrees
#
# Pair 165:
# Vector A: Magnitude=8, Angle=304 degrees
# Vector B: Magnitude=10, Angle=111 degrees
# Resultant Vector: Magnitude=2.84619, Angle=71.7809 degrees
#
# Pair 166:
# Vector A: Magnitude=8, Angle=310 degrees
# Vector B: Magnitude=7, Angle=160 degrees
# Resultant Vector: Magnitude=4.00064, Angle=-111.028 degrees
#
# Pair 167:
# Vector A: Magnitude=9, Angle=65 degrees
# Vector B: Magnitude=4, Angle=129 degrees
# Resultant Vector: Magnitude=11.3386, Angle=83.4862 degrees
#
# Pair 168:
# Vector A: Magnitude=5, Angle=111 degrees
# Vector B: Magnitude=6, Angle=254 degrees
# Resultant Vector: Magnitude=3.61689, Angle=-162.3 degrees
#
# Pair 169:
# Vector A: Magnitude=2, Angle=15 degrees
# Vector B: Magnitude=6, Angle=54 degrees
# Resultant Vector: Magnitude=7.65843, Angle=44.5407 degrees
#
# Pair 170:
# Vector A: Magnitude=10, Angle=208 degrees
# Vector B: Magnitude=4, Angle=278 degrees
# Resultant Vector: Magnitude=11.9734, Angle=-133.704 degrees
#
# Pair 171:
# Vector A: Magnitude=6, Angle=322 degrees
# Vector B: Magnitude=3, Angle=262 degrees
# Resultant Vector: Magnitude=7.93725, Angle=-57.1066 degrees
#
# Pair 172:
# Vector A: Magnitude=8, Angle=110 degrees
# Vector B: Magnitude=4, Angle=254 degrees
# Resultant Vector: Magnitude=5.31252, Angle=136.268 degrees
#
# Pair 173:
# Vector A: Magnitude=7, Angle=193 degrees
# Vector B: Magnitude=7, Angle=93 degrees
# Resultant Vector: Magnitude=8.99903, Angle=143 degrees
#
# Pair 174:
# Vector A: Magnitude=4, Angle=114 degrees
# Vector B: Magnitude=5, Angle=33 degrees
# Resultant Vector: Magnitude=6.8744, Angle=68.079 degrees
#
# Pair 175:
# Vector A: Magnitude=10, Angle=17 degrees
# Vector B: Magnitude=3, Angle=215 degrees
# Resultant Vector: Magnitude=7.20671, Angle=9.60915 degrees
#
# Pair 176:
# Vector A: Magnitude=9, Angle=39 degrees
# Vector B: Magnitude=1, Angle=332 degrees
# Resultant Vector: Magnitude=9.43574, Angle=33.4016 degrees
#
# Pair 177:
# Vector A: Magnitude=5, Angle=137 degrees
# Vector B: Magnitude=7, Angle=155 degrees
# Resultant Vector: Magnitude=11.8564, Angle=147.512 degrees
#
# Pair 178:
# Vector A: Magnitude=8, Angle=171 degrees
# Vector B: Magnitude=4, Angle=263 degrees
# Resultant Vector: Magnitude=8.81853, Angle=-162.043 degrees
#
# Pair 179:
# Vector A: Magnitude=4, Angle=128 degrees
# Vector B: Magnitude=6, Angle=331 degrees
# Resultant Vector: Magnitude=2.79567, Angle=4.99026 degrees
#
# Pair 180:
# Vector A: Magnitude=1, Angle=18 degrees
# Vector B: Magnitude=8, Angle=36 degrees
# Resultant Vector: Magnitude=8.95639, Angle=34.0228 degrees
#
# Pair 181:
# Vector A: Magnitude=4, Angle=335 degrees
# Vector B: Magnitude=1, Angle=98 degrees
# Resultant Vector: Magnitude=3.55568, Angle=-11.3572 degrees
#
# Pair 182:
# Vector A: Magnitude=1, Angle=24 degrees
# Vector B: Magnitude=2, Angle=141 degrees
# Resultant Vector: Magnitude=1.78439, Angle=111.044 degrees
#
# Pair 183:
# Vector A: Magnitude=4, Angle=165 degrees
# Vector B: Magnitude=10, Angle=273 degrees
# Resultant Vector: Magnitude=9.55399, Angle=-110.465 degrees
#
# Pair 184:
# Vector A: Magnitude=5, Angle=211 degrees
# Vector B: Magnitude=6, Angle=130 degrees
# Resultant Vector: Magnitude=8.38964, Angle=166.06 degrees
#
# Pair 185:
# Vector A: Magnitude=9, Angle=143 degrees
# Vector B: Magnitude=6, Angle=206 degrees
# Resultant Vector: Magnitude=12.8853, Angle=167.513 degrees
#
# Pair 186:
# Vector A: Magnitude=6, Angle=359 degrees
# Vector B: Magnitude=10, Angle=320 degrees
# Resultant Vector: Magnitude=15.1413, Angle=-25.5592 degrees
#
# Pair 187:
# Vector A: Magnitude=8, Angle=146 degrees
# Vector B: Magnitude=4, Angle=237 degrees
# Resultant Vector: Magnitude=8.88161, Angle=172.763 degrees
#
# Pair 188:
# Vector A: Magnitude=7, Angle=261 degrees
# Vector B: Magnitude=6, Angle=120 degrees
# Resultant Vector: Magnitude=4.44069, Angle=-157.244 degrees
#
# Pair 189:
# Vector A: Magnitude=7, Angle=275 degrees
# Vector B: Magnitude=1, Angle=198 degrees
# Resultant Vector: Magnitude=7.29036, Angle=-92.6807 degrees
#
# Pair 190:
# Vector A: Magnitude=2, Angle=222 degrees
# Vector B: Magnitude=3, Angle=316 degrees
# Resultant Vector: Magnitude=3.48754, Angle=-78.8949 degrees
#
# Pair 191:
# Vector A: Magnitude=10, Angle=81 degrees
# Vector B: Magnitude=1, Angle=104 degrees
# Resultant Vector: Magnitude=10.9275, Angle=83.0491 degrees
#
# Pair 192:
# Vector A: Magnitude=3, Angle=347 degrees
# Vector B: Magnitude=5, Angle=280 degrees
# Resultant Vector: Magnitude=6.7618, Angle=-55.8957 degrees
#
# Pair 193:
# Vector A: Magnitude=4, Angle=32 degrees
# Vector B: Magnitude=9, Angle=190 degrees
# Resultant Vector: Magnitude=5.49934, Angle=174.188 degrees
#
# Pair 194:
# Vector A: Magnitude=4, Angle=107 degrees
# Vector B: Magnitude=1, Angle=30 degrees
# Resultant Vector: Magnitude=4.33585, Angle=94.0133 degrees
#
# Pair 195:
# Vector A: Magnitude=4, Angle=314 degrees
# Vector B: Magnitude=10, Angle=162 degrees
# Resultant Vector: Magnitude=6.73529, Angle=178.189 degrees
#
# Pair 196:
# Vector A: Magnitude=8, Angle=284 degrees
# Vector B: Magnitude=3, Angle=195 degrees
# Resultant Vector: Magnitude=8.59289, Angle=-96.4306 degrees
#
# Pair 197:
# Vector A: Magnitude=3, Angle=244 degrees
# Vector B: Magnitude=5, Angle=243 degrees
# Resultant Vector: Magnitude=7.99971, Angle=-116.625 degrees
#
# Pair 198:
# Vector A: Magnitude=9, Angle=246 degrees
# Vector B: Magnitude=1, Angle=238 degrees
# Resultant Vector: Magnitude=9.99124, Angle=-114.798 degrees
#
# Pair 199:
# Vector A: Magnitude=10, Angle=302 degrees
# Vector B: Magnitude=3, Angle=3 degrees
# Resultant Vector: Magnitude=11.7511, Angle=-45.0979 degrees
#
# Pair 200:
# Vector A: Magnitude=2, Angle=88 degrees
# Vector B: Magnitude=4, Angle=164 degrees
# Resultant Vector: Magnitude=4.88577, Angle=140.597 degrees
#
# Pair 201:
# Vector A: Magnitude=3, Angle=282 degrees
# Vector B: Magnitude=5, Angle=255 degrees
# Resultant Vector: Magnitude=7.79296, Angle=-94.9348 degrees
#
# Pair 202:
# Vector A: Magnitude=2, Angle=17 degrees
# Vector B: Magnitude=6, Angle=27 degrees
# Resultant Vector: Magnitude=7.97718, Angle=24.5048 degrees
#
# Pair 203:
# Vector A: Magnitude=2, Angle=296 degrees
# Vector B: Magnitude=10, Angle=58 degrees
# Resultant Vector: Magnitude=9.09963, Angle=47.2577 degrees
#
# Pair 204:
# Vector A: Magnitude=2, Angle=343 degrees
# Vector B: Magnitude=4, Angle=293 degrees
# Resultant Vector: Magnitude=5.50314, Angle=-50.8351 degrees
#
# Pair 205:
# Vector A: Magnitude=8, Angle=159 degrees
# Vector B: Magnitude=9, Angle=206 degrees
# Resultant Vector: Magnitude=15.5951, Angle=-176.035 degrees
#
# Pair 206:
# Vector A: Magnitude=8, Angle=120 degrees
# Vector B: Magnitude=5, Angle=348 degrees
# Resultant Vector: Magnitude=5.95563, Angle=81.3984 degrees
#
# Pair 207:
# Vector A: Magnitude=5, Angle=298 degrees
# Vector B: Magnitude=2, Angle=96 degrees
# Resultant Vector: Magnitude=3.23362, Angle=-48.6031 degrees
#
# Pair 208:
# Vector A: Magnitude=9, Angle=275 degrees
# Vector B: Magnitude=3, Angle=251 degrees
# Resultant Vector: Magnitude=11.8039, Angle=-90.9335 degrees
#
# Pair 209:
# Vector A: Magnitude=10, Angle=359 degrees
# Vector B: Magnitude=7, Angle=330 degrees
# Resultant Vector: Magnitude=16.4756, Angle=-12.8869 degrees
#
# Pair 210:
# Vector A: Magnitude=7, Angle=304 degrees
# Vector B: Magnitude=10, Angle=219 degrees
# Resultant Vector: Magnitude=12.6965, Angle=-107.686 degrees
#
# Pair 211:
# Vector A: Magnitude=1, Angle=58 degrees
# Vector B: Magnitude=10, Angle=333 degrees
# Resultant Vector: Magnitude=10.1362, Angle=-21.3598 degrees
#
# Pair 212:
# Vector A: Magnitude=2, Angle=274 degrees
# Vector B: Magnitude=9, Angle=269 degrees
# Resultant Vector: Magnitude=10.9938, Angle=-90.0915 degrees
#
# Pair 213:
# Vector A: Magnitude=7, Angle=187 degrees
# Vector B: Magnitude=8, Angle=223 degrees
# Resultant Vector: Magnitude=14.2692, Angle=-153.759 degrees
#
# Pair 214:
# Vector A: Magnitude=8, Angle=71 degrees
# Vector B: Magnitude=3, Angle=242 degrees
# Resultant Vector: Magnitude=5.05875, Angle=76.323 degrees
#
# Pair 215:
# Vector A: Magnitude=2, Angle=75 degrees
# Vector B: Magnitude=1, Angle=139 degrees
# Resultant Vector: Magnitude=2.59875, Angle=95.2341 degrees
#
# Pair 216:
# Vector A: Magnitude=1, Angle=214 degrees
# Vector B: Magnitude=1, Angle=291 degrees
# Resultant Vector: Magnitude=1.56522, Angle=-107.5 degrees
#
# Pair 217:
# Vector A: Magnitude=4, Angle=177 degrees
# Vector B: Magnitude=5, Angle=101 degrees
# Resultant Vector: Magnitude=7.11877, Angle=134.039 degrees
#
# Pair 218:
# Vector A: Magnitude=2, Angle=3 degrees
# Vector B: Magnitude=1, Angle=233 degrees
# Resultant Vector: Magnitude=1.55848, Angle=-26.4415 degrees
#
# Pair 219:
# Vector A: Magnitude=3, Angle=341 degrees
# Vector B: Magnitude=8, Angle=335 degrees
# Resultant Vector: Magnitude=10.988, Angle=-23.3646 degrees
#
# Pair 220:
# Vector A: Magnitude=7, Angle=345 degrees
# Vector B: Magnitude=5, Angle=202 degrees
# Resultant Vector: Magnitude=4.25388, Angle=-60.0215 degrees
#
# Pair 221:
# Vector A: Magnitude=3, Angle=231 degrees
# Vector B: Magnitude=8, Angle=352 degrees
# Resultant Vector: Magnitude=6.94825, Angle=-29.7214 degrees
#
# Pair 222:
# Vector A: Magnitude=5, Angle=21 degrees
# Vector B: Magnitude=7, Angle=55 degrees
# Resultant Vector: Magnitude=11.4905, Angle=40.917 degrees
#
# Pair 223:
# Vector A: Magnitude=8, Angle=188 degrees
# Vector B: Magnitude=6, Angle=319 degrees
# Resultant Vector: Magnitude=6.08427, Angle=-123.905 degrees
#
# Pair 224:
# Vector A: Magnitude=3, Angle=97 degrees
# Vector B: Magnitude=4, Angle=256 degrees
# Resultant Vector: Magnitude=1.61061, Angle=-145.875 degrees
#
# Pair 225:
# Vector A: Magnitude=5, Angle=257 degrees
# Vector B: Magnitude=10, Angle=267 degrees
# Resultant Vector: Magnitude=14.9493, Angle=-96.3296 degrees
#
# Pair 226:
# Vector A: Magnitude=3, Angle=62 degrees
# Vector B: Magnitude=2, Angle=66 degrees
# Resultant Vector: Magnitude=4.99708, Angle=63.5998 degrees
#
# Pair 227:
# Vector A: Magnitude=4, Angle=220 degrees
# Vector B: Magnitude=3, Angle=171 degrees
# Resultant Vector: Magnitude=6.38321, Angle=-160.775 degrees
#
# Pair 228:
# Vector A: Magnitude=6, Angle=286 degrees
# Vector B: Magnitude=6, Angle=250 degrees
# Resultant Vector: Magnitude=11.4127, Angle=-92 degrees
#
# Pair 229:
# Vector A: Magnitude=1, Angle=183 degrees
# Vector B: Magnitude=5, Angle=76 degrees
# Resultant Vector: Magnitude=4.80378, Angle=87.4828 degrees
#
# Pair 230:
# Vector A: Magnitude=7, Angle=220 degrees
# Vector B: Magnitude=3, Angle=45 degrees
# Resultant Vector: Magnitude=4.01993, Angle=-143.729 degrees
#
# Pair 231:
# Vector A: Magnitude=9, Angle=199 degrees
# Vector B: Magnitude=6, Angle=90 degrees
# Resultant Vector: Magnitude=9.04647, Angle=160.163 degrees
#
# Pair 232:
# Vector A: Magnitude=7, Angle=0 degrees
# Vector B: Magnitude=9, Angle=83 degrees
# Resultant Vector: Magnitude=12.0563, Angle=47.8107 degrees
#
# Pair 233:
# Vector A: Magnitude=8, Angle=88 degrees
# Vector B: Magnitude=3, Angle=261 degrees
# Resultant Vector: Magnitude=5.03565, Angle=92.1636 degrees
#
# Pair 234:
# Vector A: Magnitude=1, Angle=235 degrees
# Vector B: Magnitude=9, Angle=65 degrees
# Resultant Vector: Magnitude=8.01707, Angle=66.2411 degrees
#
# Pair 235:
# Vector A: Magnitude=6, Angle=10 degrees
# Vector B: Magnitude=8, Angle=173 degrees
# Resultant Vector: Magnitude=2.86265, Angle=135.208 degrees
#
# Pair 236:
# Vector A: Magnitude=9, Angle=122 degrees
# Vector B: Magnitude=4, Angle=70 degrees
# Resultant Vector: Magnitude=11.8881, Angle=106.625 degrees
#
# Pair 237:
# Vector A: Magnitude=8, Angle=177 degrees
# Vector B: Magnitude=8, Angle=126 degrees
# Resultant Vector: Magnitude=14.4414, Angle=151.5 degrees
#
# Pair 238:
# Vector A: Magnitude=10, Angle=151 degrees
# Vector B: Magnitude=2, Angle=189 degrees
# Resultant Vector: Magnitude=11.6413, Angle=157.072 degrees
#
# Pair 239:
# Vector A: Magnitude=1, Angle=48 degrees
# Vector B: Magnitude=10, Angle=158 degrees
# Resultant Vector: Magnitude=9.70359, Angle=152.443 degrees
#
# Pair 240:
# Vector A: Magnitude=9, Angle=10 degrees
# Vector B: Magnitude=4, Angle=177 degrees
# Resultant Vector: Magnitude=5.18125, Angle=20.001 degrees
#
# Pair 241:
# Vector A: Magnitude=1, Angle=336 degrees
# Vector B: Magnitude=10, Angle=352 degrees
# Resultant Vector: Magnitude=10.9647, Angle=-9.44048 degrees
#
# Pair 242:
# Vector A: Magnitude=2, Angle=47 degrees
# Vector B: Magnitude=8, Angle=179 degrees
# Resultant Vector: Magnitude=6.82553, Angle=166.423 degrees
#
# Pair 243:
# Vector A: Magnitude=8, Angle=166 degrees
# Vector B: Magnitude=3, Angle=97 degrees
# Resultant Vector: Magnitude=9.49746, Angle=148.849 degrees
#
# Pair 244:
# Vector A: Magnitude=2, Angle=55 degrees
# Vector B: Magnitude=9, Angle=338 degrees
# Resultant Vector: Magnitude=9.64874, Angle=-10.3479 degrees
#
# Pair 245:
# Vector A: Magnitude=5, Angle=315 degrees
# Vector B: Magnitude=7, Angle=245 degrees
# Resultant Vector: Magnitude=9.89654, Angle=-86.6564 degrees
#
# Pair 246:
# Vector A: Magnitude=7, Angle=148 degrees
# Vector B: Magnitude=5, Angle=328 degrees
# Resultant Vector: Magnitude=2, Angle=148 degrees
#
# Pair 247:
# Vector A: Magnitude=9, Angle=353 degrees
# Vector B: Magnitude=9, Angle=117 degrees
# Resultant Vector: Magnitude=8.45049, Angle=55 degrees
#
# Pair 248:
# Vector A: Magnitude=6, Angle=112 degrees
# Vector B: Magnitude=5, Angle=205 degrees
# Resultant Vector: Magnitude=7.60657, Angle=153.028 degrees
#
# Pair 249:
# Vector A: Magnitude=1, Angle=245 degrees
# Vector B: Magnitude=8, Angle=43 degrees
# Resultant Vector: Magnitude=7.08273, Angle=39.9682 degrees
#
# Pair 250:
# Vector A: Magnitude=3, Angle=127 degrees
# Vector B: Magnitude=3, Angle=221 degrees
# Resultant Vector: Magnitude=4.09199, Angle=174 degrees
#
# Pair 251:
# Vector A: Magnitude=4, Angle=214 degrees
# Vector B: Magnitude=10, Angle=94 degrees
# Resultant Vector: Magnitude=8.7178, Angle=117.413 degrees
#
# Pair 252:
# Vector A: Magnitude=2, Angle=359 degrees
# Vector B: Magnitude=6, Angle=117 degrees
# Resultant Vector: Magnitude=5.36029, Angle=97.7652 degrees
#
# Pair 253:
# Vector A: Magnitude=5, Angle=281 degrees
# Vector B: Magnitude=3, Angle=292 degrees
# Resultant Vector: Magnitude=7.96548, Angle=-74.879 degrees
#
# Pair 254:
# Vector A: Magnitude=2, Angle=76 degrees
# Vector B: Magnitude=3, Angle=10 degrees
# Resultant Vector: Magnitude=4.22857, Angle=35.5998 degrees
#
# Pair 255:
# Vector A: Magnitude=3, Angle=2 degrees
# Vector B: Magnitude=10, Angle=177 degrees
# Resultant Vector: Magnitude=7.01629, Angle=174.864 degrees
#
# Pair 256:
# Vector A: Magnitude=5, Angle=293 degrees
# Vector B: Magnitude=6, Angle=306 degrees
# Resultant Vector: Magnitude=10.9299, Angle=-59.9066 degrees
#
# Pair 257:
# Vector A: Magnitude=2, Angle=324 degrees
# Vector B: Magnitude=1, Angle=343 degrees
# Resultant Vector: Magnitude=2.96346, Angle=-29.6927 degrees
#
# Pair 258:
# Vector A: Magnitude=2, Angle=212 degrees
# Vector B: Magnitude=8, Angle=257 degrees
# Resultant Vector: Magnitude=9.51984, Angle=-111.543 degrees
#
# Pair 259:
# Vector A: Magnitude=10, Angle=268 degrees
# Vector B: Magnitude=2, Angle=80 degrees
# Resultant Vector: Magnitude=8.02429, Angle=-90.0121 degrees
#
# Pair 260:
# Vector A: Magnitude=8, Angle=296 degrees
# Vector B: Magnitude=1, Angle=221 degrees
# Resultant Vector: Magnitude=8.31511, Angle=-70.6708 degrees
#
# Pair 261:
# Vector A: Magnitude=1, Angle=72 degrees
# Vector B: Magnitude=6, Angle=31 degrees
# Resultant Vector: Magnitude=6.7865, Angle=36.5475 degrees
#
# Pair 262:
# Vector A: Magnitude=10, Angle=157 degrees
# Vector B: Magnitude=2, Angle=323 degrees
# Resultant Vector: Magnitude=8.07392, Angle=160.436 degrees
#
# Pair 263:
# Vector A: Magnitude=2, Angle=272 degrees
# Vector B: Magnitude=1, Angle=146 degrees
# Resultant Vector: Magnitude=1.62753, Angle=-117.807 degrees
#
# Pair 264:
# Vector A: Magnitude=9, Angle=267 degrees
# Vector B: Magnitude=5, Angle=129 degrees
# Resultant Vector: Magnitude=6.25436, Angle=-125.339 degrees
#
# Pair 265:
# Vector A: Magnitude=3, Angle=314 degrees
# Vector B: Magnitude=5, Angle=195 degrees
# Resultant Vector: Magnitude=4.41086, Angle=-128.497 degrees
#
# Pair 266:
# Vector A: Magnitude=10, Angle=61 degrees
# Vector B: Magnitude=3, Angle=338 degrees
# Resultant Vector: Magnitude=10.7848, Angle=44.9727 degrees
#
# Pair 267:
# Vector A: Magnitude=10, Angle=316 degrees
# Vector B: Magnitude=1, Angle=236 degrees
# Resultant Vector: Magnitude=10.2212, Angle=-49.529 degrees
#
# Pair 268:
# Vector A: Magnitude=5, Angle=0 degrees
# Vector B: Magnitude=10, Angle=214 degrees
# Resultant Vector: Magnitude=6.48816, Angle=-120.473 degrees
#
# Pair 269:
# Vector A: Magnitude=6, Angle=354 degrees
# Vector B: Magnitude=7, Angle=326 degrees
# Resultant Vector: Magnitude=12.6162, Angle=-21.0987 degrees
#
# Pair 270:
# Vector A: Magnitude=4, Angle=159 degrees
# Vector B: Magnitude=10, Angle=55 degrees
# Resultant Vector: Magnitude=9.83088, Angle=78.2532 degrees
#
# Pair 271:
# Vector A: Magnitude=3, Angle=301 degrees
# Vector B: Magnitude=4, Angle=150 degrees
# Resultant Vector: Magnitude=2.00228, Angle=-163.416 degrees
#
# Pair 272:
# Vector A: Magnitude=10, Angle=269 degrees
# Vector B: Magnitude=2, Angle=313 degrees
# Resultant Vector: Magnitude=11.5227, Angle=-84.0749 degrees
#
# Pair 273:
# Vector A: Magnitude=5, Angle=135 degrees
# Vector B: Magnitude=9, Angle=135 degrees
# Resultant Vector: Magnitude=14, Angle=135 degrees
#
# Pair 274:
# Vector A: Magnitude=8, Angle=113 degrees
# Vector B: Magnitude=4, Angle=38 degrees
# Resultant Vector: Magnitude=9.82672, Angle=89.8473 degrees
#
# Pair 275:
# Vector A: Magnitude=10, Angle=275 degrees
# Vector B: Magnitude=6, Angle=193 degrees
# Resultant Vector: Magnitude=12.3572, Angle=-113.739 degrees
#
# Pair 276:
# Vector A: Magnitude=9, Angle=116 degrees
# Vector B: Magnitude=1, Angle=93 degrees
# Resultant Vector: Magnitude=9.9282, Angle=113.745 degrees
#
# Pair 277:
# Vector A: Magnitude=4, Angle=166 degrees
# Vector B: Magnitude=2, Angle=238 degrees
# Resultant Vector: Magnitude=4.99442, Angle=-171.614 degrees
#
# Pair 278:
# Vector A: Magnitude=8, Angle=220 degrees
# Vector B: Magnitude=6, Angle=141 degrees
# Resultant Vector: Magnitude=10.8774, Angle=-172.784 degrees
#
# Pair 279:
# Vector A: Magnitude=2, Angle=110 degrees
# Vector B: Magnitude=4, Angle=10 degrees
# Resultant Vector: Magnitude=4.1499, Angle=38.3345 degrees
#
# Pair 280:
# Vector A: Magnitude=1, Angle=314 degrees
# Vector B: Magnitude=6, Angle=244 degrees
# Resultant Vector: Magnitude=6.41126, Angle=-107.572 degrees
#
# Pair 281:
# Vector A: Magnitude=3, Angle=344 degrees
# Vector B: Magnitude=10, Angle=159 degrees
# Resultant Vector: Magnitude=7.01629, Angle=156.864 degrees
#
# Pair 282:
# Vector A: Magnitude=10, Angle=4 degrees
# Vector B: Magnitude=10, Angle=38 degrees
# Resultant Vector: Magnitude=19.1261, Angle=21 degrees
#
# Pair 283:
# Vector A: Magnitude=2, Angle=216 degrees
# Vector B: Magnitude=4, Angle=299 degrees
# Resultant Vector: Magnitude=4.68507, Angle=-86.0688 degrees
#
# Pair 284:
# Vector A: Magnitude=4, Angle=23 degrees
# Vector B: Magnitude=5, Angle=316 degrees
# Resultant Vector: Magnitude=7.52524, Angle=-14.7061 degrees
#
# Pair 285:
# Vector A: Magnitude=2, Angle=195 degrees
# Vector B: Magnitude=7, Angle=131 degrees
# Resultant Vector: Magnitude=8.07926, Angle=143.856 degrees
#
# Pair 286:
# Vector A: Magnitude=8, Angle=232 degrees
# Vector B: Magnitude=3, Angle=89 degrees
# Resultant Vector: Magnitude=5.88774, Angle=-145.857 degrees
#
# Pair 287:
# Vector A: Magnitude=3, Angle=308 degrees
# Vector B: Magnitude=2, Angle=2 degrees
# Resultant Vector: Magnitude=4.4781, Angle=-30.8186 degrees
#
# Pair 288:
# Vector A: Magnitude=5, Angle=167 degrees
# Vector B: Magnitude=9, Angle=96 degrees
# Resultant Vector: Magnitude=11.6319, Angle=119.981 degrees
#
# Pair 289:
# Vector A: Magnitude=4, Angle=137 degrees
# Vector B: Magnitude=8, Angle=352 degrees
# Resultant Vector: Magnitude=5.25112, Angle=17.9074 degrees
#
# Pair 290:
# Vector A: Magnitude=4, Angle=197 degrees
# Vector B: Magnitude=3, Angle=165 degrees
# Resultant Vector: Magnitude=6.73448, Angle=-176.654 degrees
#
# Pair 291:
# Vector A: Magnitude=4, Angle=237 degrees
# Vector B: Magnitude=7, Angle=258 degrees
# Resultant Vector: Magnitude=10.8296, Angle=-109.606 degrees
#
# Pair 292:
# Vector A: Magnitude=2, Angle=113 degrees
# Vector B: Magnitude=7, Angle=194 degrees
# Resultant Vector: Magnitude=7.57497, Angle=178.884 degrees
#
# Pair 293:
# Vector A: Magnitude=1, Angle=153 degrees
# Vector B: Magnitude=6, Angle=108 degrees
# Resultant Vector: Magnitude=6.74428, Angle=114.018 degrees
#
# Pair 294:
# Vector A: Magnitude=6, Angle=110 degrees
# Vector B: Magnitude=10, Angle=239 degrees
# Resultant Vector: Magnitude=7.77699, Angle=-157.839 degrees
#
# Pair 295:
# Vector A: Magnitude=9, Angle=40 degrees
# Vector B: Magnitude=3, Angle=64 degrees
# Resultant Vector: Magnitude=11.8039, Angle=45.9335 degrees
#
# Pair 296:
# Vector A: Magnitude=10, Angle=0 degrees
# Vector B: Magnitude=2, Angle=102 degrees
# Resultant Vector: Magnitude=9.7818, Angle=11.5366 degrees
#
# Pair 297:
# Vector A: Magnitude=1, Angle=160 degrees
# Vector B: Magnitude=7, Angle=23 degrees
# Resultant Vector: Magnitude=6.30564, Angle=29.2091 degrees
#
# Pair 298:
# Vector A: Magnitude=10, Angle=100 degrees
# Vector B: Magnitude=9, Angle=283 degrees
# Resultant Vector: Magnitude=1.11655, Angle=75.0482 degrees
#
# Pair 299:
# Vector A: Magnitude=9, Angle=37 degrees
# Vector B: Magnitude=4, Angle=111 degrees
# Resultant Vector: Magnitude=10.8095, Angle=57.8369 degrees
#
# Pair 300:
# Vector A: Magnitude=1, Angle=140 degrees
# Vector B: Magnitude=6, Angle=330 degrees
# Resultant Vector: Magnitude=5.0182, Angle=-28.017 degrees
#
# Pair 301:
# Vector A: Magnitude=4, Angle=271 degrees
# Vector B: Magnitude=9, Angle=190 degrees
# Resultant Vector: Magnitude=10.405, Angle=-147.685 degrees
#
# Pair 302:
# Vector A: Magnitude=2, Angle=147 degrees
# Vector B: Magnitude=10, Angle=311 degrees
# Resultant Vector: Magnitude=8.09627, Angle=-52.9043 degrees
#
# Pair 303:
# Vector A: Magnitude=1, Angle=183 degrees
# Vector B: Magnitude=6, Angle=139 degrees
# Resultant Vector: Magnitude=6.75515, Angle=144.902 degrees
#
# Pair 304:
# Vector A: Magnitude=5, Angle=48 degrees
# Vector B: Magnitude=5, Angle=66 degrees
# Resultant Vector: Magnitude=9.87688, Angle=57 degrees
#
# Pair 305:
# Vector A: Magnitude=10, Angle=312 degrees
# Vector B: Magnitude=10, Angle=310 degrees
# Resultant Vector: Magnitude=19.997, Angle=-49 degrees
#
# Pair 306:
# Vector A: Magnitude=4, Angle=150 degrees
# Vector B: Magnitude=4, Angle=263 degrees
# Resultant Vector: Magnitude=4.4155, Angle=-153.5 degrees
#
# Pair 307:
# Vector A: Magnitude=8, Angle=159 degrees
# Vector B: Magnitude=5, Angle=209 degrees
# Resultant Vector: Magnitude=11.85, Angle=177.858 degrees
#
# Pair 308:
# Vector A: Magnitude=10, Angle=191 degrees
# Vector B: Magnitude=10, Angle=104 degrees
# Resultant Vector: Magnitude=14.5075, Angle=147.5 degrees
#
# Pair 309:
# Vector A: Magnitude=3, Angle=130 degrees
# Vector B: Magnitude=7, Angle=355 degrees
# Resultant Vector: Magnitude=5.31992, Angle=18.5001 degrees
#
# Pair 310:
# Vector A: Magnitude=10, Angle=235 degrees
# Vector B: Magnitude=7, Angle=81 degrees
# Resultant Vector: Magnitude=4.8134, Angle=-164.606 degrees
#
# Pair 311:
# Vector A: Magnitude=2, Angle=194 degrees
# Vector B: Magnitude=4, Angle=347 degrees
# Resultant Vector: Magnitude=2.39664, Angle=-35.2628 degrees
#
# Pair 312:
# Vector A: Magnitude=3, Angle=207 degrees
# Vector B: Magnitude=4, Angle=323 degrees
# Resultant Vector: Magnitude=3.80514, Angle=-82.1224 degrees
#
# Pair 313:
# Vector A: Magnitude=10, Angle=142 degrees
# Vector B: Magnitude=5, Angle=84 degrees
# Resultant Vector: Magnitude=13.3414, Angle=123.468 degrees
#
# Pair 314:
# Vector A: Magnitude=5, Angle=19 degrees
# Vector B: Magnitude=10, Angle=223 degrees
# Resultant Vector: Magnitude=5.80047, Angle=-116.476 degrees
#
# Pair 315:
# Vector A: Magnitude=9, Angle=233 degrees
# Vector B: Magnitude=3, Angle=349 degrees
# Resultant Vector: Magnitude=8.1442, Angle=-107.666 degrees
#
# Pair 316:
# Vector A: Magnitude=6, Angle=124 degrees
# Vector B: Magnitude=4, Angle=39 degrees
# Resultant Vector: Magnitude=7.49556, Angle=91.8851 degrees
#
# Pair 317:
# Vector A: Magnitude=5, Angle=259 degrees
# Vector B: Magnitude=6, Angle=275 degrees
# Resultant Vector: Magnitude=10.8938, Angle=-92.268 degrees
#
# ...
# Vector B: Magnitude=9, Angle=100 degrees
# Resultant Vector: Magnitude=8.56035, Angle=87.2377 degrees
#
# Pair 896:
# Vector A: Magnitude=7, Angle=276 degrees
# Vector B: Magnitude=7, Angle=260 degrees
# Resultant Vector: Magnitude=13.8638, Angle=-92 degrees
#
# Pair 897:
# Vector A: Magnitude=10, Angle=120 degrees
# Vector B: Magnitude=6, Angle=278 degrees
# Resultant Vector: Magnitude=4.97372, Angle=146.866 degrees
#
# Pair 898:
# Vector A: Magnitude=8, Angle=340 degrees
# Vector B: Magnitude=5, Angle=86 degrees
# Resultant Vector: Magnitude=8.18224, Angle=15.9733 degrees
#
# Pair 899:
# Vector A: Magnitude=7, Angle=310 degrees
# Vector B: Magnitude=1, Angle=176 degrees
# Resultant Vector: Magnitude=6.34624, Angle=-56.5084 degrees
#
# Pair 900:
# Vector A: Magnitude=3, Angle=126 degrees
# Vector B: Magnitude=6, Angle=172 degrees
# Resultant Vector: Magnitude=8.36706, Angle=157.053 degrees
#
# Pair 901:
# Vector A: Magnitude=5, Angle=11 degrees
# Vector B: Magnitude=5, Angle=32 degrees
# Resultant Vector: Magnitude=9.83255, Angle=21.5 degrees
#
# Pair 902:
# Vector A: Magnitude=1, Angle=41 degrees
# Vector B: Magnitude=1, Angle=73 degrees
# Resultant Vector: Magnitude=1.92252, Angle=57 degrees
#
# Pair 903:
# Vector A: Magnitude=5, Angle=110 degrees
# Vector B: Magnitude=5, Angle=30 degrees
# Resultant Vector: Magnitude=7.66044, Angle=70 degrees
#
# Pair 904:
# Vector A: Magnitude=7, Angle=232 degrees
# Vector B: Magnitude=3, Angle=47 degrees
# Resultant Vector: Magnitude=4.01993, Angle=-124.271 degrees
#
# Pair 905:
# Vector A: Magnitude=3, Angle=17 degrees
# Vector B: Magnitude=6, Angle=181 degrees
# Resultant Vector: Magnitude=3.22406, Angle=166.139 degrees
#
# Pair 906:
# Vector A: Magnitude=10, Angle=260 degrees
# Vector B: Magnitude=1, Angle=16 degrees
# Resultant Vector: Magnitude=9.60378, Angle=-94.63 degrees
#
# Pair 907:
# Vector A: Magnitude=3, Angle=30 degrees
# Vector B: Magnitude=3, Angle=224 degrees
# Resultant Vector: Magnitude=0.731216, Angle=-53 degrees
#
# Pair 908:
# Vector A: Magnitude=10, Angle=209 degrees
# Vector B: Magnitude=10, Angle=315 degrees
# Resultant Vector: Magnitude=12.0363, Angle=-98 degrees
#
# Pair 909:
# Vector A: Magnitude=1, Angle=283 degrees
# Vector B: Magnitude=8, Angle=160 degrees
# Resultant Vector: Magnitude=7.50238, Angle=166.418 degrees
#
# Pair 910:
# Vector A: Magnitude=5, Angle=349 degrees
# Vector B: Magnitude=5, Angle=228 degrees
# Resultant Vector: Magnitude=4.92424, Angle=-71.5 degrees
#
# Pair 911:
# Vector A: Magnitude=10, Angle=280 degrees
# Vector B: Magnitude=1, Angle=358 degrees
# Resultant Vector: Magnitude=10.2547, Angle=-74.5265 degrees
#
# Pair 912:
# Vector A: Magnitude=3, Angle=292 degrees
# Vector B: Magnitude=6, Angle=16 degrees
# Resultant Vector: Magnitude=6.98305, Angle=-9.29368 degrees
#
# Pair 913:
# Vector A: Magnitude=3, Angle=11 degrees
# Vector B: Magnitude=9, Angle=51 degrees
# Resultant Vector: Magnitude=11.4615, Angle=41.3141 degrees
#
# Pair 914:
# Vector A: Magnitude=4, Angle=210 degrees
# Vector B: Magnitude=8, Angle=97 degrees
# Resultant Vector: Magnitude=7.41574, Angle=126.77 degrees
#
# Pair 915:
# Vector A: Magnitude=3, Angle=131 degrees
# Vector B: Magnitude=5, Angle=141 degrees
# Resultant Vector: Magnitude=7.97146, Angle=137.253 degrees
#
# Pair 916:
# Vector A: Magnitude=2, Angle=103 degrees
# Vector B: Magnitude=7, Angle=73 degrees
# Resultant Vector: Magnitude=8.78912, Angle=79.5331 degrees
#
# Pair 917:
# Vector A: Magnitude=9, Angle=316 degrees
# Vector B: Magnitude=7, Angle=223 degrees
# Resultant Vector: Magnitude=11.1088, Angle=-82.9961 degrees
#
# Pair 918:
# Vector A: Magnitude=6, Angle=212 degrees
# Vector B: Magnitude=4, Angle=277 degrees
# Resultant Vector: Magnitude=8.5021, Angle=-122.761 degrees
#
# Pair 919:
# Vector A: Magnitude=3, Angle=326 degrees
# Vector B: Magnitude=6, Angle=156 degrees
# Resultant Vector: Magnitude=3.08981, Angle=165.706 degrees
#
# Pair 920:
# Vector A: Magnitude=9, Angle=320 degrees
# Vector B: Magnitude=3, Angle=312 degrees
# Resultant Vector: Magnitude=11.9781, Angle=-41.9976 degrees
#
# Pair 921:
# Vector A: Magnitude=4, Angle=242 degrees
# Vector B: Magnitude=5, Angle=218 degrees
# Resultant Vector: Magnitude=8.80578, Angle=-131.353 degrees
#
# Pair 922:
# Vector A: Magnitude=3, Angle=303 degrees
# Vector B: Magnitude=9, Angle=205 degrees
# Resultant Vector: Magnitude=9.08211, Angle=-135.907 degrees
#
# Pair 923:
# Vector A: Magnitude=8, Angle=22 degrees
# Vector B: Magnitude=9, Angle=288 degrees
# Resultant Vector: Magnitude=11.617, Angle=-28.6095 degrees
#
# Pair 924:
# Vector A: Magnitude=8, Angle=187 degrees
# Vector B: Magnitude=4, Angle=255 degrees
# Resultant Vector: Magnitude=10.1968, Angle=-151.671 degrees
#
# Pair 925:
# Vector A: Magnitude=4, Angle=339 degrees
# Vector B: Magnitude=1, Angle=88 degrees
# Resultant Vector: Magnitude=3.79413, Angle=-6.56951 degrees
#
# Pair 926:
# Vector A: Magnitude=2, Angle=186 degrees
# Vector B: Magnitude=6, Angle=195 degrees
# Resultant Vector: Magnitude=7.98151, Angle=-167.247 degrees
#
# Pair 927:
# Vector A: Magnitude=3, Angle=152 degrees
# Vector B: Magnitude=2, Angle=282 degrees
# Resultant Vector: Magnitude=2.29925, Angle=-166.215 degrees
#
# Pair 928:
# Vector A: Magnitude=6, Angle=36 degrees
# Vector B: Magnitude=6, Angle=188 degrees
# Resultant Vector: Magnitude=2.90306, Angle=112 degrees
#
# Pair 929:
# Vector A: Magnitude=9, Angle=239 degrees
# Vector B: Magnitude=10, Angle=243 degrees
# Resultant Vector: Magnitude=18.9885, Angle=-118.895 degrees
#
# Pair 930:
# Vector A: Magnitude=5, Angle=107 degrees
# Vector B: Magnitude=1, Angle=1 degrees
# Resultant Vector: Magnitude=4.82116, Angle=95.4991 degrees
#
# Pair 931:
# Vector A: Magnitude=2, Angle=50 degrees
# Vector B: Magnitude=2, Angle=358 degrees
# Resultant Vector: Magnitude=3.59518, Angle=24 degrees
#
# Pair 932:
# Vector A: Magnitude=8, Angle=35 degrees
# Vector B: Magnitude=4, Angle=20 degrees
# Resultant Vector: Magnitude=11.9088, Angle=30.0128 degrees
#
# Pair 933:
# Vector A: Magnitude=7, Angle=116 degrees
# Vector B: Magnitude=2, Angle=78 degrees
# Resultant Vector: Magnitude=8.66397, Angle=107.829 degrees
#
# Pair 934:
# Vector A: Magnitude=3, Angle=218 degrees
# Vector B: Magnitude=6, Angle=94 degrees
# Resultant Vector: Magnitude=4.98689, Angle=123.916 degrees
#
# Pair 935:
# Vector A: Magnitude=4, Angle=9 degrees
# Vector B: Magnitude=7, Angle=228 degrees
# Resultant Vector: Magnitude=4.63463, Angle=-99.102 degrees
#
# Pair 936:
# Vector A: Magnitude=6, Angle=251 degrees
# Vector B: Magnitude=9, Angle=195 degrees
# Resultant Vector: Magnitude=13.3189, Angle=-143.07 degrees
#
# Pair 937:
# Vector A: Magnitude=3, Angle=79 degrees
# Vector B: Magnitude=1, Angle=57 degrees
# Resultant Vector: Magnitude=3.94501, Angle=73.5512 degrees
#
# Pair 938:
# Vector A: Magnitude=7, Angle=270 degrees
# Vector B: Magnitude=1, Angle=187 degrees
# Resultant Vector: Magnitude=7.1907, Angle=-97.934 degrees
#
# Pair 939:
# Vector A: Magnitude=4, Angle=92 degrees
# Vector B: Magnitude=8, Angle=70 degrees
# Resultant Vector: Magnitude=11.8042, Angle=77.2928 degrees
#
# Pair 940:
# Vector A: Magnitude=8, Angle=311 degrees
# Vector B: Magnitude=4, Angle=13 degrees
# Resultant Vector: Magnitude=10.4903, Angle=-29.3257 degrees
#
# Pair 941:
# Vector A: Magnitude=8, Angle=176 degrees
# Vector B: Magnitude=4, Angle=9 degrees
# Resultant Vector: Magnitude=4.20004, Angle=163.629 degrees
#
# Pair 942:
# Vector A: Magnitude=7, Angle=109 degrees
# Vector B: Magnitude=6, Angle=149 degrees
# Resultant Vector: Magnitude=12.2208, Angle=127.396 degrees
#
# Pair 943:
# Vector A: Magnitude=9, Angle=351 degrees
# Vector B: Magnitude=8, Angle=35 degrees
# Resultant Vector: Magnitude=15.7666, Angle=11.6386 degrees
#
# Pair 944:
# Vector A: Magnitude=4, Angle=178 degrees
# Vector B: Magnitude=1, Angle=117 degrees
# Resultant Vector: Magnitude=4.5693, Angle=166.965 degrees
#
# Pair 945:
# Vector A: Magnitude=8, Angle=53 degrees
# Vector B: Magnitude=5, Angle=316 degrees
# Resultant Vector: Magnitude=8.90227, Angle=19.1191 degrees
#
# Pair 946:
# Vector A: Magnitude=6, Angle=105 degrees
# Vector B: Magnitude=6, Angle=28 degrees
# Resultant Vector: Magnitude=9.3913, Angle=66.5 degrees
#
# Pair 947:
# Vector A: Magnitude=10, Angle=73 degrees
# Vector B: Magnitude=10, Angle=196 degrees
# Resultant Vector: Magnitude=9.54318, Angle=134.5 degrees
#
# Pair 948:
# Vector A: Magnitude=7, Angle=294 degrees
# Vector B: Magnitude=2, Angle=195 degrees
# Resultant Vector: Magnitude=6.97279, Angle=-82.4571 degrees
#
# Pair 949:
# Vector A: Magnitude=1, Angle=277 degrees
# Vector B: Magnitude=7, Angle=16 degrees
# Resultant Vector: Magnitude=6.91447, Angle=7.78757 degrees
#
# Pair 950:
# Vector A: Magnitude=9, Angle=51 degrees
# Vector B: Magnitude=7, Angle=248 degrees
# Resultant Vector: Magnitude=3.08312, Angle=9.40893 degrees
#
# Pair 951:
# Vector A: Magnitude=3, Angle=55 degrees
# Vector B: Magnitude=4, Angle=157 degrees
# Resultant Vector: Magnitude=4.47327, Angle=116.005 degrees
#
# Pair 952:
# Vector A: Magnitude=4, Angle=25 degrees
# Vector B: Magnitude=6, Angle=131 degrees
# Resultant Vector: Magnitude=6.22651, Angle=92.8641 degrees
#
# Pair 953:
# Vector A: Magnitude=9, Angle=321 degrees
# Vector B: Magnitude=8, Angle=146 degrees
# Resultant Vector: Magnitude=1.24417, Angle=-73.0841 degrees
#
# Pair 954:
# Vector A: Magnitude=9, Angle=102 degrees
# Vector B: Magnitude=5, Angle=7 degrees
# Resultant Vector: Magnitude=9.90737, Angle=71.8176 degrees
#
# Pair 955:
# Vector A: Magnitude=8, Angle=273 degrees
# Vector B: Magnitude=4, Angle=303 degrees
# Resultant Vector: Magnitude=11.6373, Angle=-77.1039 degrees
#
# Pair 956:
# Vector A: Magnitude=8, Angle=157 degrees
# Vector B: Magnitude=9, Angle=189 degrees
# Resultant Vector: Magnitude=16.3438, Angle=173.966 degrees
#
# Pair 957:
# Vector A: Magnitude=7, Angle=214 degrees
# Vector B: Magnitude=7, Angle=204 degrees
# Resultant Vector: Magnitude=13.9467, Angle=-151 degrees
#
# Pair 958:
# Vector A: Magnitude=6, Angle=244 degrees
# Vector B: Magnitude=3, Angle=180 degrees
# Resultant Vector: Magnitude=7.79624, Angle=-136.234 degrees
#
# Pair 959:
# Vector A: Magnitude=10, Angle=247 degrees
# Vector B: Magnitude=8, Angle=45 degrees
# Resultant Vector: Magnitude=3.95608, Angle=-63.753 degrees
#
# Pair 960:
# Vector A: Magnitude=5, Angle=124 degrees
# Vector B: Magnitude=7, Angle=95 degrees
# Resultant Vector: Magnitude=11.6286, Angle=107.032 degrees
#
# Pair 961:
# Vector A: Magnitude=7, Angle=135 degrees
# Vector B: Magnitude=2, Angle=24 degrees
# Resultant Vector: Magnitude=6.55482, Angle=118.45 degrees
#
# Pair 962:
# Vector A: Magnitude=10, Angle=55 degrees
# Vector B: Magnitude=3, Angle=157 degrees
# Resultant Vector: Magnitude=9.82473, Angle=72.3783 degrees
#
# Pair 963:
# Vector A: Magnitude=2, Angle=107 degrees
# Vector B: Magnitude=1, Angle=280 degrees
# Resultant Vector: Magnitude=1.0148, Angle=113.897 degrees
#
# Pair 964:
# Vector A: Magnitude=7, Angle=111 degrees
# Vector B: Magnitude=1, Angle=82 degrees
# Resultant Vector: Magnitude=7.88953, Angle=107.477 degrees
#
# Pair 965:
# Vector A: Magnitude=6, Angle=188 degrees
# Vector B: Magnitude=7, Angle=103 degrees
# Resultant Vector: Magnitude=9.60839, Angle=141.468 degrees
#
# Pair 966:
# Vector A: Magnitude=3, Angle=250 degrees
# Vector B: Magnitude=4, Angle=11 degrees
# Resultant Vector: Magnitude=3.55515, Angle=-35.3291 degrees
#
# Pair 967:
# Vector A: Magnitude=10, Angle=132 degrees
# Vector B: Magnitude=7, Angle=26 degrees
# Resultant Vector: Magnitude=10.5077, Angle=92.1803 degrees
#
# Pair 968:
# Vector A: Magnitude=8, Angle=104 degrees
# Vector B: Magnitude=2, Angle=343 degrees
# Resultant Vector: Magnitude=7.17766, Angle=90.1817 degrees
#
# Pair 969:
# Vector A: Magnitude=2, Angle=234 degrees
# Vector B: Magnitude=10, Angle=221 degrees
# Resultant Vector: Magnitude=11.9572, Angle=-136.844 degrees
#
# Pair 970:
# Vector A: Magnitude=2, Angle=271 degrees
# Vector B: Magnitude=1, Angle=2 degrees
# Resultant Vector: Magnitude=2.2204, Angle=-62.2371 degrees
#
# Pair 971:
# Vector A: Magnitude=2, Angle=222 degrees
# Vector B: Magnitude=6, Angle=27 degrees
# Resultant Vector: Magnitude=4.10095, Angle=19.7486 degrees
#
# Pair 972:
# Vector A: Magnitude=4, Angle=265 degrees
# Vector B: Magnitude=1, Angle=171 degrees
# Resultant Vector: Magnitude=4.05487, Angle=-109.242 degrees
#
# Pair 973:
# Vector A: Magnitude=6, Angle=268 degrees
# Vector B: Magnitude=7, Angle=37 degrees
# Resultant Vector: Magnitude=5.66896, Angle=-18.3386 degrees
#
# Pair 974:
# Vector A: Magnitude=2, Angle=69 degrees
# Vector B: Magnitude=1, Angle=272 degrees
# Resultant Vector: Magnitude=1.14803, Angle=49.1019 degrees
#
# Pair 975:
# Vector A: Magnitude=4, Angle=209 degrees
# Vector B: Magnitude=9, Angle=330 degrees
# Resultant Vector: Magnitude=7.74062, Angle=-56.2919 degrees
#
# Pair 976:
# Vector A: Magnitude=4, Angle=291 degrees
# Vector B: Magnitude=6, Angle=297 degrees
# Resultant Vector: Magnitude=9.98684, Angle=-65.3995 degrees
#
# Pair 977:
# Vector A: Magnitude=8, Angle=297 degrees
# Vector B: Magnitude=1, Angle=199 degrees
# Resultant Vector: Magnitude=7.92296, Angle=-70.18 degrees
#
# Pair 978:
# Vector A: Magnitude=9, Angle=280 degrees
# Vector B: Magnitude=4, Angle=331 degrees
# Resultant Vector: Magnitude=11.9294, Angle=-64.8954 degrees
#
# Pair 979:
# Vector A: Magnitude=5, Angle=228 degrees
# Vector B: Magnitude=10, Angle=220 degrees
# Resultant Vector: Magnitude=14.9675, Angle=-137.335 degrees
#
# Pair 980:
# Vector A: Magnitude=6, Angle=341 degrees
# Vector B: Magnitude=4, Angle=330 degrees
# Resultant Vector: Magnitude=9.95581, Angle=-23.3967 degrees
#
# Pair 981:
# Vector A: Magnitude=2, Angle=49 degrees
# Vector B: Magnitude=10, Angle=152 degrees
# Resultant Vector: Magnitude=9.74689, Angle=140.467 degrees
#
# Pair 982:
# Vector A: Magnitude=1, Angle=160 degrees
# Vector B: Magnitude=8, Angle=63 degrees
# Resultant Vector: Magnitude=7.94041, Angle=70.1807 degrees
#
# Pair 983:
# Vector A: Magnitude=10, Angle=107 degrees
# Vector B: Magnitude=7, Angle=194 degrees
# Resultant Vector: Magnitude=12.5031, Angle=140.993 degrees
#
# Pair 984:
# Vector A: Magnitude=10, Angle=323 degrees
# Vector B: Magnitude=4, Angle=308 degrees
# Resultant Vector: Magnitude=13.9023, Angle=-41.2707 degrees
#
# Pair 985:
# Vector A: Magnitude=1, Angle=33 degrees
# Vector B: Magnitude=8, Angle=341 degrees
# Resultant Vector: Magnitude=8.65162, Angle=-13.7741 degrees
#
# Pair 986:
# Vector A: Magnitude=6, Angle=221 degrees
# Vector B: Magnitude=3, Angle=72 degrees
# Resultant Vector: Magnitude=3.76058, Angle=-163.26 degrees
#
# Pair 987:
# Vector A: Magnitude=2, Angle=183 degrees
# Vector B: Magnitude=3, Angle=327 degrees
# Resultant Vector: Magnitude=1.81433, Angle=-73.3862 degrees
#
# Pair 988:
# Vector A: Magnitude=5, Angle=195 degrees
# Vector B: Magnitude=10, Angle=286 degrees
# Resultant Vector: Magnitude=11.102, Angle=-100.763 degrees
#
# Pair 989:
# Vector A: Magnitude=5, Angle=49 degrees
# Vector B: Magnitude=1, Angle=234 degrees
# Resultant Vector: Magnitude=4.00475, Angle=47.753 degrees
#
# Pair 990:
# Vector A: Magnitude=2, Angle=247 degrees
# Vector B: Magnitude=10, Angle=90 degrees
# Resultant Vector: Magnitude=8.19633, Angle=95.4711 degrees
#
# Pair 991:
# Vector A: Magnitude=6, Angle=75 degrees
# Vector B: Magnitude=7, Angle=266 degrees
# Resultant Vector: Magnitude=1.59478, Angle=-48.1205 degrees
#
# Pair 992:
# Vector A: Magnitude=2, Angle=160 degrees
# Vector B: Magnitude=5, Angle=171 degrees
# Resultant Vector: Magnitude=6.9737, Angle=167.863 degrees
#
# Pair 993:
# Vector A: Magnitude=6, Angle=2 degrees
# Vector B: Magnitude=5, Angle=123 degrees
# Resultant Vector: Magnitude=5.48614, Angle=53.3717 degrees
#
# Pair 994:
# Vector A: Magnitude=6, Angle=337 degrees
# Vector B: Magnitude=6, Angle=56 degrees
# Resultant Vector: Magnitude=9.2595, Angle=16.5 degrees
#
# Pair 995:
# Vector A: Magnitude=3, Angle=127 degrees
# Vector B: Magnitude=6, Angle=197 degrees
# Resultant Vector: Magnitude=7.57052, Angle=175.138 degrees
#
# Pair 996:
# Vector A: Magnitude=5, Angle=65 degrees
# Vector B: Magnitude=4, Angle=78 degrees
# Resultant Vector: Magnitude=8.94286, Angle=70.7747 degrees
#
# Pair 997:
# Vector A: Magnitude=7, Angle=73 degrees
# Vector B: Magnitude=5, Angle=67 degrees
# Resultant Vector: Magnitude=11.984, Angle=70.5004 degrees
#
# Pair 998:
# Vector A: Magnitude=2, Angle=353 degrees
# Vector B: Magnitude=10, Angle=188 degrees
# Resultant Vector: Magnitude=8.08474, Angle=-168.329 degrees
#
# Pair 999:
# Vector A: Magnitude=2, Angle=57 degrees
# Vector B: Magnitude=5, Angle=212 degrees
# Resultant Vector: Magnitude=3.29755, Angle=-162.852 degrees
#
# Pair 1000:
# Vector A: Magnitude=10, Angle=308 degrees
# Vector B: Magnitude=6, Angle=155 degrees
# Resultant Vector: Magnitude=5.39251, Angle=-82.3403 degrees
